# %%
#Importing modules
import os
from bs4 import BeautifulSoup
import requests
from splinter import Browser
import pandas as pd

# %% [markdown]
# ### Function definition

# %%
def get_pages_count(soup):
    '''
    Return the number of pages to visit for APA that contain dog information
    
    Params: soup --> BeautifulSoup object
    
    Return: pet_entry --> number of pages to iterate
    '''
    #Get the pagination division
    pagination = soup.find('div', class_='pagination')
    pages = list()
    for page in pagination.find_all('a',class_='page'):
        pages.append(page.text)
    return(int(pages[-1]))

# %%
def get_pet_info_by_url(soup):
    '''
    Parse the dog information into a dictionary to append to Mongo DB
    
    Params: soup --> BeautifulSoup object
    
    Return: pet_entry --> dictionary will all pat information
    '''
    #Main dictionary that will hold the data base entry
    pet_entry = dict()
    # Get all dog information
    all_dogs_per_page = soup.find_all('div', class_='large-tile')
    #Parse teh data
    for dog in all_dogs_per_page:
        #Dictonary used to store the data
        pet_data = dict()
        #Get the text based information
        #[-] Name
        pet_name = dog.find('h3').find('a').text
        #[-] Id
        pet_id = dog.find('h6').text
        #[-] Listed information : Age, Sex, Breed
        pet_info = dog.find('ul').find_all("li")
        #[--] Age , index 0
        age_data = pet_info[0].text.split('Months')[0].split('Years')
        #Conver the age in fraction of years
        pet_age = round(int(age_data[0].strip()) + (int(age_data[1].strip()) /12.0),2)
        #[--] Sex , index 1
        pet_sex = pet_info[1].text
        #[--] Breed , index 2
        pet_breed = pet_info[2].text
        #Build the data into the dictionary
        #Get the pet dtats , we need to translate from stars to numbers
        pet_location = pet_info[3].text
        pet_data.update({'pet_name':pet_name})
        pet_data.update({'pet_age':pet_age})
        pet_data.update({'pet_sex':pet_sex})
        pet_data.update({'pet_breed':pet_breed})
        pet_data.update({'pet_location':pet_location})
        #Count the starts to get the data
        possible_stat_list = dog.find_all('div',class_='stats-panel')
        for possible_stat in possible_stat_list:
            stat = possible_stat.find_all('div',class_='flex')
            for category in stat:
                category_name = category.find('span',class_='stats-text').text
                category_score = 0
                stars = category.find_all('img')
                for star in stars:
                    if('star full' == star['alt']):
                         category_score += 1
                #Update the dictionary for each stat
                pet_data.update({category_name:category_score})
        #Update the main dictionary with the ID as main key and return
        pet_entry.update({pet_id:pet_data})
    return pet_entry

# %%
def get_all_apa_data():
    '''
    Parse all dog information for APA dogs
    
    Params: None
    
    Return: pet_entry --> dictionary with the information
    '''
    #main page for DOG adoption APA
    main_url = url = 'https://www.austinpetsalive.org/adopt/dogs'
    #Base url to add the page to scrape
    bas_url_4_page = 'https://www.austinpetsalive.org/adopt/dogs/p'
    #Dictionary used to store all the data scraped
    pet_data = dict()
    #create the browser object
    executable_path = {'executable_path': 'chromedriver'}
    browser = Browser('chrome', **executable_path, headless=False)
    #Create the defult list of URLs to vist and add the first page
    url_list = list(main_url)
    #Visit the main page to collect number of pages and the first data scrape
    browser.visit(main_url)
    # Create BeautifulSoup object; parse with 'html.parser'
    soup = BeautifulSoup(browser.html, 'html.parser')
    #Get the number fo pages to scrape besides the main one
    total_pages = get_pages_count(soup)
    #Update the data of the main entry page
    pet_data.update(get_pet_info_by_url(soup))
    #Iterate over the next pages to get the complete data, we start in 2 bacause
    #index 1 is the pain page
    for page_idx in range(2,total_pages+1):
        #Build the new page
        page_url = bas_url_4_page + str(page_idx)
        #Visit the new page
        browser.visit(page_url)
        #parse teh data
        soup = BeautifulSoup(browser.html, 'html.parser')
        #Update the information
        pet_data.update(get_pet_info_by_url(soup))
    #Clos ethe browser
    browser.quit()
    return pet_data

# %% [markdown]
# ###  Scrape the data

# %%
#Get the information
apa_data = get_all_apa_data()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\selenium\webdriver\common\service.py in start(self)
#      75                                             stderr=self.log_file,
# ---> 76                                             stdin=PIPE)
#      77         except TypeError:
#
# ~\Anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     774                                 errread, errwrite,
# --> 775                                 restore_signals, start_new_session)
#     776         except:
#
# ~\Anaconda3\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_start_new_session)
#    1177                                          os.fspath(cwd) if cwd is not None else None,
# -> 1178                                          startupinfo)
#    1179             finally:
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# During handling of the above exception, another exception occurred:
#
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-5-706f5ac8b593> in <module>
#       1 #Get the information
# ----> 2 apa_data = get_all_apa_data()
#
# <ipython-input-4-56103071d447> in get_all_apa_data()
#      15     #create the browser object
#      16     executable_path = {'executable_path': 'chromedriver'}
# ---> 17     browser = Browser('chrome', **executable_path, headless=False)
#      18     #Create the defult list of URLs to vist and add the first page
#      19     url_list = list(main_url)
#
# ~\Anaconda3\lib\site-packages\splinter\browser.py in Browser(driver_name, *args, **kwargs)
#      62     except KeyError:
#      63         raise DriverNotFoundError("No driver for %s" % driver_name)
# ---> 64     return driver(*args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\splinter\driver\webdriver\chrome.py in __init__(self, options, user_agent, wait_time, fullscreen, incognito, headless, **kwargs)
#      41             options.add_argument("--disable-gpu")
#      42
# ---> 43         self.driver = Chrome(options=options, **kwargs)
#      44
#      45         self.element_class = WebDriverElement
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\chrome\webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, keep_alive)
#      71             service_args=service_args,
#      72             log_path=service_log_path)
# ---> 73         self.service.start()
#      74
#      75         try:
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\common\service.py in start(self)
#      81                 raise WebDriverException(
#      82                     "'%s' executable needs to be in PATH. %s" % (
# ---> 83                         os.path.basename(self.path), self.start_error_message)
#      84                 )
#      85             elif err.errno == errno.EACCES:
#
# WebDriverException: Message: 'chromedriver' executable needs to be in PATH. Please see https://sites.google.com/a/chromium.org/chromedriver/home

# %%
#Display the information
apa_data
# Out:
# {'APA-A-36615': {'pet_name': 'Sparky',
#   'pet_age': 6.5,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'Foster',
#   'Dog': 1,
#   'Cat': 1,
#   'Child': 2,
#   'Home  Alone ': 4},
#  'APA-A-45785': {'pet_name': 'Rio',
#   'pet_age': 3.75,
#   'pet_sex': 'Male',
#   'pet_breed': 'Mixed Breed (Large) / Great Dane',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 5},
#  'APA-A-47726': {'pet_name': 'Twister',
#   'pet_age': 5.67,
#   'pet_sex': 'Male',
#   'pet_breed': 'Shepherd, Anatolian / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 2,
#   'Child': 1,
#   'Home  Alone ': 5},
#  'APA-A-49698': {'pet_name': 'Beryl',
#   'pet_age': 6.58,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Yellow Labrador / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 2,
#   'Child': 1,
#   'Home  Alone ': 4},
#  'APA-A-43905': {'pet_name': 'Brindle',
#   'pet_age': 5.5,
#   'pet_sex': 'Male',
#   'pet_breed': 'Hound / Hound',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 2,
#   'Child': 1,
#   'Home  Alone ': 5},
#  'APA-A-35188': {'pet_name': 'Ziggy',
#   'pet_age': 4.42,
#   'pet_sex': 'Male',
#   'pet_breed': 'Hound / Mix',
#   'pet_location': 'Foster',
#   'Dog': 1,
#   'Cat': 3,
#   'Child': 1,
#   'Home  Alone ': 4},
#  'APA-A-53121': {'pet_name': 'Grayson',
#   'pet_age': 3.92,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Labrador / Mix',
#   'pet_location': 'Foster',
#   'Dog': 1,
#   'Cat': 0,
#   'Child': 3,
#   'Home  Alone ': 5},
#  'APA-A-53740': {'pet_name': 'Ludwig',
#   'pet_age': 6.67,
#   'pet_sex': 'Male',
#   'pet_breed': 'Bernese Mountain Dog / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 3},
#  'APA-A-54604': {'pet_name': 'Vegas',
#   'pet_age': 5.83,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'Foster',
#   'Dog': 1,
#   'Cat': 2,
#   'Child': 1,
#   'Home  Alone ': 4},
#  'APA-A-54851': {'pet_name': 'June Bug',
#   'pet_age': 5.92,
#   'pet_sex': 'Female',
#   'pet_breed': 'Retriever, Labrador / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 4,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 4},
#  'APA-A-37564': {'pet_name': 'Rocco',
#   'pet_age': 4.75,
#   'pet_sex': 'Male',
#   'pet_breed': 'Catahoula Leopard Dog / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 2,
#   'Child': 1,
#   'Home  Alone ': 4},
#  'APA-A-55056': {'pet_name': 'Jake Ryan',
#   'pet_age': 6.83,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Labrador / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 1,
#   'Child': 1,
#   'Home  Alone ': 2},
#  'APA-A-55237': {'pet_name': 'Brooks',
#   'pet_age': 7.92,
#   'pet_sex': 'Male',
#   'pet_breed': 'Mixed Breed (Medium) / Mix',
#   'pet_location': 'Foster',
#   'Dog': 1,
#   'Cat': 1,
#   'Child': 2,
#   'Home  Alone ': 4},
#  'APA-A-55491': {'pet_name': 'Schone',
#   'pet_age': 10.25,
#   'pet_sex': 'Female',
#   'pet_breed': 'Retriever, Black Labrador',
#   'pet_location': 'Foster',
#   'Dog': 1,
#   'Cat': 3,
#   'Child': 4,
#   'Home  Alone ': 3},
#  'APA-A-40017': {'pet_name': 'Monty',
#   'pet_age': 4.42,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'Foster',
#   'Dog': 1,
#   'Cat': 1,
#   'Child': 2,
#   'Home  Alone ': 4},
#  'APA-A-36893': {'pet_name': 'Nike',
#   'pet_age': 9.0,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Labrador / Mix',
#   'pet_location': 'Foster',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 5},
#  'APA-A-57113': {'pet_name': 'Bob Barker',
#   'pet_age': 6.5,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever / Mixed Breed (Large)',
#   'pet_location': 'Foster',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 3},
#  'APA-A-57449': {'pet_name': 'Bethany',
#   'pet_age': 9.83,
#   'pet_sex': 'Female',
#   'pet_breed': 'Retriever, Black Labrador / Mix',
#   'pet_location': 'Foster',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 4},
#  'APA-A-53450': {'pet_name': 'Jasmine',
#   'pet_age': 5.08,
#   'pet_sex': 'Female',
#   'pet_breed': 'Retriever, Black Labrador / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 1,
#   'Child': 1,
#   'Home  Alone ': 5},
#  'APA-A-58608': {'pet_name': 'Manning',
#   'pet_age': 4.33,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Labrador / Shepherd, German',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 3},
#  'APA-A-59189': {'pet_name': 'Benito',
#   'pet_age': 4.58,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'Foster',
#   'Dog': 1,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 5},
#  'APA-A-59431': {'pet_name': 'Princeton',
#   'pet_age': 7.42,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 4,
#   'Child': 1,
#   'Home  Alone ': 4},
#  'APA-A-55345': {'pet_name': 'Cricket',
#   'pet_age': 7.92,
#   'pet_sex': 'Female',
#   'pet_breed': 'Retriever, Labrador / Mix',
#   'pet_location': 'Foster',
#   'Dog': 2,
#   'Cat': 2,
#   'Child': 3,
#   'Home  Alone ': 3},
#  'APA-A-60553': {'pet_name': 'Toro',
#   'pet_age': 6.83,
#   'pet_sex': 'Male',
#   'pet_breed': 'Mixed Breed (Large) / Mix',
#   'pet_location': 'Foster',
#   'Dog': 2,
#   'Cat': 2,
#   'Child': 2,
#   'Home  Alone ': 3},
#  'APA-A-61252': {'pet_name': 'Sally',
#   'pet_age': 3.67,
#   'pet_sex': 'Female',
#   'pet_breed': 'Mixed Breed (Medium)',
#   'pet_location': 'Foster',
#   'Dog': 2,
#   'Cat': 2,
#   'Child': 2,
#   'Home  Alone ': 4},
#  'APA-A-56868': {'pet_name': 'Migos',
#   'pet_age': 5.83,
#   'pet_sex': 'Male',
#   'pet_breed': 'Mixed Breed (Medium)',
#   'pet_location': 'Foster',
#   'Dog': 2,
#   'Cat': 2,
#   'Child': 3,
#   'Home  Alone ': 4},
#  'APA-A-30844': {'pet_name': 'Josie',
#   'pet_age': 4.67,
#   'pet_sex': 'Female',
#   'pet_breed': 'Retriever / Mix',
#   'pet_location': 'Foster',
#   'Dog': 2,
#   'Cat': 1,
#   'Child': 1,
#   'Home  Alone ': 5},
#  'APA-A-61501': {'pet_name': 'Kline',
#   'pet_age': 2.67,
#   'pet_sex': 'Male',
#   'pet_breed': 'Cattle Dog / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 2,
#   'Child': 3,
#   'Home  Alone ': 3},
#  'APA-A-62339': {'pet_name': 'Miguelito',
#   'pet_age': 8.08,
#   'pet_sex': 'Male',
#   'pet_breed': 'Chihuahua',
#   'pet_location': 'Tarrytown',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 4},
#  'APA-A-62575': {'pet_name': 'Tom Hanks',
#   'pet_age': 6.17,
#   'pet_sex': 'Male',
#   'pet_breed': 'Mixed Breed (Medium) / Mix',
#   'pet_location': 'Foster',
#   'Dog': 1,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 4},
#  'APA-A-55843': {'pet_name': 'Floppy',
#   'pet_age': 4.83,
#   'pet_sex': 'Male',
#   'pet_breed': 'Mixed Breed (Medium)',
#   'pet_location': 'Foster',
#   'Dog': 1,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 4},
#  'APA-A-64403': {'pet_name': 'Brady',
#   'pet_age': 11.0,
#   'pet_sex': 'Male',
#   'pet_breed': 'Mixed Breed (Medium) / Mix',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 1,
#   'Child': 4,
#   'Home  Alone ': 3},
#  'APA-A-64409': {'pet_name': 'Jenga',
#   'pet_age': 4.08,
#   'pet_sex': 'Female',
#   'pet_breed': 'Bulldog, American / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 2,
#   'Child': 2,
#   'Home  Alone ': 4},
#  'APA-A-64524': {'pet_name': 'Mr Marbles',
#   'pet_age': 6.25,
#   'pet_sex': 'Male',
#   'pet_breed': 'Mixed Breed (Large)',
#   'pet_location': 'Foster',
#   'Dog': 1,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 5},
#  'APA-A-64567': {'pet_name': 'Midnight',
#   'pet_age': 4.08,
#   'pet_sex': 'Female',
#   'pet_breed': 'Retriever, Black Labrador / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 1,
#   'Child': 2,
#   'Home  Alone ': 4},
#  'APA-A-41503': {'pet_name': 'Clark',
#   'pet_age': 8.33,
#   'pet_sex': 'Male',
#   'pet_breed': 'Boxer / Mixed Breed (Medium)',
#   'pet_location': 'Foster',
#   'Dog': 2,
#   'Cat': 3,
#   'Child': 1,
#   'Home  Alone ': 5},
#  'APA-A-38221': {'pet_name': 'Calvin',
#   'pet_age': 3.83,
#   'pet_sex': 'Male',
#   'pet_breed': 'Coonhound, Redbone / Mix',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 4},
#  'APA-A-46986': {'pet_name': 'Brenda',
#   'pet_age': 7.08,
#   'pet_sex': 'Female',
#   'pet_breed': 'Dachshund / Mix',
#   'pet_location': 'Foster',
#   'Dog': 3,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 3},
#  'APA-A-49870': {'pet_name': 'El Jefe',
#   'pet_age': 4.25,
#   'pet_sex': 'Male',
#   'pet_breed': 'Boxer / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 4},
#  'APA-A-57999': {'pet_name': 'Button',
#   'pet_age': 3.17,
#   'pet_sex': 'Male',
#   'pet_breed': 'Mixed Breed (Medium) / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 4},
#  'APA-A-65267': {'pet_name': 'Sarah',
#   'pet_age': 5.83,
#   'pet_sex': 'Female',
#   'pet_breed': 'Mixed Breed (Medium) / Mix',
#   'pet_location': 'Foster',
#   'Dog': 1,
#   'Cat': 2,
#   'Child': 2,
#   'Home  Alone ': 4},
#  'APA-A-55076': {'pet_name': 'Sailor',
#   'pet_age': 3.33,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 2,
#   'Child': 3,
#   'Home  Alone ': 5},
#  'APA-A-59055': {'pet_name': 'Rhino',
#   'pet_age': 3.83,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'Foster',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 5},
#  'APA-A-38419': {'pet_name': 'Tutu',
#   'pet_age': 5.67,
#   'pet_sex': 'Female',
#   'pet_breed': 'Mixed Breed (Medium) / Boxer',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 1},
#  'APA-A-66283': {'pet_name': 'Churchill',
#   'pet_age': 3.83,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 0,
#   'Child': 4,
#   'Home  Alone ': 4},
#  'APA-A-55384': {'pet_name': 'John Rambo',
#   'pet_age': 4.33,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Labrador / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 4},
#  'APA-A-62493': {'pet_name': 'Lennon',
#   'pet_age': 4.75,
#   'pet_sex': 'Male',
#   'pet_breed': 'Shepherd, German / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 1,
#   'Child': 1,
#   'Home  Alone ': 2},
#  'APA-A-50261': {'pet_name': 'Mercedes',
#   'pet_age': 3.25,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 2,
#   'Child': 2,
#   'Home  Alone ': 5},
#  'APA-A-50976': {'pet_name': 'Bel-air',
#   'pet_age': 2.08,
#   'pet_sex': 'Male',
#   'pet_breed': 'Mixed Breed (Medium) / Mix',
#   'pet_location': 'Foster',
#   'Dog': 3,
#   'Cat': 2,
#   'Child': 2,
#   'Home  Alone ': 5},
#  'APA-A-66640': {'pet_name': 'Albus',
#   'pet_age': 4.83,
#   'pet_sex': 'Male',
#   'pet_breed': 'Mixed Breed (Large) / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 4},
#  'APA-A-66661': {'pet_name': 'Goldman',
#   'pet_age': 3.0,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Yellow Labrador / Mixed Breed (Medium)',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 4},
#  'APA-A-45661': {'pet_name': 'Nokie',
#   'pet_age': 8.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier, American Staffordshire / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 2,
#   'Child': 2,
#   'Home  Alone ': 5},
#  'APA-A-36999': {'pet_name': 'Mack',
#   'pet_age': 7.67,
#   'pet_sex': 'Male',
#   'pet_breed': 'Mixed Breed (Medium)',
#   'pet_location': 'Foster',
#   'Dog': 1,
#   'Cat': 3,
#   'Child': 2,
#   'Home  Alone ': 4},
#  'APA-A-49408': {'pet_name': 'Minka',
#   'pet_age': 7.25,
#   'pet_sex': 'Female',
#   'pet_breed': 'Mixed Breed (Medium) / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 1,
#   'Child': 1,
#   'Home  Alone ': 4},
#  'APA-A-31118': {'pet_name': 'Fun Guy',
#   'pet_age': 4.83,
#   'pet_sex': 'Male',
#   'pet_breed': 'Chihuahua, Short Coat / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 2,
#   'Child': 1,
#   'Home  Alone ': 4},
#  'APA-A-69626': {'pet_name': 'Lee',
#   'pet_age': 2.67,
#   'pet_sex': 'Male',
#   'pet_breed': 'Hound, Pharaoh / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 3},
#  'APA-A-69663': {'pet_name': 'Trigger',
#   'pet_age': 3.75,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Chocolate Labrador / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 4},
#  'APA-A-56036': {'pet_name': 'Osito',
#   'pet_age': 3.83,
#   'pet_sex': 'Male',
#   'pet_breed': 'Chihuahua / Terrier',
#   'pet_location': 'Tarrytown',
#   'Dog': 3,
#   'Cat': 3,
#   'Child': 2,
#   'Home  Alone ': 5},
#  'APA-A-69717': {'pet_name': 'Otis',
#   'pet_age': 3.67,
#   'pet_sex': 'Male',
#   'pet_breed': 'Akita / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 4},
#  'APA-A-55324': {'pet_name': 'Spot',
#   'pet_age': 6.17,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Bulldog, American',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 3,
#   'Child': 2,
#   'Home  Alone ': 4},
#  'APA-A-70116': {'pet_name': 'Cashew',
#   'pet_age': 2.0,
#   'pet_sex': 'Female',
#   'pet_breed': 'Basenji',
#   'pet_location': 'Foster',
#   'Dog': 2,
#   'Cat': 4,
#   'Child': 2,
#   'Home  Alone ': 4},
#  'APA-A-45387': {'pet_name': 'Mondo',
#   'pet_age': 6.83,
#   'pet_sex': 'Male',
#   'pet_breed': 'Hound / Mix',
#   'pet_location': 'Foster',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 3},
#  'APA-A-50809': {'pet_name': 'Juanita',
#   'pet_age': 3.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Mixed Breed (Medium)',
#   'pet_location': 'Foster',
#   'Dog': 1,
#   'Cat': 1,
#   'Child': 2,
#   'Home  Alone ': 4},
#  'APA-A-25593': {'pet_name': 'Dennis',
#   'pet_age': 10.67,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Labrador / Mix',
#   'pet_location': 'Foster',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 5},
#  'APA-A-46692': {'pet_name': 'Rustler',
#   'pet_age': 6.58,
#   'pet_sex': 'Male',
#   'pet_breed': 'Mixed Breed (Medium) / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 1,
#   'Child': 2,
#   'Home  Alone ': 3},
#  'APA-A-33573': {'pet_name': 'Tommy',
#   'pet_age': 4.42,
#   'pet_sex': 'Male',
#   'pet_breed': 'Greyhound / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 3},
#  'APA-A-66855': {'pet_name': 'Van Gogh',
#   'pet_age': 1.83,
#   'pet_sex': 'Male',
#   'pet_breed': 'Cattle Dog, Australian (Blue Heeler) / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 2,
#   'Child': 2,
#   'Home  Alone ': 3},
#  'APA-A-69494': {'pet_name': 'Queen Brenda',
#   'pet_age': 3.08,
#   'pet_sex': 'Female',
#   'pet_breed': 'Malinois, Belgian',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 4},
#  'APA-A-37920': {'pet_name': 'Pinocchio',
#   'pet_age': 7.08,
#   'pet_sex': 'Male',
#   'pet_breed': 'Great Dane / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 3},
#  'APA-A-56161': {'pet_name': 'Gelato',
#   'pet_age': 3.75,
#   'pet_sex': 'Male',
#   'pet_breed': 'Mixed Breed (Medium) / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 2,
#   'Child': 3,
#   'Home  Alone ': 4},
#  'APA-A-70891': {'pet_name': 'Sullivan',
#   'pet_age': 2.5,
#   'pet_sex': 'Male',
#   'pet_breed': 'Shepherd, Anatolian / Chow Chow',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 4},
#  'APA-A-71075': {'pet_name': 'Alejandro',
#   'pet_age': 2.83,
#   'pet_sex': 'Male',
#   'pet_breed': 'Shepherd, German / Retriever, Labrador',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 3},
#  'APA-A-50901': {'pet_name': 'Stella',
#   'pet_age': 2.58,
#   'pet_sex': 'Female',
#   'pet_breed': 'Mixed Breed (Medium) / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 4},
#  'APA-A-20065': {'pet_name': 'Dino',
#   'pet_age': 6.67,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 4},
#  'APA-A-37585': {'pet_name': 'Rousseau',
#   'pet_age': 3.67,
#   'pet_sex': 'Female',
#   'pet_breed': 'Coonhound, Bluetick / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 0,
#   'Child': 3,
#   'Home  Alone ': 4},
#  'APA-A-71312': {'pet_name': 'Pumpkin',
#   'pet_age': 5.92,
#   'pet_sex': 'Female',
#   'pet_breed': 'Hound / Mix',
#   'pet_location': 'Foster',
#   'Dog': 2,
#   'Cat': 3,
#   'Child': 2,
#   'Home  Alone ': 3},
#  'APA-A-71317': {'pet_name': 'Raphael',
#   'pet_age': 5.17,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, American Staffordshire / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 4},
#  'APA-A-55862': {'pet_name': 'Mike Jonze',
#   'pet_age': 1.67,
#   'pet_sex': 'Male',
#   'pet_breed': 'Shepherd, German / Mix',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 2,
#   'Child': 2,
#   'Home  Alone ': 4},
#  'APA-A-71409': {'pet_name': 'Dreamboat',
#   'pet_age': 1.42,
#   'pet_sex': 'Male',
#   'pet_breed': 'Chihuahua / Mix',
#   'pet_location': 'Tarrytown',
#   'Dog': 4,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 3},
#  'APA-A-71406': {'pet_name': 'Poof',
#   'pet_age': 3.42,
#   'pet_sex': 'Female',
#   'pet_breed': 'Chihuahua / Mix',
#   'pet_location': 'Tarrytown',
#   'Dog': 4,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 4},
#  'APA-A-71315': {'pet_name': 'Mariska',
#   'pet_age': 1.75,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-71498': {'pet_name': 'Mr. Pickles',
#   'pet_age': 3.42,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Black Labrador / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 3,
#   'Home  Alone ': 4},
#  'APA-A-71489': {'pet_name': 'Thanos',
#   'pet_age': 2.25,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Chocolate Labrador',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-32193': {'pet_name': 'Lillian',
#   'pet_age': 5.08,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier, American Staffordshire / Mix',
#   'pet_location': 'Foster',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 5},
#  'APA-A-51527': {'pet_name': 'Prince Charming',
#   'pet_age': 4.0,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Retriever, Labrador',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 1,
#   'Child': 3,
#   'Home  Alone ': 3},
#  'APA-A-12490': {'pet_name': 'Amelia Bedelia',
#   'pet_age': 7.92,
#   'pet_sex': 'Female',
#   'pet_breed': 'Cattle Dog, Australian (Blue Heeler) / Collie, Border',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 4},
#  'APA-A-71685': {'pet_name': 'Revlon',
#   'pet_age': 2.75,
#   'pet_sex': 'Male',
#   'pet_breed': 'Bulldog, American / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 4},
#  'APA-A-19372': {'pet_name': 'Xena',
#   'pet_age': 6.58,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 3},
#  'APA-A-6404': {'pet_name': 'Silent Bob',
#   'pet_age': 8.83,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-71745': {'pet_name': 'Possum',
#   'pet_age': 1.75,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'Foster',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 3,
#   'Home  Alone ': 3},
#  'APA-A-38468': {'pet_name': 'Howard',
#   'pet_age': 5.92,
#   'pet_sex': 'Male',
#   'pet_breed': 'Cattle Dog, Australian (Blue Heeler) / Mix',
#   'pet_location': 'Foster',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 5},
#  'APA-A-71798': {'pet_name': 'Gale',
#   'pet_age': 0.42,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, American Pit Bull',
#   'pet_location': 'TLAC',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-28011': {'pet_name': 'Reno',
#   'pet_age': 5.92,
#   'pet_sex': 'Male',
#   'pet_breed': 'Shepherd, Australian / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 4},
#  'APA-A-71948': {'pet_name': 'Thomas',
#   'pet_age': 3.42,
#   'pet_sex': 'Male',
#   'pet_breed': 'Collie / Mix',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 1},
#  'APA-A-50244': {'pet_name': 'Zora',
#   'pet_age': 4.25,
#   'pet_sex': 'Female',
#   'pet_breed': 'Retriever, Black Labrador / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 3},
#  'APA-A-72390': {'pet_name': 'Denny',
#   'pet_age': 2.33,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, American Staffordshire / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 4},
#  'APA-A-38108': {'pet_name': 'Cookie',
#   'pet_age': 4.75,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Labrador / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 2,
#   'Child': 1,
#   'Home  Alone ': 4},
#  'APA-A-72785': {'pet_name': 'Gomez',
#   'pet_age': 0.5,
#   'pet_sex': 'Male',
#   'pet_breed': 'Mixed Breed (Medium) / Mix',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 3,
#   'Child': 2,
#   'Home  Alone ': 0},
#  'APA-A-72839': {'pet_name': 'Willis',
#   'pet_age': 2.33,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-73067': {'pet_name': 'Zelda',
#   'pet_age': 3.25,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier, American Pit Bull / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-73063': {'pet_name': 'Filbert',
#   'pet_age': 2.25,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Labrador / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 1,
#   'Child': 0,
#   'Home  Alone ': 4},
#  'APA-A-72999': {'pet_name': 'Bohdi',
#   'pet_age': 1.33,
#   'pet_sex': 'Male',
#   'pet_breed': 'Shepherd, Anatolian',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 4,
#   'Child': 1,
#   'Home  Alone ': 4},
#  'APA-A-73129': {'pet_name': 'Jack',
#   'pet_age': 6.42,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Labrador',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 4},
#  'APA-A-48650': {'pet_name': 'Martin',
#   'pet_age': 2.75,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'Foster',
#   'Dog': 2,
#   'Cat': 2,
#   'Child': 2,
#   'Home  Alone ': 4},
#  'APA-A-73283': {'pet_name': 'Marshall',
#   'pet_age': 1.75,
#   'pet_sex': 'Male',
#   'pet_breed': 'Catahoula Leopard Dog / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 4},
#  'APA-A-73287': {'pet_name': 'Brandy',
#   'pet_age': 6.08,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 0,
#   'Child': 3,
#   'Home  Alone ': 4},
#  'APA-A-63194': {'pet_name': 'Triton',
#   'pet_age': 4.0,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 2,
#   'Child': 2,
#   'Home  Alone ': 4},
#  'APA-A-73377': {'pet_name': 'Elmo',
#   'pet_age': 1.25,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Labrador / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 4,
#   'Cat': 3,
#   'Child': 0,
#   'Home  Alone ': 3},
#  'APA-A-59125': {'pet_name': 'Maple',
#   'pet_age': 2.0,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, American Pit Bull / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 4,
#   'Child': 2,
#   'Home  Alone ': 3},
#  'APA-A-73433': {'pet_name': 'Flare',
#   'pet_age': 0.25,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Labrador / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-73448': {'pet_name': 'Harry Potter',
#   'pet_age': 6.83,
#   'pet_sex': 'Male',
#   'pet_breed': 'Chihuahua / Pomeranian',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-73509': {'pet_name': 'Charlie',
#   'pet_age': 1.25,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull',
#   'pet_location': 'Foster',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 0},
#  'APA-A-12538': {'pet_name': 'Martha',
#   'pet_age': 8.0,
#   'pet_sex': 'Female',
#   'pet_breed': 'Retriever, Labrador / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 0,
#   'Child': 4,
#   'Home  Alone ': 5},
#  'APA-A-46924': {'pet_name': 'Olympia',
#   'pet_age': 6.08,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier, Pit Bull',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 2,
#   'Child': 2,
#   'Home  Alone ': 3},
#  'APA-A-71256': {'pet_name': 'Crackers',
#   'pet_age': 3.17,
#   'pet_sex': 'Male',
#   'pet_breed': 'Chihuahua / Mix',
#   'pet_location': 'Foster',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 3},
#  'APA-A-39606': {'pet_name': 'Leonidas',
#   'pet_age': 7.08,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'Foster',
#   'Dog': 2,
#   'Cat': 1,
#   'Child': 3,
#   'Home  Alone ': 4},
#  'APA-A-71471': {'pet_name': 'Soup',
#   'pet_age': 2.5,
#   'pet_sex': 'Male',
#   'pet_breed': 'Bulldog, American / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 1,
#   'Child': 2,
#   'Home  Alone ': 4},
#  'APA-A-32157': {'pet_name': 'Big Caesar',
#   'pet_age': 10.42,
#   'pet_sex': 'Male',
#   'pet_breed': 'Dogo Argentino / Bulldog',
#   'pet_location': 'Foster',
#   'Dog': 1,
#   'Cat': 1,
#   'Child': 2,
#   'Home  Alone ': 5},
#  'APA-A-73778': {'pet_name': 'Shasta',
#   'pet_age': 2.33,
#   'pet_sex': 'Female',
#   'pet_breed': 'Dogo Argentino / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-73806': {'pet_name': 'Serengeti',
#   'pet_age': 5.25,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 0,
#   'Child': 3,
#   'Home  Alone ': 4},
#  'APA-A-73794': {'pet_name': 'Sir Mix-a-Lot',
#   'pet_age': 2.33,
#   'pet_sex': 'Male',
#   'pet_breed': 'Catahoula Leopard Dog',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-73815': {'pet_name': 'Parker',
#   'pet_age': 3.25,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 4},
#  'APA-A-73813': {'pet_name': 'Harmony',
#   'pet_age': 2.25,
#   'pet_sex': 'Female',
#   'pet_breed': 'Retriever, Labrador / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 0,
#   'Cat': 1,
#   'Child': 0,
#   'Home  Alone ': 3},
#  'APA-A-62458': {'pet_name': 'Todd',
#   'pet_age': 2.08,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 4},
#  'APA-A-73822': {'pet_name': 'Molly',
#   'pet_age': 5.25,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier, Pit Bull',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-73914': {'pet_name': 'Altaria',
#   'pet_age': 1.33,
#   'pet_sex': 'Female',
#   'pet_breed': 'Hound, Plott',
#   'pet_location': 'TLAC',
#   'Dog': 0,
#   'Cat': 3,
#   'Child': 4,
#   'Home  Alone ': 3},
#  'APA-A-71768': {'pet_name': 'Scott',
#   'pet_age': 2.42,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Black Labrador / Mixed Breed (Medium)',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 2,
#   'Child': 2,
#   'Home  Alone ': 3},
#  'APA-A-73987': {'pet_name': 'Flute',
#   'pet_age': 1.25,
#   'pet_sex': 'Female',
#   'pet_breed': 'Pyrenees, Great / Retriever, Labrador',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 3,
#   'Child': 3,
#   'Home  Alone ': 4},
#  'APA-A-73983': {'pet_name': 'Zephyr',
#   'pet_age': 6.25,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Bull / Chinese Shar-Pei',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 4},
#  'APA-A-73981': {'pet_name': 'Sage',
#   'pet_age': 4.25,
#   'pet_sex': 'Female',
#   'pet_breed': 'Bulldog, American',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-74049': {'pet_name': 'Melody',
#   'pet_age': 0.17,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Labrador / Mix',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-74046': {'pet_name': 'Tempo',
#   'pet_age': 0.17,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Labrador / Mix',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-74051': {'pet_name': 'Chicklet',
#   'pet_age': 4.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier, Pit Bull',
#   'pet_location': 'Foster',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 4},
#  'APA-A-74064': {'pet_name': 'Rosebud',
#   'pet_age': 0.83,
#   'pet_sex': 'Female',
#   'pet_breed': 'Great Dane / Retriever, Black Labrador',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 3},
#  'APA-A-74132': {'pet_name': 'James Bond',
#   'pet_age': 4.17,
#   'pet_sex': 'Male',
#   'pet_breed': 'Mixed Breed (Medium)',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-74126': {'pet_name': 'Elmer',
#   'pet_age': 2.17,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Labrador / Pointer',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-74140': {'pet_name': 'Snortlette',
#   'pet_age': 3.25,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier, American Pit Bull / Terrier, American Staffordshire',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 2,
#   'Child': 3,
#   'Home  Alone ': 4},
#  'APA-A-74099': {'pet_name': 'Margrrrita',
#   'pet_age': 10.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Poodle, Miniature',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 4,
#   'Home  Alone ': 2},
#  'APA-A-74145': {'pet_name': 'Thelma',
#   'pet_age': 0.75,
#   'pet_sex': 'Female',
#   'pet_breed': 'Pyrenees, Great / Mix',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 4,
#   'Home  Alone ': 4},
#  'APA-A-74082': {'pet_name': 'Bette',
#   'pet_age': 2.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Husky / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 4},
#  'APA-A-65855': {'pet_name': 'Schroeder',
#   'pet_age': 1.83,
#   'pet_sex': 'Male',
#   'pet_breed': 'Bernese Mountain Dog / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 0},
#  'APA-A-39544': {'pet_name': 'Pippen',
#   'pet_age': 3.5,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Labrador / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 4,
#   'Cat': 3,
#   'Child': 2,
#   'Home  Alone ': 4},
#  'APA-A-66365': {'pet_name': 'Joshua',
#   'pet_age': 2.83,
#   'pet_sex': 'Male',
#   'pet_breed': 'Collie, Border / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 3},
#  'APA-A-74279': {'pet_name': 'Mr. Squiggles',
#   'pet_age': 0.92,
#   'pet_sex': 'Male',
#   'pet_breed': 'Shepherd, German / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 3},
#  'APA-A-74250': {'pet_name': 'Elton',
#   'pet_age': 0.83,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Labrador / Mix',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 0,
#   'Child': 4,
#   'Home  Alone ': 3},
#  'APA-A-74277': {'pet_name': 'Sugar',
#   'pet_age': 1.33,
#   'pet_sex': 'Female',
#   'pet_breed': 'Pyrenees, Great / Mix',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-74278': {'pet_name': 'Spice',
#   'pet_age': 1.33,
#   'pet_sex': 'Female',
#   'pet_breed': 'Pyrenees, Great / Mix',
#   'pet_location': 'Foster',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 3},
#  'APA-A-74282': {'pet_name': 'Juno',
#   'pet_age': 1.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Chihuahua',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-26694': {'pet_name': 'Paco',
#   'pet_age': 5.5,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 2,
#   'Child': 2,
#   'Home  Alone ': 4},
#  'APA-A-74276': {'pet_name': 'Prince Harry',
#   'pet_age': 2.17,
#   'pet_sex': 'Male',
#   'pet_breed': 'Mixed Breed (Medium)',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-74352': {'pet_name': 'Tip',
#   'pet_age': 12.17,
#   'pet_sex': 'Male',
#   'pet_breed': 'Chihuahua, Short Coat / Mix',
#   'pet_location': 'Foster',
#   'Dog': 3,
#   'Cat': 3,
#   'Child': 2,
#   'Home  Alone ': 3},
#  'APA-A-40577': {'pet_name': 'Felipe',
#   'pet_age': 3.58,
#   'pet_sex': 'Male',
#   'pet_breed': 'Cattle Dog, Australian (Red Heeler) / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 3},
#  'APA-A-74380': {'pet_name': 'Master',
#   'pet_age': 0.33,
#   'pet_sex': 'Male',
#   'pet_breed': 'Cattle Dog, Australian (Red Heeler)',
#   'pet_location': 'TLAC',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-74437': {'pet_name': 'Jessie',
#   'pet_age': 2.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Retriever / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-74435': {'pet_name': 'Sir Wigglesworth',
#   'pet_age': 2.5,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-74418': {'pet_name': 'Amara',
#   'pet_age': 0.33,
#   'pet_sex': 'Female',
#   'pet_breed': 'Mixed Breed (Large)',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-74459': {'pet_name': 'Cersei',
#   'pet_age': 0.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Chihuahua',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-74420': {'pet_name': 'Beckett',
#   'pet_age': 0.33,
#   'pet_sex': 'Male',
#   'pet_breed': 'Mixed Breed (Large)',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-74503': {'pet_name': 'Chewbarka',
#   'pet_age': 0.17,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-74534': {'pet_name': 'Connie',
#   'pet_age': 2.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Chihuahua / Mix',
#   'pet_location': 'Foster',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 4},
#  'APA-A-74535': {'pet_name': 'Scarlett',
#   'pet_age': 1.5,
#   'pet_sex': 'Female',
#   'pet_breed': 'Retriever, Labrador / American Blue Heeler',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 3,
#   'Home  Alone ': 4},
#  'APA-A-74562': {'pet_name': 'Dude',
#   'pet_age': 2.67,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Labrador / Boxer',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 4},
#  'APA-A-74607': {'pet_name': 'Flabbergasted',
#   'pet_age': 0.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Black Mouth Cur',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-74598': {'pet_name': 'Precious',
#   'pet_age': 2.08,
#   'pet_sex': 'Female',
#   'pet_breed': 'Black Mouth Cur',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 4},
#  'APA-A-24854': {'pet_name': 'Ravioli',
#   'pet_age': 5.5,
#   'pet_sex': 'Male',
#   'pet_breed': 'Shepherd / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 3,
#   'Child': 1,
#   'Home  Alone ': 4},
#  'APA-A-74632': {'pet_name': 'Moxi',
#   'pet_age': 2.25,
#   'pet_sex': 'Female',
#   'pet_breed': 'Chinese Shar-Pei / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-74633': {'pet_name': 'Chowder',
#   'pet_age': 2.0,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'Foster',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 3,
#   'Home  Alone ': 4},
#  'APA-A-74655': {'pet_name': 'Joker',
#   'pet_age': 3.17,
#   'pet_sex': 'Male',
#   'pet_breed': 'Mastiff / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 4},
#  'APA-A-51960': {'pet_name': 'Vickie',
#   'pet_age': 8.0,
#   'pet_sex': 'Female',
#   'pet_breed': 'Cattle Dog / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 4,
#   'Child': 2,
#   'Home  Alone ': 4},
#  'APA-A-74658': {'pet_name': 'Pepper',
#   'pet_age': 3.08,
#   'pet_sex': 'Female',
#   'pet_breed': 'Chihuahua',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 0,
#   'Child': 3,
#   'Home  Alone ': 4},
#  'APA-A-74659': {'pet_name': 'Sequoia',
#   'pet_age': 3.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier, Pit Bull',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-74684': {'pet_name': 'Falcon',
#   'pet_age': 2.58,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 3,
#   'Home  Alone ': 3},
#  'APA-A-74688': {'pet_name': 'Odin',
#   'pet_age': 2.17,
#   'pet_sex': 'Male',
#   'pet_breed': 'Hound, Plott',
#   'pet_location': 'Foster',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-74719': {'pet_name': 'Layla',
#   'pet_age': 8.67,
#   'pet_sex': 'Female',
#   'pet_breed': 'Chow Chow / Retriever, Labrador',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 0,
#   'Child': 3,
#   'Home  Alone ': 4},
#  'APA-A-71316': {'pet_name': 'Shorty',
#   'pet_age': 3.0,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, American Staffordshire',
#   'pet_location': 'Foster',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 4},
#  'APA-A-74799': {'pet_name': 'Blackie',
#   'pet_age': 0.08,
#   'pet_sex': 'Male',
#   'pet_breed': 'Chihuahua',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-74782': {'pet_name': 'Bolo Tie',
#   'pet_age': 0.25,
#   'pet_sex': 'Male',
#   'pet_breed': 'Shepherd, German / Mix',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-74800': {'pet_name': 'Black Diamond',
#   'pet_age': 0.08,
#   'pet_sex': 'Male',
#   'pet_breed': 'Chihuahua',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-74805': {'pet_name': 'Paco Taco',
#   'pet_age': 0.08,
#   'pet_sex': 'Male',
#   'pet_breed': 'Chihuahua / Mix',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-74806': {'pet_name': 'Bushes Beans',
#   'pet_age': 0.08,
#   'pet_sex': 'Male',
#   'pet_breed': 'Chihuahua / Mix',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-55509': {'pet_name': 'Mr. Fantastic',
#   'pet_age': 3.67,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, American Staffordshire / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 5},
#  'APA-A-74807': {'pet_name': 'Pablo Pablano',
#   'pet_age': 0.08,
#   'pet_sex': 'Male',
#   'pet_breed': 'Chihuahua / Mix',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-74808': {'pet_name': 'Elvis Parsley',
#   'pet_age': 0.08,
#   'pet_sex': 'Male',
#   'pet_breed': 'Chihuahua / Mix',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-74809': {'pet_name': 'Hamlett',
#   'pet_age': 0.08,
#   'pet_sex': 'Male',
#   'pet_breed': 'Chihuahua / Mix',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-74843': {'pet_name': 'Billy',
#   'pet_age': 4.25,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 4,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 4},
#  'APA-A-74844': {'pet_name': 'Jagger',
#   'pet_age': 4.08,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, American Pit Bull / Boxer',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 4},
#  'APA-A-74838': {'pet_name': 'Odette',
#   'pet_age': 10.08,
#   'pet_sex': 'Female',
#   'pet_breed': 'Chihuahua',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 3,
#   'Home  Alone ': 4},
#  'APA-A-74865': {'pet_name': 'Ben',
#   'pet_age': 6.5,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 0},
#  'APA-A-74899': {'pet_name': 'Chesney',
#   'pet_age': 6.08,
#   'pet_sex': 'Female',
#   'pet_breed': 'Retriever, Labrador',
#   'pet_location': 'Foster',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-74894': {'pet_name': 'Tinka',
#   'pet_age': 3.58,
#   'pet_sex': 'Female',
#   'pet_breed': 'Mastiff / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-45985': {'pet_name': 'Kent',
#   'pet_age': 7.83,
#   'pet_sex': 'Male',
#   'pet_breed': 'Cattle Dog, Australian (Blue Heeler) / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 2,
#   'Child': 3,
#   'Home  Alone ': 3},
#  'APA-A-43151': {'pet_name': 'Calab',
#   'pet_age': 3.08,
#   'pet_sex': 'Male',
#   'pet_breed': 'Chihuahua, Short Coat / Mix',
#   'pet_location': 'Tarrytown',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 3,
#   'Home  Alone ': 2},
#  'APA-A-65150': {'pet_name': 'Jason',
#   'pet_age': 4.75,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 2,
#   'Child': 1,
#   'Home  Alone ': 4},
#  'APA-A-75045': {'pet_name': 'Argus',
#   'pet_age': 0.83,
#   'pet_sex': 'Male',
#   'pet_breed': 'Mixed Breed (Medium)',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 3,
#   'Child': 0,
#   'Home  Alone ': 3},
#  'APA-A-75102': {'pet_name': 'Maggie Lab',
#   'pet_age': 13.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Retriever, Labrador / Chow Chow',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 0,
#   'Child': 4,
#   'Home  Alone ': 4},
#  'APA-A-75101': {'pet_name': 'Loma',
#   'pet_age': 10.08,
#   'pet_sex': 'Female',
#   'pet_breed': 'Boxer',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-70287': {'pet_name': 'Brixton',
#   'pet_age': 5.08,
#   'pet_sex': 'Male',
#   'pet_breed': 'Mastiff / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 4},
#  'APA-A-75142': {'pet_name': 'Pistachio',
#   'pet_age': 0.5,
#   'pet_sex': 'Female',
#   'pet_breed': 'Chihuahua',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-59131': {'pet_name': 'Opal',
#   'pet_age': 1.33,
#   'pet_sex': 'Female',
#   'pet_breed': 'Mastiff / Mix',
#   'pet_location': 'Foster',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 3,
#   'Home  Alone ': 2},
#  'APA-A-75160': {'pet_name': 'Hopi',
#   'pet_age': 0.17,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Black Labrador / Mix',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 3},
#  'APA-A-75173': {'pet_name': 'Shaylee',
#   'pet_age': 4.25,
#   'pet_sex': 'Female',
#   'pet_breed': 'Dachshund, Miniature Smooth Haired / Dachshund, Standard Smooth Haired',
#   'pet_location': 'Foster',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 3,
#   'Home  Alone ': 4},
#  'APA-A-41414': {'pet_name': 'Freddie',
#   'pet_age': 4.5,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 4},
#  'APA-A-75212': {'pet_name': 'Bumble bee',
#   'pet_age': 0.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier, Pit Bull',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-75247': {'pet_name': 'Bryant',
#   'pet_age': 1.0,
#   'pet_sex': 'Male',
#   'pet_breed': 'Collie, Border / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-75251': {'pet_name': 'Canelo',
#   'pet_age': 1.83,
#   'pet_sex': 'Male',
#   'pet_breed': 'Shepherd, German / Terrier, Pit Bull',
#   'pet_location': 'TLAC',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-75252': {'pet_name': 'Oso',
#   'pet_age': 2.17,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-74224': {'pet_name': 'Snax',
#   'pet_age': 2.08,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Cairn',
#   'pet_location': 'Foster',
#   'Dog': 5,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 5},
#  'APA-A-75250': {'pet_name': 'Stone',
#   'pet_age': 0.75,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Black Labrador / Terrier, Pit Bull',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 3},
#  'APA-A-75249': {'pet_name': 'Monet',
#   'pet_age': 1.58,
#   'pet_sex': 'Female',
#   'pet_breed': 'Hound, Plott',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 3,
#   'Home  Alone ': 3},
#  'APA-A-75295': {'pet_name': 'Kadeem',
#   'pet_age': 2.08,
#   'pet_sex': 'Male',
#   'pet_breed': 'Chihuahua / Mix',
#   'pet_location': 'Foster',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 3},
#  'APA-A-75292': {'pet_name': 'Willy Wonka',
#   'pet_age': 2.08,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 4},
#  'APA-A-48911': {'pet_name': 'Kylie',
#   'pet_age': 5.0,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 5},
#  'APA-A-12473': {'pet_name': 'Nellie',
#   'pet_age': 9.75,
#   'pet_sex': 'Female',
#   'pet_breed': 'Retriever, Labrador / Mix',
#   'pet_location': 'Foster',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-75363': {'pet_name': 'Einstein',
#   'pet_age': 13.58,
#   'pet_sex': 'Male',
#   'pet_breed': 'Poodle, Toy / Mix',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-75378': {'pet_name': 'Mike',
#   'pet_age': 1.75,
#   'pet_sex': 'Male',
#   'pet_breed': 'Pyrenees, Great / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 4,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 4},
#  'APA-A-75380': {'pet_name': 'Betsy',
#   'pet_age': 8.08,
#   'pet_sex': 'Female',
#   'pet_breed': 'Beagle / Chihuahua',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 3,
#   'Home  Alone ': 4},
#  'APA-A-75385': {'pet_name': 'Esther',
#   'pet_age': 5.58,
#   'pet_sex': 'Female',
#   'pet_breed': 'Shepherd, German / Mix',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 4},
#  'APA-A-75389': {'pet_name': 'Eva',
#   'pet_age': 3.08,
#   'pet_sex': 'Female',
#   'pet_breed': 'Mixed Breed (Medium)',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-75357': {'pet_name': 'Toast',
#   'pet_age': 3.5,
#   'pet_sex': 'Female',
#   'pet_breed': 'Cattle Dog / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 4},
#  'APA-A-75358': {'pet_name': 'Angelique',
#   'pet_age': 1.08,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-75417': {'pet_name': 'Raisin Bran',
#   'pet_age': 0.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Cattle Dog / Mix',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-75421': {'pet_name': 'Special K',
#   'pet_age': 2.08,
#   'pet_sex': 'Female',
#   'pet_breed': 'Cattle Dog / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 4},
#  'APA-A-75423': {'pet_name': 'Lucy',
#   'pet_age': 11.08,
#   'pet_sex': 'Female',
#   'pet_breed': 'Malinois, Belgian',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 1,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-75435': {'pet_name': 'Hermione Granger',
#   'pet_age': 0.08,
#   'pet_sex': 'Female',
#   'pet_breed': 'Retriever, Yellow Labrador / American Blue Heeler',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-75460': {'pet_name': 'Goldilocks',
#   'pet_age': 0.33,
#   'pet_sex': 'Female',
#   'pet_breed': 'Retriever, Golden / Mix',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-75438': {'pet_name': 'Draco Malfoy',
#   'pet_age': 0.08,
#   'pet_sex': 'Unknown',
#   'pet_breed': 'Retriever, Yellow Labrador / American Blue Heeler',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-75433': {'pet_name': 'Danny',
#   'pet_age': 2.58,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Labrador / Mix',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 0,
#   'Child': 4,
#   'Home  Alone ': 0},
#  'APA-A-75439': {'pet_name': 'Professor Severus Snape',
#   'pet_age': 0.08,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Yellow Labrador / American Blue Heeler',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-75440': {'pet_name': 'Luna Lovegood',
#   'pet_age': 0.08,
#   'pet_sex': 'Female',
# ...
#   'pet_sex': 'Male',
#   'pet_breed': 'Collie, Border / Retriever, Labrador',
#   'pet_location': 'TLAC',
#   'Dog': 0,
#   'Cat': 2,
#   'Child': 1,
#   'Home  Alone ': 5},
#  'APA-A-32374': {'pet_name': 'Cane',
#   'pet_age': 7.33,
#   'pet_sex': 'Male',
#   'pet_breed': 'Chinese Shar-Pei / Bulldog, American',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 5},
#  'APA-A-75915': {'pet_name': 'Misterio',
#   'pet_age': 4.0,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-61182': {'pet_name': 'King Triton',
#   'pet_age': 4.17,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Chocolate Labrador / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 3},
#  'APA-A-75934': {'pet_name': 'Ri',
#   'pet_age': 4.33,
#   'pet_sex': 'Female',
#   'pet_breed': 'Retriever, Labrador / Mix',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-75935': {'pet_name': 'Kazmo',
#   'pet_age': 10.83,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Rat',
#   'pet_location': 'Tarrytown',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-75936': {'pet_name': 'Genevieve',
#   'pet_age': 3.0,
#   'pet_sex': 'Female',
#   'pet_breed': 'Chihuahua',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-75939': {'pet_name': 'Salsa',
#   'pet_age': 3.0,
#   'pet_sex': 'Female',
#   'pet_breed': 'Chihuahua / Mix',
#   'pet_location': 'Tarrytown',
#   'Dog': 4,
#   'Cat': 3,
#   'Child': 3,
#   'Home  Alone ': 4},
#  'APA-A-75947': {'pet_name': 'Cayde',
#   'pet_age': 1.17,
#   'pet_sex': 'Male',
#   'pet_breed': 'Cattle Dog, Australian (Red Heeler) / Basenji',
#   'pet_location': 'TLAC',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-75941': {'pet_name': 'Baby',
#   'pet_age': 3.0,
#   'pet_sex': 'Female',
#   'pet_breed': 'American Blue Heeler / Mix',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-75940': {'pet_name': 'Emarosa',
#   'pet_age': 1.0,
#   'pet_sex': 'Female',
#   'pet_breed': 'Shepherd, German / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-75958': {'pet_name': 'Lulu',
#   'pet_age': 5.58,
#   'pet_sex': 'Female',
#   'pet_breed': 'Shepherd, German / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-70081': {'pet_name': 'Prada',
#   'pet_age': 3.58,
#   'pet_sex': 'Female',
#   'pet_breed': 'Catahoula Leopard Dog / Shepherd, German',
#   'pet_location': 'Foster',
#   'Dog': 3,
#   'Cat': 2,
#   'Child': 4,
#   'Home  Alone ': 4},
#  'APA-A-75989': {'pet_name': 'Grizzly',
#   'pet_age': 9.0,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Chocolate Labrador',
#   'pet_location': 'TLAC',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 4,
#   'Home  Alone ': 0},
#  'APA-A-75987': {'pet_name': 'Potato Ole',
#   'pet_age': 10.0,
#   'pet_sex': 'Male',
#   'pet_breed': 'Chihuahua / Mix',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-72847': {'pet_name': 'Griggs',
#   'pet_age': 2.33,
#   'pet_sex': 'Male',
#   'pet_breed': 'Hound / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 4,
#   'Child': 4,
#   'Home  Alone ': 4},
#  'APA-A-75981': {'pet_name': 'Jackson',
#   'pet_age': 3.17,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Labrador / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 4},
#  'APA-A-75985': {'pet_name': 'AJ',
#   'pet_age': 10.0,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Labrador / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-75983': {'pet_name': 'Opie',
#   'pet_age': 2.0,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Retriever, Labrador',
#   'pet_location': 'TLAC',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-75992': {'pet_name': 'Nala',
#   'pet_age': 2.0,
#   'pet_sex': 'Female',
#   'pet_breed': 'Retriever, Black Labrador',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-75991': {'pet_name': 'Buford',
#   'pet_age': 7.0,
#   'pet_sex': 'Male',
#   'pet_breed': 'Hound',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-75993': {'pet_name': 'Honey',
#   'pet_age': 4.0,
#   'pet_sex': 'Female',
#   'pet_breed': 'Hound / Mix',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-5344': {'pet_name': 'Izzy',
#   'pet_age': 10.08,
#   'pet_sex': 'Female',
#   'pet_breed': 'Shepherd / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 5},
#  'APA-A-76022': {'pet_name': 'Jermaine',
#   'pet_age': 0.33,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-76023': {'pet_name': 'Jackie',
#   'pet_age': 0.33,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-76024': {'pet_name': 'Randy',
#   'pet_age': 0.33,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-76025': {'pet_name': 'Tito',
#   'pet_age': 0.33,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-76056': {'pet_name': 'Freddie Mercury',
#   'pet_age': 1.0,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-76045': {'pet_name': 'Eren',
#   'pet_age': 1.42,
#   'pet_sex': 'Male',
#   'pet_breed': 'Shepherd, Australian',
#   'pet_location': 'TLAC',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-75482': {'pet_name': 'India Opal',
#   'pet_age': 1.08,
#   'pet_sex': 'Female',
#   'pet_breed': 'Blue Lacy / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-71024': {'pet_name': 'Oli Sykes',
#   'pet_age': 3.67,
#   'pet_sex': 'Male',
#   'pet_breed': 'Mixed Breed (Medium) / Mixed Breed (Medium)',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 3,
#   'Child': 0,
#   'Home  Alone ': 4},
#  'APA-A-76047': {'pet_name': 'Frank Sinatra',
#   'pet_age': 1.0,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull',
#   'pet_location': 'TLAC',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-76040': {'pet_name': 'Hunter',
#   'pet_age': 0.33,
#   'pet_sex': 'Male',
#   'pet_breed': 'Pointer / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-76046': {'pet_name': 'Jupiter',
#   'pet_age': 4.0,
#   'pet_sex': 'Male',
#   'pet_breed': 'Shepherd, German / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-76096': {'pet_name': 'Carly',
#   'pet_age': 0.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier, Pit Bull',
#   'pet_location': 'TLAC',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-76063': {'pet_name': 'Rocko',
#   'pet_age': 1.5,
#   'pet_sex': 'Male',
#   'pet_breed': 'Rottweiler',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 3},
#  'APA-A-56883': {'pet_name': 'Paz',
#   'pet_age': 1.58,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 4},
#  'APA-A-76111': {'pet_name': 'Callie',
#   'pet_age': 0.42,
#   'pet_sex': 'Female',
#   'pet_breed': 'Shepherd, German / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-76103': {'pet_name': 'Tango',
#   'pet_age': 0.17,
#   'pet_sex': 'Male',
#   'pet_breed': 'Dachshund / Terrier',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-76104': {'pet_name': 'Barker',
#   'pet_age': 0.17,
#   'pet_sex': 'Male',
#   'pet_breed': 'Dachshund / Terrier',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-40179': {'pet_name': 'Rufus',
#   'pet_age': 5.75,
#   'pet_sex': 'Male',
#   'pet_breed': 'Mixed Breed (Medium) / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 2,
#   'Child': 1,
#   'Home  Alone ': 5},
#  'APA-A-76105': {'pet_name': 'Stump',
#   'pet_age': 0.17,
#   'pet_sex': 'Male',
#   'pet_breed': 'Dachshund / Terrier',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-76039': {'pet_name': 'Jiggy',
#   'pet_age': 7.0,
#   'pet_sex': 'Male',
#   'pet_breed': 'Chihuahua / Mix',
#   'pet_location': 'Tarrytown',
#   'Dog': 4,
#   'Cat': 0,
#   'Child': 3,
#   'Home  Alone ': 3},
#  'APA-A-76106': {'pet_name': 'Reese',
#   'pet_age': 0.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Dachshund / Terrier',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-76108': {'pet_name': 'Lavigne',
#   'pet_age': 0.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Dachshund / Terrier',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-76109': {'pet_name': 'Jett',
#   'pet_age': 0.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Dachshund / Terrier',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-53573': {'pet_name': 'Mary Pitt',
#   'pet_age': 2.33,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 3,
#   'Child': 2,
#   'Home  Alone ': 5},
#  'APA-A-76110': {'pet_name': 'Foxy',
#   'pet_age': 0.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Dachshund / Terrier',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-76133': {'pet_name': 'Roxanne',
#   'pet_age': 1.58,
#   'pet_sex': 'Female',
#   'pet_breed': 'Catahoula Leopard Dog / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-76126': {'pet_name': 'Shaamus',
#   'pet_age': 5.5,
#   'pet_sex': 'Male',
#   'pet_breed': 'Cattle Dog / Mix',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 3,
#   'Home  Alone ': 4},
#  'APA-A-76128': {'pet_name': 'Casper',
#   'pet_age': 0.42,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Labrador / Mix',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-74381': {'pet_name': 'Missy',
#   'pet_age': 0.33,
#   'pet_sex': 'Female',
#   'pet_breed': 'Cattle Dog, Australian (Red Heeler)',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-76129': {'pet_name': 'JFK',
#   'pet_age': 7.83,
#   'pet_sex': 'Male',
#   'pet_breed': 'Mixed Breed (Small)',
#   'pet_location': 'Tarrytown',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 3,
#   'Home  Alone ': 3},
#  'APA-A-76131': {'pet_name': 'Security',
#   'pet_age': 7.25,
#   'pet_sex': 'Male',
#   'pet_breed': 'Chihuahua / Mix',
#   'pet_location': 'Tarrytown',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 0},
#  'APA-A-76127': {'pet_name': 'Smile',
#   'pet_age': 3.58,
#   'pet_sex': 'Female',
#   'pet_breed': 'Black Mouth Cur / Mix',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-76148': {'pet_name': 'Delilah',
#   'pet_age': 0.58,
#   'pet_sex': 'Female',
#   'pet_breed': 'Shepherd / Chinese Shar-Pei',
#   'pet_location': 'TLAC',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-76146': {'pet_name': 'Phyllis',
#   'pet_age': 7.0,
#   'pet_sex': 'Female',
#   'pet_breed': 'Chihuahua / Mix',
#   'pet_location': 'Tarrytown',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-76151': {'pet_name': 'Cota',
#   'pet_age': 2.0,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Labrador / Pyrenees, Great',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-76153': {'pet_name': 'Duchess',
#   'pet_age': 0.5,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-76152': {'pet_name': 'Tyler',
#   'pet_age': 2.0,
#   'pet_sex': 'Male',
#   'pet_breed': 'Cattle Dog, Australian (Red Heeler) / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-27139': {'pet_name': 'Azra',
#   'pet_age': 5.5,
#   'pet_sex': 'Female',
#   'pet_breed': 'Hound, Plott / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 0,
#   'Child': 4,
#   'Home  Alone ': 5},
#  'APA-A-76157': {'pet_name': 'Casablanca',
#   'pet_age': 0.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Mixed Breed (Medium)',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-76159': {'pet_name': 'Vertigo',
#   'pet_age': 0.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Mixed Breed (Medium)',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-76160': {'pet_name': 'The Wiz',
#   'pet_age': 0.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Mixed Breed (Medium)',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-76161': {'pet_name': 'Nosferatu',
#   'pet_age': 0.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Mixed Breed (Medium)',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-76178': {'pet_name': 'Maggie Shepherd',
#   'pet_age': 6.0,
#   'pet_sex': 'Female',
#   'pet_breed': 'Shepherd / Mixed Breed (Medium)',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-76156': {'pet_name': 'Mockingbird',
#   'pet_age': 0.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Mixed Breed (Medium)',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-76158': {'pet_name': 'Jaws',
#   'pet_age': 0.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Mixed Breed (Medium)',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-76184': {'pet_name': 'Ted',
#   'pet_age': 10.0,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Rat / Chihuahua',
#   'pet_location': 'Tarrytown',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-76183': {'pet_name': 'Allie',
#   'pet_age': 6.67,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-76187': {'pet_name': 'Eloise',
#   'pet_age': 0.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Pointer / Retriever, Black Labrador',
#   'pet_location': 'TLAC',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-76226': {'pet_name': 'Highland',
#   'pet_age': 0.33,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Labrador',
#   'pet_location': 'TLAC',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-76225': {'pet_name': 'Caroline',
#   'pet_age': 0.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Coonhound, English / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-76224': {'pet_name': 'Chanel',
#   'pet_age': 1.5,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-76227': {'pet_name': 'Little Sarah',
#   'pet_age': 0.33,
#   'pet_sex': 'Female',
#   'pet_breed': 'Hound / Mix',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2},
#  'APA-A-76245': {'pet_name': 'Buster Brown',
#   'pet_age': 3.0,
#   'pet_sex': 'Male',
#   'pet_breed': 'Boxer / Mix',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0},
#  'APA-A-76250': {'pet_name': 'Joe',
#   'pet_age': 6.0,
#   'pet_sex': 'Male',
#   'pet_breed': 'Mastiff',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0}}

# %%
#Get the number of entries
len(apa_data)
# Out:
# 362

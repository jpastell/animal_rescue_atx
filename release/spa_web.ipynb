# %%
#Importing modules
import os
from bs4 import BeautifulSoup
import requests
from splinter import Browser
import pandas as pd
import pymongo

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
# Define database and collection
db = client.pets_db
collection = db.items

# %% [markdown]
# ### Function definition

# %%
def get_pages_count(soup):
    '''
    Return the number of pages to visit for APA that contain dog information
    
    Params: soup --> BeautifulSoup object
    
    Return: pet_entry --> number of pages to iterate
    '''
    #Get the pagination division
    pagination = soup.find('div', class_='pagination')
    pages = list()
    for page in pagination.find_all('a',class_='page'):
        pages.append(page.text)
    return(int(pages[-1]))

# %%
def get_pet_info_by_url(soup):
    '''
    Parse the dog information into a dictionary to append to Mongo DB
    
    Params: soup --> BeautifulSoup object
    
    Return: pet_entry --> dictionary will all pat information
    '''
    #Main dictionary that will hold the data base entry
    pet_entry = list()
    # Get all dog information
    all_dogs_per_page = soup.find_all('div', class_='large-tile')
    #Parse teh data
    for dog in all_dogs_per_page:
        #Dictonary used to store the data
        pet_data = dict()
        #Get the text based information
        #[-] Name
        pet_name = dog.find('h3').find('a').text
        #[-] Id
        pet_id = dog.find('h6').text
        #[-] Listed information : Age, Sex, Breed
        pet_info = dog.find('ul').find_all("li")
        #[--] Age , index 0
        age_data = pet_info[0].text.split('Months')[0].split('Years')
        #Conver the age in fraction of years
        pet_age = round(int(age_data[0].strip()) + (int(age_data[1].strip()) /12.0),2)
        #[--] Sex , index 1
        pet_sex = pet_info[1].text
        #[--] Breed , index 2
        pet_breed = pet_info[2].text
        #Build the data into the dictionary
        #Get the pet dtats , we need to translate from stars to numbers
        pet_location = pet_info[3].text
        pet_data.update({'pet_name':pet_name})
        pet_data.update({'pet_age':pet_age})
        pet_data.update({'pet_sex':pet_sex})
        pet_data.update({'pet_breed':pet_breed})
        pet_data.update({'pet_location':pet_location})
        #Count the starts to get the data
        possible_stat_list = dog.find_all('div',class_='stats-panel')
        for possible_stat in possible_stat_list:
            stat = possible_stat.find_all('div',class_='flex')
            for category in stat:
                category_name = category.find('span',class_='stats-text').text
                category_score = 0
                stars = category.find_all('img')
                for star in stars:
                    if('star full' == star['alt']):
                         category_score += 1
                #Update the dictionary for each stat
                pet_data.update({category_name:category_score})
        pet_data.update({"pet_id":pet_id})
        #Update the main dictionary with the ID as main key and return
        #pet_entry.append({pet_id:pet_data})
        pet_entry.append(pet_data)
        #print(pet_entry)
    return pet_entry

# %%
def get_all_apa_data():
    '''
    Parse all dog information for APA dogs
    
    Params: None
    
    Return: pet_entry --> dictionary with the information
    '''
    #main page for DOG adoption APA
    main_url = url = 'https://www.austinpetsalive.org/adopt/dogs'
    #Base url to add the page to scrape
    bas_url_4_page = 'https://www.austinpetsalive.org/adopt/dogs/p'
    #Dictionary used to store all the data scraped
    pet_data = list()
    #create the browser object
    executable_path = {'executable_path': 'chromedriver'}
    browser = Browser('chrome', **executable_path, headless=False)
    #Create the defult list of URLs to vist and add the first page
    url_list = list(main_url)
    #Visit the main page to collect number of pages and the first data scrape
    browser.visit(main_url)
    # Create BeautifulSoup object; parse with 'html.parser'
    soup = BeautifulSoup(browser.html, 'html.parser')
    #Get the number fo pages to scrape besides the main one
    total_pages = get_pages_count(soup)
    #Update the data of the main entry page
    pet_data = pet_data + get_pet_info_by_url(soup)
    #Iterate over the next pages to get the complete data, we start in 2 bacause
    #index 1 is the pain page
    for page_idx in range(2,total_pages+1):
        #Build the new page
        page_url = bas_url_4_page + str(page_idx)
        #Visit the new page
        browser.visit(page_url)
        #parse teh data
        soup = BeautifulSoup(browser.html, 'html.parser')
        #Update the information
        pet_data = pet_data +get_pet_info_by_url(soup)
    #Clos ethe browser
    browser.quit()
    return pet_data

# %% [markdown]
# ###  Scrape the data

# %%
#Get the information
apa_data = get_all_apa_data()

# %%
#Display the information
apa_data
# Out:
# [{'pet_name': 'Sparky',
#   'pet_age': 6.5,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'Foster',
#   'Dog': 1,
#   'Cat': 1,
#   'Child': 2,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-36615'},
#  {'pet_name': 'Rio',
#   'pet_age': 3.75,
#   'pet_sex': 'Male',
#   'pet_breed': 'Mixed Breed (Large) / Great Dane',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 5,
#   'pet_id': 'APA-A-45785'},
#  {'pet_name': 'Twister',
#   'pet_age': 5.67,
#   'pet_sex': 'Male',
#   'pet_breed': 'Shepherd, Anatolian / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 2,
#   'Child': 1,
#   'Home  Alone ': 5,
#   'pet_id': 'APA-A-47726'},
#  {'pet_name': 'Beryl',
#   'pet_age': 6.58,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Yellow Labrador / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 2,
#   'Child': 1,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-49698'},
#  {'pet_name': 'Brindle',
#   'pet_age': 5.5,
#   'pet_sex': 'Male',
#   'pet_breed': 'Hound / Hound',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 2,
#   'Child': 1,
#   'Home  Alone ': 5,
#   'pet_id': 'APA-A-43905'},
#  {'pet_name': 'Ziggy',
#   'pet_age': 4.42,
#   'pet_sex': 'Male',
#   'pet_breed': 'Hound / Mix',
#   'pet_location': 'Foster',
#   'Dog': 1,
#   'Cat': 3,
#   'Child': 1,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-35188'},
#  {'pet_name': 'Grayson',
#   'pet_age': 4.0,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Labrador / Mix',
#   'pet_location': 'Foster',
#   'Dog': 1,
#   'Cat': 0,
#   'Child': 3,
#   'Home  Alone ': 5,
#   'pet_id': 'APA-A-53121'},
#  {'pet_name': 'Ludwig',
#   'pet_age': 6.67,
#   'pet_sex': 'Male',
#   'pet_breed': 'Bernese Mountain Dog / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 3,
#   'pet_id': 'APA-A-53740'},
#  {'pet_name': 'Vegas',
#   'pet_age': 5.83,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'Foster',
#   'Dog': 1,
#   'Cat': 2,
#   'Child': 1,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-54604'},
#  {'pet_name': 'June Bug',
#   'pet_age': 5.92,
#   'pet_sex': 'Female',
#   'pet_breed': 'Retriever, Labrador / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 4,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-54851'},
#  {'pet_name': 'Rocco',
#   'pet_age': 4.75,
#   'pet_sex': 'Male',
#   'pet_breed': 'Catahoula Leopard Dog / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 2,
#   'Child': 1,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-37564'},
#  {'pet_name': 'Jake Ryan',
#   'pet_age': 6.83,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Labrador / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 1,
#   'Child': 1,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-55056'},
#  {'pet_name': 'Brooks',
#   'pet_age': 7.92,
#   'pet_sex': 'Male',
#   'pet_breed': 'Mixed Breed (Medium) / Mix',
#   'pet_location': 'Foster',
#   'Dog': 1,
#   'Cat': 1,
#   'Child': 2,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-55237'},
#  {'pet_name': 'Schone',
#   'pet_age': 10.25,
#   'pet_sex': 'Female',
#   'pet_breed': 'Retriever, Black Labrador',
#   'pet_location': 'Foster',
#   'Dog': 1,
#   'Cat': 3,
#   'Child': 4,
#   'Home  Alone ': 3,
#   'pet_id': 'APA-A-55491'},
#  {'pet_name': 'Monty',
#   'pet_age': 4.42,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'Foster',
#   'Dog': 1,
#   'Cat': 1,
#   'Child': 2,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-40017'},
#  {'pet_name': 'Nike',
#   'pet_age': 9.0,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Labrador / Mix',
#   'pet_location': 'Foster',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 5,
#   'pet_id': 'APA-A-36893'},
#  {'pet_name': 'Bob Barker',
#   'pet_age': 6.5,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever / Mixed Breed (Large)',
#   'pet_location': 'Foster',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 3,
#   'pet_id': 'APA-A-57113'},
#  {'pet_name': 'Bethany',
#   'pet_age': 9.83,
#   'pet_sex': 'Female',
#   'pet_breed': 'Retriever, Black Labrador / Mix',
#   'pet_location': 'Foster',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-57449'},
#  {'pet_name': 'Jasmine',
#   'pet_age': 5.08,
#   'pet_sex': 'Female',
#   'pet_breed': 'Retriever, Black Labrador / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 1,
#   'Child': 1,
#   'Home  Alone ': 5,
#   'pet_id': 'APA-A-53450'},
#  {'pet_name': 'Manning',
#   'pet_age': 4.33,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Labrador / Shepherd, German',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 3,
#   'pet_id': 'APA-A-58608'},
#  {'pet_name': 'Benito',
#   'pet_age': 4.67,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'Foster',
#   'Dog': 1,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 5,
#   'pet_id': 'APA-A-59189'},
#  {'pet_name': 'Princeton',
#   'pet_age': 7.42,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 4,
#   'Child': 1,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-59431'},
#  {'pet_name': 'Cricket',
#   'pet_age': 7.92,
#   'pet_sex': 'Female',
#   'pet_breed': 'Retriever, Labrador / Mix',
#   'pet_location': 'Foster',
#   'Dog': 2,
#   'Cat': 2,
#   'Child': 3,
#   'Home  Alone ': 3,
#   'pet_id': 'APA-A-55345'},
#  {'pet_name': 'Toro',
#   'pet_age': 6.83,
#   'pet_sex': 'Male',
#   'pet_breed': 'Mixed Breed (Large) / Mix',
#   'pet_location': 'Foster',
#   'Dog': 2,
#   'Cat': 2,
#   'Child': 2,
#   'Home  Alone ': 3,
#   'pet_id': 'APA-A-60553'},
#  {'pet_name': 'Sally',
#   'pet_age': 3.67,
#   'pet_sex': 'Female',
#   'pet_breed': 'Mixed Breed (Medium)',
#   'pet_location': 'Foster',
#   'Dog': 2,
#   'Cat': 2,
#   'Child': 2,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-61252'},
#  {'pet_name': 'Migos',
#   'pet_age': 5.83,
#   'pet_sex': 'Male',
#   'pet_breed': 'Mixed Breed (Medium)',
#   'pet_location': 'Foster',
#   'Dog': 2,
#   'Cat': 2,
#   'Child': 3,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-56868'},
#  {'pet_name': 'Josie',
#   'pet_age': 4.67,
#   'pet_sex': 'Female',
#   'pet_breed': 'Retriever / Mix',
#   'pet_location': 'Foster',
#   'Dog': 2,
#   'Cat': 1,
#   'Child': 1,
#   'Home  Alone ': 5,
#   'pet_id': 'APA-A-30844'},
#  {'pet_name': 'Kline',
#   'pet_age': 2.67,
#   'pet_sex': 'Male',
#   'pet_breed': 'Cattle Dog / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 2,
#   'Child': 3,
#   'Home  Alone ': 3,
#   'pet_id': 'APA-A-61501'},
#  {'pet_name': 'Miguelito',
#   'pet_age': 8.08,
#   'pet_sex': 'Male',
#   'pet_breed': 'Chihuahua',
#   'pet_location': 'Tarrytown',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-62339'},
#  {'pet_name': 'Tom Hanks',
#   'pet_age': 6.17,
#   'pet_sex': 'Male',
#   'pet_breed': 'Mixed Breed (Medium) / Mix',
#   'pet_location': 'Foster',
#   'Dog': 1,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-62575'},
#  {'pet_name': 'Floppy',
#   'pet_age': 4.83,
#   'pet_sex': 'Male',
#   'pet_breed': 'Mixed Breed (Medium)',
#   'pet_location': 'Foster',
#   'Dog': 1,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-55843'},
#  {'pet_name': 'Jenga',
#   'pet_age': 4.08,
#   'pet_sex': 'Female',
#   'pet_breed': 'Bulldog, American / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 2,
#   'Child': 2,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-64409'},
#  {'pet_name': 'Brady',
#   'pet_age': 11.0,
#   'pet_sex': 'Male',
#   'pet_breed': 'Mixed Breed (Medium) / Mix',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 1,
#   'Child': 4,
#   'Home  Alone ': 3,
#   'pet_id': 'APA-A-64403'},
#  {'pet_name': 'Mr Marbles',
#   'pet_age': 6.25,
#   'pet_sex': 'Male',
#   'pet_breed': 'Mixed Breed (Large)',
#   'pet_location': 'Foster',
#   'Dog': 1,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 5,
#   'pet_id': 'APA-A-64524'},
#  {'pet_name': 'Midnight',
#   'pet_age': 4.08,
#   'pet_sex': 'Female',
#   'pet_breed': 'Retriever, Black Labrador / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 1,
#   'Child': 2,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-64567'},
#  {'pet_name': 'Clark',
#   'pet_age': 8.33,
#   'pet_sex': 'Male',
#   'pet_breed': 'Boxer / Mixed Breed (Medium)',
#   'pet_location': 'Foster',
#   'Dog': 2,
#   'Cat': 3,
#   'Child': 1,
#   'Home  Alone ': 5,
#   'pet_id': 'APA-A-41503'},
#  {'pet_name': 'Calvin',
#   'pet_age': 3.83,
#   'pet_sex': 'Male',
#   'pet_breed': 'Coonhound, Redbone / Mix',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 2,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-38221'},
#  {'pet_name': 'El Jefe',
#   'pet_age': 4.25,
#   'pet_sex': 'Male',
#   'pet_breed': 'Boxer / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-49870'},
#  {'pet_name': 'Brenda',
#   'pet_age': 7.08,
#   'pet_sex': 'Female',
#   'pet_breed': 'Dachshund / Mix',
#   'pet_location': 'Foster',
#   'Dog': 3,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 3,
#   'pet_id': 'APA-A-46986'},
#  {'pet_name': 'Sarah',
#   'pet_age': 5.83,
#   'pet_sex': 'Female',
#   'pet_breed': 'Mixed Breed (Medium) / Mix',
#   'pet_location': 'Foster',
#   'Dog': 1,
#   'Cat': 2,
#   'Child': 2,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-65267'},
#  {'pet_name': 'Button',
#   'pet_age': 3.17,
#   'pet_sex': 'Male',
#   'pet_breed': 'Mixed Breed (Medium) / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-57999'},
#  {'pet_name': 'Sailor',
#   'pet_age': 3.33,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 2,
#   'Child': 3,
#   'Home  Alone ': 5,
#   'pet_id': 'APA-A-55076'},
#  {'pet_name': 'Rhino',
#   'pet_age': 3.83,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'Foster',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 5,
#   'pet_id': 'APA-A-59055'},
#  {'pet_name': 'Tutu',
#   'pet_age': 5.67,
#   'pet_sex': 'Female',
#   'pet_breed': 'Mixed Breed (Medium) / Boxer',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 1,
#   'pet_id': 'APA-A-38419'},
#  {'pet_name': 'Churchill',
#   'pet_age': 3.83,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 0,
#   'Child': 4,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-66283'},
#  {'pet_name': 'John Rambo',
#   'pet_age': 4.33,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Labrador / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-55384'},
#  {'pet_name': 'Lennon',
#   'pet_age': 4.75,
#   'pet_sex': 'Male',
#   'pet_breed': 'Shepherd, German / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 1,
#   'Child': 1,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-62493'},
#  {'pet_name': 'Mercedes',
#   'pet_age': 3.25,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 2,
#   'Child': 2,
#   'Home  Alone ': 5,
#   'pet_id': 'APA-A-50261'},
#  {'pet_name': 'Bel-air',
#   'pet_age': 2.08,
#   'pet_sex': 'Male',
#   'pet_breed': 'Mixed Breed (Medium) / Mix',
#   'pet_location': 'Foster',
#   'Dog': 3,
#   'Cat': 2,
#   'Child': 2,
#   'Home  Alone ': 5,
#   'pet_id': 'APA-A-50976'},
#  {'pet_name': 'Albus',
#   'pet_age': 4.83,
#   'pet_sex': 'Male',
#   'pet_breed': 'Mixed Breed (Large) / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-66640'},
#  {'pet_name': 'Goldman',
#   'pet_age': 3.0,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Yellow Labrador / Mixed Breed (Medium)',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-66661'},
#  {'pet_name': 'Nokie',
#   'pet_age': 8.25,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier, American Staffordshire / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 2,
#   'Child': 2,
#   'Home  Alone ': 5,
#   'pet_id': 'APA-A-45661'},
#  {'pet_name': 'Mack',
#   'pet_age': 7.75,
#   'pet_sex': 'Male',
#   'pet_breed': 'Mixed Breed (Medium)',
#   'pet_location': 'Foster',
#   'Dog': 1,
#   'Cat': 3,
#   'Child': 2,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-36999'},
#  {'pet_name': 'Minka',
#   'pet_age': 7.25,
#   'pet_sex': 'Female',
#   'pet_breed': 'Mixed Breed (Medium) / Mix',
#   'pet_location': 'Foster',
#   'Dog': 2,
#   'Cat': 1,
#   'Child': 1,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-49408'},
#  {'pet_name': 'Fun Guy',
#   'pet_age': 4.83,
#   'pet_sex': 'Male',
#   'pet_breed': 'Chihuahua, Short Coat / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 2,
#   'Child': 1,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-31118'},
#  {'pet_name': 'Lee',
#   'pet_age': 2.75,
#   'pet_sex': 'Male',
#   'pet_breed': 'Hound, Pharaoh / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 3,
#   'pet_id': 'APA-A-69626'},
#  {'pet_name': 'Osito',
#   'pet_age': 3.83,
#   'pet_sex': 'Male',
#   'pet_breed': 'Chihuahua / Terrier',
#   'pet_location': 'Tarrytown',
#   'Dog': 3,
#   'Cat': 3,
#   'Child': 2,
#   'Home  Alone ': 5,
#   'pet_id': 'APA-A-56036'},
#  {'pet_name': 'Trigger',
#   'pet_age': 3.75,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Chocolate Labrador / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-69663'},
#  {'pet_name': 'Otis',
#   'pet_age': 3.67,
#   'pet_sex': 'Male',
#   'pet_breed': 'Akita / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-69717'},
#  {'pet_name': 'Spot',
#   'pet_age': 6.17,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Bulldog, American',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 3,
#   'Child': 2,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-55324'},
#  {'pet_name': 'Cashew',
#   'pet_age': 2.0,
#   'pet_sex': 'Female',
#   'pet_breed': 'Basenji',
#   'pet_location': 'Foster',
#   'Dog': 2,
#   'Cat': 4,
#   'Child': 2,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-70116'},
#  {'pet_name': 'Mondo',
#   'pet_age': 6.83,
#   'pet_sex': 'Male',
#   'pet_breed': 'Hound / Mix',
#   'pet_location': 'Foster',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 3,
#   'pet_id': 'APA-A-45387'},
#  {'pet_name': 'Juanita',
#   'pet_age': 3.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Mixed Breed (Medium)',
#   'pet_location': 'Foster',
#   'Dog': 1,
#   'Cat': 1,
#   'Child': 2,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-50809'},
#  {'pet_name': 'Dennis',
#   'pet_age': 10.67,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Labrador / Mix',
#   'pet_location': 'Foster',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 5,
#   'pet_id': 'APA-A-25593'},
#  {'pet_name': 'Rustler',
#   'pet_age': 6.58,
#   'pet_sex': 'Male',
#   'pet_breed': 'Mixed Breed (Medium) / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 1,
#   'Child': 2,
#   'Home  Alone ': 3,
#   'pet_id': 'APA-A-46692'},
#  {'pet_name': 'Tommy',
#   'pet_age': 4.42,
#   'pet_sex': 'Male',
#   'pet_breed': 'Greyhound / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 3,
#   'pet_id': 'APA-A-33573'},
#  {'pet_name': 'Van Gogh',
#   'pet_age': 1.83,
#   'pet_sex': 'Male',
#   'pet_breed': 'Cattle Dog, Australian (Blue Heeler) / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 2,
#   'Child': 2,
#   'Home  Alone ': 3,
#   'pet_id': 'APA-A-66855'},
#  {'pet_name': 'Queen Brenda',
#   'pet_age': 3.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Malinois, Belgian',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-69494'},
#  {'pet_name': 'Pinocchio',
#   'pet_age': 7.08,
#   'pet_sex': 'Male',
#   'pet_breed': 'Great Dane / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 3,
#   'pet_id': 'APA-A-37920'},
#  {'pet_name': 'Gelato',
#   'pet_age': 3.75,
#   'pet_sex': 'Male',
#   'pet_breed': 'Mixed Breed (Medium) / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 2,
#   'Child': 3,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-56161'},
#  {'pet_name': 'Sullivan',
#   'pet_age': 2.5,
#   'pet_sex': 'Male',
#   'pet_breed': 'Shepherd, Anatolian / Chow Chow',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-70891'},
#  {'pet_name': 'Alejandro',
#   'pet_age': 2.83,
#   'pet_sex': 'Male',
#   'pet_breed': 'Shepherd, German / Retriever, Labrador',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 3,
#   'pet_id': 'APA-A-71075'},
#  {'pet_name': 'Stella',
#   'pet_age': 2.58,
#   'pet_sex': 'Female',
#   'pet_breed': 'Mixed Breed (Medium) / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-50901'},
#  {'pet_name': 'Dino',
#   'pet_age': 6.67,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-20065'},
#  {'pet_name': 'Rousseau',
#   'pet_age': 3.67,
#   'pet_sex': 'Female',
#   'pet_breed': 'Coonhound, Bluetick / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 0,
#   'Child': 3,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-37585'},
#  {'pet_name': 'Raphael',
#   'pet_age': 5.17,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, American Staffordshire / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-71317'},
#  {'pet_name': 'Pumpkin',
#   'pet_age': 5.92,
#   'pet_sex': 'Female',
#   'pet_breed': 'Hound / Mix',
#   'pet_location': 'Foster',
#   'Dog': 2,
#   'Cat': 3,
#   'Child': 2,
#   'Home  Alone ': 3,
#   'pet_id': 'APA-A-71312'},
#  {'pet_name': 'Mike Jonze',
#   'pet_age': 1.67,
#   'pet_sex': 'Male',
#   'pet_breed': 'Shepherd, German / Mix',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 2,
#   'Child': 2,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-55862'},
#  {'pet_name': 'Dreamboat',
#   'pet_age': 1.42,
#   'pet_sex': 'Male',
#   'pet_breed': 'Chihuahua / Mix',
#   'pet_location': 'Tarrytown',
#   'Dog': 4,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 3,
#   'pet_id': 'APA-A-71409'},
#  {'pet_name': 'Poof',
#   'pet_age': 3.42,
#   'pet_sex': 'Female',
#   'pet_breed': 'Chihuahua / Mix',
#   'pet_location': 'Tarrytown',
#   'Dog': 4,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-71406'},
#  {'pet_name': 'Mariska',
#   'pet_age': 1.75,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-71315'},
#  {'pet_name': 'Lillian',
#   'pet_age': 5.08,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier, American Staffordshire / Mix',
#   'pet_location': 'Foster',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 5,
#   'pet_id': 'APA-A-32193'},
#  {'pet_name': 'Mr. Pickles',
#   'pet_age': 3.42,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Black Labrador / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 3,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-71498'},
#  {'pet_name': 'Thanos',
#   'pet_age': 2.25,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Chocolate Labrador',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-71489'},
#  {'pet_name': 'Prince Charming',
#   'pet_age': 4.0,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Retriever, Labrador',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 1,
#   'Child': 3,
#   'Home  Alone ': 3,
#   'pet_id': 'APA-A-51527'},
#  {'pet_name': 'Amelia Bedelia',
#   'pet_age': 7.92,
#   'pet_sex': 'Female',
#   'pet_breed': 'Cattle Dog, Australian (Blue Heeler) / Collie, Border',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-12490'},
#  {'pet_name': 'Revlon',
#   'pet_age': 2.75,
#   'pet_sex': 'Male',
#   'pet_breed': 'Bulldog, American / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-71685'},
#  {'pet_name': 'Xena',
#   'pet_age': 6.58,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 3,
#   'pet_id': 'APA-A-19372'},
#  {'pet_name': 'Silent Bob',
#   'pet_age': 8.83,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-6404'},
#  {'pet_name': 'Possum',
#   'pet_age': 1.75,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'Foster',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 3,
#   'Home  Alone ': 3,
#   'pet_id': 'APA-A-71745'},
#  {'pet_name': 'Howard',
#   'pet_age': 5.92,
#   'pet_sex': 'Male',
#   'pet_breed': 'Cattle Dog, Australian (Blue Heeler) / Mix',
#   'pet_location': 'Foster',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 5,
#   'pet_id': 'APA-A-38468'},
#  {'pet_name': 'Gale',
#   'pet_age': 0.42,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, American Pit Bull',
#   'pet_location': 'TLAC',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-71798'},
#  {'pet_name': 'Reno',
#   'pet_age': 5.92,
#   'pet_sex': 'Male',
#   'pet_breed': 'Shepherd, Australian / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-28011'},
#  {'pet_name': 'Thomas',
#   'pet_age': 3.42,
#   'pet_sex': 'Male',
#   'pet_breed': 'Collie / Mix',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 1,
#   'pet_id': 'APA-A-71948'},
#  {'pet_name': 'Zora',
#   'pet_age': 4.25,
#   'pet_sex': 'Female',
#   'pet_breed': 'Retriever, Black Labrador / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 3,
#   'pet_id': 'APA-A-50244'},
#  {'pet_name': 'Denny',
#   'pet_age': 2.33,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, American Staffordshire / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-72390'},
#  {'pet_name': 'Cookie',
#   'pet_age': 4.75,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Labrador / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 2,
#   'Child': 1,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-38108'},
#  {'pet_name': 'Gomez',
#   'pet_age': 0.5,
#   'pet_sex': 'Male',
#   'pet_breed': 'Mixed Breed (Medium) / Mix',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 3,
#   'Child': 2,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-72785'},
#  {'pet_name': 'Willis',
#   'pet_age': 2.33,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-72839'},
#  {'pet_name': 'Zelda',
#   'pet_age': 3.25,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier, American Pit Bull / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-73067'},
#  {'pet_name': 'Filbert',
#   'pet_age': 2.25,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Labrador / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 1,
#   'Child': 0,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-73063'},
#  {'pet_name': 'Bohdi',
#   'pet_age': 1.33,
#   'pet_sex': 'Male',
#   'pet_breed': 'Shepherd, Anatolian',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 4,
#   'Child': 1,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-72999'},
#  {'pet_name': 'Jack',
#   'pet_age': 6.42,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Labrador',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-73129'},
#  {'pet_name': 'Martin',
#   'pet_age': 2.75,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'Foster',
#   'Dog': 2,
#   'Cat': 2,
#   'Child': 2,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-48650'},
#  {'pet_name': 'Marshall',
#   'pet_age': 1.75,
#   'pet_sex': 'Male',
#   'pet_breed': 'Catahoula Leopard Dog / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-73283'},
#  {'pet_name': 'Brandy',
#   'pet_age': 6.08,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 0,
#   'Child': 3,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-73287'},
#  {'pet_name': 'Triton',
#   'pet_age': 4.0,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 2,
#   'Child': 2,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-63194'},
#  {'pet_name': 'Elmo',
#   'pet_age': 1.25,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Labrador / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 4,
#   'Cat': 3,
#   'Child': 0,
#   'Home  Alone ': 3,
#   'pet_id': 'APA-A-73377'},
#  {'pet_name': 'Maple',
#   'pet_age': 2.0,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, American Pit Bull / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 4,
#   'Child': 2,
#   'Home  Alone ': 3,
#   'pet_id': 'APA-A-59125'},
#  {'pet_name': 'Harry Potter',
#   'pet_age': 6.83,
#   'pet_sex': 'Male',
#   'pet_breed': 'Chihuahua / Pomeranian',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-73448'},
#  {'pet_name': 'Charlie',
#   'pet_age': 1.25,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull',
#   'pet_location': 'Foster',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-73509'},
#  {'pet_name': 'Olympia',
#   'pet_age': 6.08,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier, Pit Bull',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 2,
#   'Child': 2,
#   'Home  Alone ': 3,
#   'pet_id': 'APA-A-46924'},
#  {'pet_name': 'Crackers',
#   'pet_age': 3.17,
#   'pet_sex': 'Male',
#   'pet_breed': 'Chihuahua / Mix',
#   'pet_location': 'Foster',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 3,
#   'pet_id': 'APA-A-71256'},
#  {'pet_name': 'Martha',
#   'pet_age': 8.0,
#   'pet_sex': 'Female',
#   'pet_breed': 'Retriever, Labrador / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 0,
#   'Child': 4,
#   'Home  Alone ': 5,
#   'pet_id': 'APA-A-12538'},
#  {'pet_name': 'Leonidas',
#   'pet_age': 7.17,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'Foster',
#   'Dog': 2,
#   'Cat': 1,
#   'Child': 3,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-39606'},
#  {'pet_name': 'Soup',
#   'pet_age': 2.5,
#   'pet_sex': 'Male',
#   'pet_breed': 'Bulldog, American / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 1,
#   'Child': 2,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-71471'},
#  {'pet_name': 'Big Caesar',
#   'pet_age': 10.42,
#   'pet_sex': 'Male',
#   'pet_breed': 'Dogo Argentino / Bulldog',
#   'pet_location': 'Foster',
#   'Dog': 1,
#   'Cat': 1,
#   'Child': 2,
#   'Home  Alone ': 5,
#   'pet_id': 'APA-A-32157'},
#  {'pet_name': 'Shasta',
#   'pet_age': 2.33,
#   'pet_sex': 'Female',
#   'pet_breed': 'Dogo Argentino / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-73778'},
#  {'pet_name': 'Sir Mix-a-Lot',
#   'pet_age': 2.33,
#   'pet_sex': 'Male',
#   'pet_breed': 'Catahoula Leopard Dog',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-73794'},
#  {'pet_name': 'Serengeti',
#   'pet_age': 5.25,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 0,
#   'Child': 3,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-73806'},
#  {'pet_name': 'Parker',
#   'pet_age': 3.25,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-73815'},
#  {'pet_name': 'Harmony',
#   'pet_age': 2.25,
#   'pet_sex': 'Female',
#   'pet_breed': 'Retriever, Labrador / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 0,
#   'Cat': 1,
#   'Child': 0,
#   'Home  Alone ': 3,
#   'pet_id': 'APA-A-73813'},
#  {'pet_name': 'Todd',
#   'pet_age': 2.08,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-62458'},
#  {'pet_name': 'Molly',
#   'pet_age': 5.25,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier, Pit Bull',
#   'pet_location': 'TLAC',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-73822'},
#  {'pet_name': 'Altaria',
#   'pet_age': 1.33,
#   'pet_sex': 'Female',
#   'pet_breed': 'Hound, Plott',
#   'pet_location': 'TLAC',
#   'Dog': 0,
#   'Cat': 3,
#   'Child': 4,
#   'Home  Alone ': 3,
#   'pet_id': 'APA-A-73914'},
#  {'pet_name': 'Scott',
#   'pet_age': 2.42,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Black Labrador / Mixed Breed (Medium)',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 2,
#   'Child': 2,
#   'Home  Alone ': 3,
#   'pet_id': 'APA-A-71768'},
#  {'pet_name': 'Flute',
#   'pet_age': 1.25,
#   'pet_sex': 'Female',
#   'pet_breed': 'Pyrenees, Great / Retriever, Labrador',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 3,
#   'Child': 3,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-73987'},
#  {'pet_name': 'Zephyr',
#   'pet_age': 6.25,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Bull / Chinese Shar-Pei',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-73983'},
#  {'pet_name': 'Sage',
#   'pet_age': 4.25,
#   'pet_sex': 'Female',
#   'pet_breed': 'Bulldog, American',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-73981'},
#  {'pet_name': 'Tempo',
#   'pet_age': 0.17,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Labrador / Mix',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-74046'},
#  {'pet_name': 'Melody',
#   'pet_age': 0.17,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Labrador / Mix',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-74049'},
#  {'pet_name': 'Chicklet',
#   'pet_age': 4.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier, Pit Bull',
#   'pet_location': 'Foster',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-74051'},
#  {'pet_name': 'Sophia',
#   'pet_age': 8.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Chihuahua',
#   'pet_location': 'Foster',
#   'Dog': 3,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-74053'},
#  {'pet_name': 'Elmer',
#   'pet_age': 2.25,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Labrador / Pointer',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-74126'},
#  {'pet_name': 'Snortlette',
#   'pet_age': 3.25,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier, American Pit Bull / Terrier, American Staffordshire',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 2,
#   'Child': 3,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-74140'},
#  {'pet_name': 'Margrrrita',
#   'pet_age': 10.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Poodle, Miniature',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 4,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-74099'},
#  {'pet_name': 'Bette',
#   'pet_age': 2.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Husky / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-74082'},
#  {'pet_name': 'Rosebud',
#   'pet_age': 0.83,
#   'pet_sex': 'Female',
#   'pet_breed': 'Great Dane / Retriever, Black Labrador',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 3,
#   'pet_id': 'APA-A-74064'},
#  {'pet_name': 'James Bond',
#   'pet_age': 4.25,
#   'pet_sex': 'Male',
#   'pet_breed': 'Mixed Breed (Medium)',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-74132'},
#  {'pet_name': 'Schroeder',
#   'pet_age': 1.83,
#   'pet_sex': 'Male',
#   'pet_breed': 'Bernese Mountain Dog / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-65855'},
#  {'pet_name': 'Joshua',
#   'pet_age': 2.83,
#   'pet_sex': 'Male',
#   'pet_breed': 'Collie, Border / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 3,
#   'pet_id': 'APA-A-66365'},
#  {'pet_name': 'Pippen',
#   'pet_age': 3.5,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Labrador / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 4,
#   'Cat': 3,
#   'Child': 2,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-39544'},
#  {'pet_name': 'Mr. Squiggles',
#   'pet_age': 0.92,
#   'pet_sex': 'Male',
#   'pet_breed': 'Shepherd, German / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 3,
#   'pet_id': 'APA-A-74279'},
#  {'pet_name': 'Elton',
#   'pet_age': 0.83,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Labrador / Mix',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 0,
#   'Child': 4,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-74250'},
#  {'pet_name': 'Prince Harry',
#   'pet_age': 2.17,
#   'pet_sex': 'Male',
#   'pet_breed': 'Mixed Breed (Medium)',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-74276'},
#  {'pet_name': 'Sugar',
#   'pet_age': 1.33,
#   'pet_sex': 'Female',
#   'pet_breed': 'Pyrenees, Great / Mix',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-74277'},
#  {'pet_name': 'Spice',
#   'pet_age': 1.33,
#   'pet_sex': 'Female',
#   'pet_breed': 'Pyrenees, Great / Mix',
#   'pet_location': 'Foster',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 3,
#   'pet_id': 'APA-A-74278'},
#  {'pet_name': 'Juno',
#   'pet_age': 1.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Chihuahua',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-74282'},
#  {'pet_name': 'Paco',
#   'pet_age': 5.5,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 2,
#   'Child': 2,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-26694'},
#  {'pet_name': 'Felipe',
#   'pet_age': 3.58,
#   'pet_sex': 'Male',
#   'pet_breed': 'Cattle Dog, Australian (Red Heeler) / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 3,
#   'pet_id': 'APA-A-40577'},
#  {'pet_name': 'Tip',
#   'pet_age': 12.17,
#   'pet_sex': 'Male',
#   'pet_breed': 'Chihuahua, Short Coat / Mix',
#   'pet_location': 'Foster',
#   'Dog': 3,
#   'Cat': 3,
#   'Child': 2,
#   'Home  Alone ': 3,
#   'pet_id': 'APA-A-74352'},
#  {'pet_name': 'Master',
#   'pet_age': 0.33,
#   'pet_sex': 'Male',
#   'pet_breed': 'Cattle Dog, Australian (Red Heeler)',
#   'pet_location': 'Foster Home',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-74380'},
#  {'pet_name': 'Amara',
#   'pet_age': 0.33,
#   'pet_sex': 'Female',
#   'pet_breed': 'Mixed Breed (Large)',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-74418'},
#  {'pet_name': 'Beckett',
#   'pet_age': 0.33,
#   'pet_sex': 'Male',
#   'pet_breed': 'Mixed Breed (Large)',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-74420'},
#  {'pet_name': 'Cersei',
#   'pet_age': 0.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Chihuahua',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-74459'},
#  {'pet_name': 'Jessie',
#   'pet_age': 2.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Retriever / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-74437'},
#  {'pet_name': 'Sir Wigglesworth',
#   'pet_age': 2.5,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-74435'},
#  {'pet_name': 'Connie',
#   'pet_age': 2.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Chihuahua / Mix',
#   'pet_location': 'Foster',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-74534'},
#  {'pet_name': 'Scarlett',
#   'pet_age': 1.5,
#   'pet_sex': 'Female',
#   'pet_breed': 'Retriever, Labrador / American Blue Heeler',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 3,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-74535'},
#  {'pet_name': 'Dude',
#   'pet_age': 2.67,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Labrador / Boxer',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-74562'},
#  {'pet_name': 'Precious',
#   'pet_age': 2.08,
#   'pet_sex': 'Female',
#   'pet_breed': 'Black Mouth Cur',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-74598'},
#  {'pet_name': 'Flabbergasted',
#   'pet_age': 0.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Black Mouth Cur',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-74607'},
#  {'pet_name': 'Ravioli',
#   'pet_age': 5.5,
#   'pet_sex': 'Male',
#   'pet_breed': 'Shepherd / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 3,
#   'Child': 1,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-24854'},
#  {'pet_name': 'Moxi',
#   'pet_age': 2.25,
#   'pet_sex': 'Female',
#   'pet_breed': 'Chinese Shar-Pei / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-74632'},
#  {'pet_name': 'Joker',
#   'pet_age': 3.17,
#   'pet_sex': 'Male',
#   'pet_breed': 'Mastiff / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-74655'},
#  {'pet_name': 'Vickie',
#   'pet_age': 8.0,
#   'pet_sex': 'Female',
#   'pet_breed': 'Cattle Dog / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 4,
#   'Child': 2,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-51960'},
#  {'pet_name': 'Pepper',
#   'pet_age': 3.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Chihuahua',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 0,
#   'Child': 3,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-74658'},
#  {'pet_name': 'Falcon',
#   'pet_age': 2.58,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 3,
#   'Home  Alone ': 3,
#   'pet_id': 'APA-A-74684'},
#  {'pet_name': 'Sequoia',
#   'pet_age': 3.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier, Pit Bull',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-74659'},
#  {'pet_name': 'Falcon',
#   'pet_age': 2.58,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 3,
#   'Home  Alone ': 3,
#   'pet_id': 'APA-A-74684'},
#  {'pet_name': 'Layla',
#   'pet_age': 8.67,
#   'pet_sex': 'Female',
#   'pet_breed': 'Chow Chow / Retriever, Labrador',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 0,
#   'Child': 3,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-74719'},
#  {'pet_name': 'Shorty',
#   'pet_age': 3.0,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, American Staffordshire',
#   'pet_location': 'Foster',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-71316'},
#  {'pet_name': 'Black Diamond',
#   'pet_age': 0.08,
#   'pet_sex': 'Male',
#   'pet_breed': 'Chihuahua',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-74800'},
#  {'pet_name': 'Mr. Fantastic',
#   'pet_age': 3.67,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, American Staffordshire / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 5,
#   'pet_id': 'APA-A-55509'},
#  {'pet_name': 'Paco Taco',
#   'pet_age': 0.08,
#   'pet_sex': 'Male',
#   'pet_breed': 'Chihuahua / Mix',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-74805'},
#  {'pet_name': 'Pablo Pablano',
#   'pet_age': 0.08,
#   'pet_sex': 'Male',
#   'pet_breed': 'Chihuahua / Mix',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-74807'},
#  {'pet_name': 'Elvis Parsley',
#   'pet_age': 0.08,
#   'pet_sex': 'Male',
#   'pet_breed': 'Chihuahua / Mix',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-74808'},
#  {'pet_name': 'Hamlett',
#   'pet_age': 0.08,
#   'pet_sex': 'Male',
#   'pet_breed': 'Chihuahua / Mix',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-74809'},
#  {'pet_name': 'Bolo Tie',
#   'pet_age': 0.25,
#   'pet_sex': 'Male',
#   'pet_breed': 'Shepherd, German / Mix',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-74782'},
#  {'pet_name': 'Billy',
#   'pet_age': 4.25,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-74843'},
#  {'pet_name': 'Jagger',
#   'pet_age': 4.08,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, American Pit Bull / Boxer',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-74844'},
#  {'pet_name': 'Odette',
#   'pet_age': 10.08,
#   'pet_sex': 'Female',
#   'pet_breed': 'Chihuahua',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 3,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-74838'},
#  {'pet_name': 'Ben',
#   'pet_age': 6.5,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-74865'},
#  {'pet_name': 'Elizabeth',
#   'pet_age': 0.08,
#   'pet_sex': 'Female',
#   'pet_breed': 'Shepherd, Anatolian',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-75009'},
#  {'pet_name': 'Chesney',
#   'pet_age': 6.08,
#   'pet_sex': 'Female',
#   'pet_breed': 'Retriever, Labrador',
#   'pet_location': 'Foster',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-74899'},
#  {'pet_name': 'Tinka',
#   'pet_age': 3.58,
#   'pet_sex': 'Female',
#   'pet_breed': 'Mastiff / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-74894'},
#  {'pet_name': 'Kent',
#   'pet_age': 7.83,
#   'pet_sex': 'Male',
#   'pet_breed': 'Cattle Dog, Australian (Blue Heeler) / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 2,
#   'Child': 3,
#   'Home  Alone ': 3,
#   'pet_id': 'APA-A-45985'},
#  {'pet_name': 'Sabelia',
#   'pet_age': 0.08,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier, Pit Bull',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-74926'},
#  {'pet_name': 'Sagara',
#   'pet_age': 0.08,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier, Pit Bull',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-74927'},
#  {'pet_name': 'Calab',
#   'pet_age': 3.08,
#   'pet_sex': 'Male',
#   'pet_breed': 'Chihuahua, Short Coat / Mix',
#   'pet_location': 'Tarrytown',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 3,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-43151'},
#  {'pet_name': 'Sapphire',
#   'pet_age': 0.08,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier, Pit Bull',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-74928'},
#  {'pet_name': 'Seki',
#   'pet_age': 0.08,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier, Pit Bull',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-74929'},
#  {'pet_name': 'Seki',
#   'pet_age': 0.08,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier, Pit Bull',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-74929'},
#  {'pet_name': 'Shyanna',
#   'pet_age': 0.08,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier, Pit Bull',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-74930'},
#  {'pet_name': 'Tyson',
#   'pet_age': 1.75,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'Foster',
#   'Dog': 2,
#   'Cat': 3,
#   'Child': 2,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-66784'},
#  {'pet_name': 'Santi',
#   'pet_age': 0.08,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-74931'},
#  {'pet_name': 'Everett',
#   'pet_age': 0.08,
#   'pet_sex': 'Male',
#   'pet_breed': 'Shepherd, Anatolian',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-75011'},
#  {'pet_name': 'Elise',
#   'pet_age': 0.08,
#   'pet_sex': 'Female',
#   'pet_breed': 'Shepherd, Anatolian',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-75012'},
#  {'pet_name': 'Eleanor',
#   'pet_age': 0.08,
#   'pet_sex': 'Female',
#   'pet_breed': 'Shepherd, Anatolian',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-75013'},
#  {'pet_name': 'Edgar',
#   'pet_age': 0.08,
#   'pet_sex': 'Male',
#   'pet_breed': 'Shepherd, Anatolian',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-75014'},
#  {'pet_name': 'Elena',
#   'pet_age': 0.08,
#   'pet_sex': 'Female',
#   'pet_breed': 'Shepherd, Anatolian',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-75015'},
#  {'pet_name': 'Jason',
#   'pet_age': 4.75,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 2,
#   'Child': 1,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-65150'},
#  {'pet_name': 'Emerson',
#   'pet_age': 0.08,
#   'pet_sex': 'Male',
#   'pet_breed': 'Shepherd, Anatolian',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-75016'},
#  {'pet_name': 'Eastwood',
#   'pet_age': 0.08,
#   'pet_sex': 'Male',
#   'pet_breed': 'Shepherd, Anatolian',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-75010'},
#  {'pet_name': 'Argus',
#   'pet_age': 0.83,
#   'pet_sex': 'Male',
#   'pet_breed': 'Mixed Breed (Medium)',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 3,
#   'Child': 0,
#   'Home  Alone ': 3,
#   'pet_id': 'APA-A-75045'},
#  {'pet_name': 'Maggie Lab',
#   'pet_age': 13.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Retriever, Labrador / Chow Chow',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 0,
#   'Child': 4,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-75102'},
#  {'pet_name': 'Loma',
#   'pet_age': 10.08,
#   'pet_sex': 'Female',
#   'pet_breed': 'Boxer',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-75101'},
#  {'pet_name': 'Brixton',
#   'pet_age': 5.08,
#   'pet_sex': 'Male',
#   'pet_breed': 'Mastiff / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 1,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-70287'},
#  {'pet_name': 'Pistachio',
#   'pet_age': 0.5,
#   'pet_sex': 'Female',
#   'pet_breed': 'Chihuahua',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-75142'},
#  {'pet_name': 'Hopi',
#   'pet_age': 0.17,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Black Labrador / Mix',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 3,
#   'pet_id': 'APA-A-75160'},
#  {'pet_name': 'Freddie',
#   'pet_age': 4.5,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-41414'},
#  {'pet_name': 'Bumble Bee',
#   'pet_age': 0.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier, Pit Bull',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-75212'},
#  {'pet_name': 'Bryant',
#   'pet_age': 1.0,
#   'pet_sex': 'Male',
#   'pet_breed': 'Collie, Border / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-75247'},
#  {'pet_name': 'Oso',
#   'pet_age': 2.17,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-75252'},
#  {'pet_name': 'Canelo',
#   'pet_age': 1.83,
#   'pet_sex': 'Male',
#   'pet_breed': 'Shepherd, German / Terrier, Pit Bull',
#   'pet_location': 'TLAC',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-75251'},
#  {'pet_name': 'Stone',
#   'pet_age': 0.75,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Black Labrador / Terrier, Pit Bull',
#   'pet_location': 'TLAC',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 3,
#   'pet_id': 'APA-A-75250'},
#  {'pet_name': 'Monet',
#   'pet_age': 1.58,
#   'pet_sex': 'Female',
#   'pet_breed': 'Hound, Plott',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
# ...
#  {'pet_name': 'Jackie',
#   'pet_age': 0.33,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-76023'},
#  {'pet_name': 'Izzy',
#   'pet_age': 10.08,
#   'pet_sex': 'Female',
#   'pet_breed': 'Shepherd / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 5,
#   'pet_id': 'APA-A-5344'},
#  {'pet_name': 'Randy',
#   'pet_age': 0.33,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-76024'},
#  {'pet_name': 'Nala',
#   'pet_age': 2.0,
#   'pet_sex': 'Female',
#   'pet_breed': 'Retriever, Black Labrador',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-75992'},
#  {'pet_name': 'Honey',
#   'pet_age': 4.0,
#   'pet_sex': 'Female',
#   'pet_breed': 'Hound / Mix',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-75993'},
#  {'pet_name': 'Frank Sinatra',
#   'pet_age': 1.0,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull',
#   'pet_location': 'TLAC',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-76047'},
#  {'pet_name': 'India Opal',
#   'pet_age': 1.08,
#   'pet_sex': 'Female',
#   'pet_breed': 'Blue Lacy / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-75482'},
#  {'pet_name': 'Frank Sinatra',
#   'pet_age': 1.0,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull',
#   'pet_location': 'TLAC',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-76047'},
#  {'pet_name': 'Hunter',
#   'pet_age': 0.33,
#   'pet_sex': 'Male',
#   'pet_breed': 'Pointer / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-76040'},
#  {'pet_name': 'Oli Sykes',
#   'pet_age': 3.67,
#   'pet_sex': 'Male',
#   'pet_breed': 'Mixed Breed (Medium) / Mixed Breed (Medium)',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 3,
#   'Child': 0,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-71024'},
#  {'pet_name': 'Aubrey',
#   'pet_age': 6.0,
#   'pet_sex': 'Female',
#   'pet_breed': 'Pointer / Mix',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-76062'},
#  {'pet_name': 'Ringo',
#   'pet_age': 1.5,
#   'pet_sex': 'Male',
#   'pet_breed': 'Rottweiler',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 3,
#   'pet_id': 'APA-A-76063'},
#  {'pet_name': 'Paz',
#   'pet_age': 1.58,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-56883'},
#  {'pet_name': 'Mary Pitt',
#   'pet_age': 2.33,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 2,
#   'Cat': 3,
#   'Child': 2,
#   'Home  Alone ': 5,
#   'pet_id': 'APA-A-53573'},
#  {'pet_name': 'Callie',
#   'pet_age': 0.42,
#   'pet_sex': 'Female',
#   'pet_breed': 'Shepherd, German / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-76111'},
#  {'pet_name': 'Tango',
#   'pet_age': 0.17,
#   'pet_sex': 'Male',
#   'pet_breed': 'Dachshund / Terrier',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-76103'},
#  {'pet_name': 'Barker',
#   'pet_age': 0.17,
#   'pet_sex': 'Male',
#   'pet_breed': 'Dachshund / Terrier',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-76104'},
#  {'pet_name': 'Stump',
#   'pet_age': 0.17,
#   'pet_sex': 'Male',
#   'pet_breed': 'Dachshund / Terrier',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-76105'},
#  {'pet_name': 'Reese',
#   'pet_age': 0.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Dachshund / Terrier',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-76106'},
#  {'pet_name': 'Lavigne',
#   'pet_age': 0.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Dachshund / Terrier',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-76108'},
#  {'pet_name': 'Rufus',
#   'pet_age': 5.75,
#   'pet_sex': 'Male',
#   'pet_breed': 'Mixed Breed (Medium) / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 2,
#   'Child': 1,
#   'Home  Alone ': 5,
#   'pet_id': 'APA-A-40179'},
#  {'pet_name': 'Jett',
#   'pet_age': 0.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Dachshund / Terrier',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-76109'},
#  {'pet_name': 'Jiggy',
#   'pet_age': 7.0,
#   'pet_sex': 'Male',
#   'pet_breed': 'Chihuahua / Mix',
#   'pet_location': 'Tarrytown',
#   'Dog': 4,
#   'Cat': 0,
#   'Child': 3,
#   'Home  Alone ': 3,
#   'pet_id': 'APA-A-76039'},
#  {'pet_name': 'Foxy',
#   'pet_age': 0.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Dachshund / Terrier',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-76110'},
#  {'pet_name': 'Missy',
#   'pet_age': 0.33,
#   'pet_sex': 'Female',
#   'pet_breed': 'Cattle Dog, Australian (Red Heeler)',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-74381'},
#  {'pet_name': 'JFK',
#   'pet_age': 7.83,
#   'pet_sex': 'Male',
#   'pet_breed': 'Mixed Breed (Small)',
#   'pet_location': 'Tarrytown',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 3,
#   'Home  Alone ': 3,
#   'pet_id': 'APA-A-76129'},
#  {'pet_name': 'Smile',
#   'pet_age': 3.58,
#   'pet_sex': 'Female',
#   'pet_breed': 'Black Mouth Cur / Mix',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-76127'},
#  {'pet_name': 'Shaamus',
#   'pet_age': 5.5,
#   'pet_sex': 'Male',
#   'pet_breed': 'Cattle Dog / Mix',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 3,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-76126'},
#  {'pet_name': 'Security',
#   'pet_age': 7.25,
#   'pet_sex': 'Male',
#   'pet_breed': 'Chihuahua / Mix',
#   'pet_location': 'Tarrytown',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 2,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-76131'},
#  {'pet_name': 'Casper',
#   'pet_age': 0.42,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Labrador / Mix',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-76128'},
#  {'pet_name': 'Phyllis',
#   'pet_age': 7.0,
#   'pet_sex': 'Female',
#   'pet_breed': 'Chihuahua / Mix',
#   'pet_location': 'Tarrytown',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-76146'},
#  {'pet_name': 'Cota',
#   'pet_age': 2.0,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Labrador / Pyrenees, Great',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-76151'},
#  {'pet_name': 'Azra',
#   'pet_age': 5.5,
#   'pet_sex': 'Female',
#   'pet_breed': 'Hound, Plott / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 1,
#   'Cat': 0,
#   'Child': 4,
#   'Home  Alone ': 5,
#   'pet_id': 'APA-A-27139'},
#  {'pet_name': 'Lemon',
#   'pet_age': 0.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Mixed Breed (Medium)',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-76161'},
#  {'pet_name': 'Maggie Shepherd',
#   'pet_age': 6.0,
#   'pet_sex': 'Female',
#   'pet_breed': 'Shepherd / Mixed Breed (Medium)',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-76178'},
#  {'pet_name': 'Mockingbird',
#   'pet_age': 0.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Mixed Breed (Medium)',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-76156'},
#  {'pet_name': 'Jaws',
#   'pet_age': 0.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Mixed Breed (Medium)',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-76158'},
#  {'pet_name': 'Ted',
#   'pet_age': 10.0,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Rat / Chihuahua',
#   'pet_location': 'Tarrytown',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-76184'},
#  {'pet_name': 'Allie',
#   'pet_age': 6.67,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-76183'},
#  {'pet_name': 'Eloise',
#   'pet_age': 0.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Pointer / Retriever, Black Labrador',
#   'pet_location': 'TLAC',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-76187'},
#  {'pet_name': 'Casablanca',
#   'pet_age': 0.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Mixed Breed (Medium)',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-76157'},
#  {'pet_name': 'Vertigo',
#   'pet_age': 0.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Mixed Breed (Medium)',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-76159'},
#  {'pet_name': 'The Wiz',
#   'pet_age': 0.17,
#   'pet_sex': 'Female',
#   'pet_breed': 'Mixed Breed (Medium)',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-76160'},
#  {'pet_name': 'Chanel',
#   'pet_age': 1.5,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-76224'},
#  {'pet_name': 'Highland',
#   'pet_age': 0.33,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Labrador',
#   'pet_location': 'TLAC',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-76226'},
#  {'pet_name': 'Rex',
#   'pet_age': 1.67,
#   'pet_sex': 'Male',
#   'pet_breed': 'Shepherd, Belgian Malinois / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 1,
#   'Child': 3,
#   'Home  Alone ': 4,
#   'pet_id': 'APA-A-61107'},
#  {'pet_name': 'Mikey',
#   'pet_age': 1.5,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Curly-Coated / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 3,
#   'pet_id': 'APA-A-65819'},
#  {'pet_name': 'Marley',
#   'pet_age': 0.33,
#   'pet_sex': 'Female',
#   'pet_breed': 'Retriever, Labrador / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-76249'},
#  {'pet_name': 'Little Sarah',
#   'pet_age': 0.42,
#   'pet_sex': 'Female',
#   'pet_breed': 'Hound / Mix',
#   'pet_location': 'Foster',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-76227'},
#  {'pet_name': 'Dan',
#   'pet_age': 1.08,
#   'pet_sex': 'Male',
#   'pet_breed': 'Boxer / Terrier, Pit Bull',
#   'pet_location': 'TLAC',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 3,
#   'pet_id': 'APA-A-75668'},
#  {'pet_name': 'Joe',
#   'pet_age': 6.0,
#   'pet_sex': 'Male',
#   'pet_breed': 'Mastiff',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-76250'},
#  {'pet_name': 'Razen',
#   'pet_age': 3.0,
#   'pet_sex': 'Female',
#   'pet_breed': 'Catahoula Leopard Dog',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-76287'},
#  {'pet_name': 'Gabby',
#   'pet_age': 1.0,
#   'pet_sex': 'Female',
#   'pet_breed': 'Beagle / Pointer',
#   'pet_location': 'TLAC',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-76304'},
#  {'pet_name': 'Givenchy',
#   'pet_age': 0.67,
#   'pet_sex': 'Female',
#   'pet_breed': 'Cattle Dog / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-76307'},
#  {'pet_name': 'Razen',
#   'pet_age': 3.0,
#   'pet_sex': 'Female',
#   'pet_breed': 'Catahoula Leopard Dog',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-76287'},
#  {'pet_name': 'Gabby',
#   'pet_age': 1.0,
#   'pet_sex': 'Female',
#   'pet_breed': 'Beagle / Pointer',
#   'pet_location': 'TLAC',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-76304'},
#  {'pet_name': 'Givenchy',
#   'pet_age': 0.67,
#   'pet_sex': 'Female',
#   'pet_breed': 'Cattle Dog / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-76307'},
#  {'pet_name': 'Tootles',
#   'pet_age': 1.5,
#   'pet_sex': 'Female',
#   'pet_breed': 'Collie, Smooth / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-76308'},
#  {'pet_name': 'Khloe',
#   'pet_age': 0.83,
#   'pet_sex': 'Female',
#   'pet_breed': 'Retriever, Labrador / Mix',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-76284'},
#  {'pet_name': 'Napoleon',
#   'pet_age': 4.25,
#   'pet_sex': 'Male',
#   'pet_breed': 'Hound / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 3,
#   'Cat': 5,
#   'Child': 2,
#   'Home  Alone ': 5,
#   'pet_id': 'APA-A-32756'},
#  {'pet_name': 'Sr Butter',
#   'pet_age': 10.0,
#   'pet_sex': 'Female',
#   'pet_breed': 'Retriever, Yellow Labrador',
#   'pet_location': 'Foster',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-76286'},
#  {'pet_name': 'Chocolate',
#   'pet_age': 2.0,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Labrador / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-76305'},
#  {'pet_name': 'Herb',
#   'pet_age': 2.0,
#   'pet_sex': 'Male',
#   'pet_breed': 'Cattle Dog / Husky',
#   'pet_location': 'TLAC',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-76306'},
#  {'pet_name': 'Malik',
#   'pet_age': 0.83,
#   'pet_sex': 'Male',
#   'pet_breed': 'Pointer / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-76331'},
#  {'pet_name': 'Nickolas',
#   'pet_age': 0.42,
#   'pet_sex': 'Male',
#   'pet_breed': 'Retriever, Labrador / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-76332'},
#  {'pet_name': 'Luna',
#   'pet_age': 0.5,
#   'pet_sex': 'Female',
#   'pet_breed': 'Retriever, Labrador',
#   'pet_location': 'TLAC',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-76335'},
#  {'pet_name': 'Ginger',
#   'pet_age': 0.67,
#   'pet_sex': 'Female',
#   'pet_breed': 'Hound, Plott',
#   'pet_location': 'TLAC',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-76336'},
#  {'pet_name': 'Nadine',
#   'pet_age': 0.33,
#   'pet_sex': 'Female',
#   'pet_breed': 'Hound, Plott / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 4,
#   'Cat': 4,
#   'Child': 0,
#   'Home  Alone ': 2,
#   'pet_id': 'APA-A-76339'},
#  {'pet_name': 'Marcella',
#   'pet_age': 4.0,
#   'pet_sex': 'Female',
#   'pet_breed': 'Terrier / Chihuahua',
#   'pet_location': 'Tarrytown',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-76323'},
#  {'pet_name': 'Raggedy Andy',
#   'pet_age': 2.5,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier / Mix',
#   'pet_location': 'Tarrytown',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 3,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-76325'},
#  {'pet_name': 'Denzel',
#   'pet_age': 2.0,
#   'pet_sex': 'Male',
#   'pet_breed': 'Hound, Basset / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-76340'},
#  {'pet_name': 'Apple Pie',
#   'pet_age': 2.0,
#   'pet_sex': 'Female',
#   'pet_breed': 'Sheepdog, Old English / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-76328'},
#  {'pet_name': 'Skippy',
#   'pet_age': 1.5,
#   'pet_sex': 'Male',
#   'pet_breed': 'Terrier, Pit Bull / Mix',
#   'pet_location': 'TLAC',
#   'Dog': 0,
#   'Cat': 0,
#   'Child': 0,
#   'Home  Alone ': 0,
#   'pet_id': 'APA-A-76330'}]

# %%
for pet in apa_data:
    print(pet)
    collection.insert_one(pet)
# Out:
# {'pet_name': 'Sparky', 'pet_age': 6.5, 'pet_sex': 'Male', 'pet_breed': 'Terrier, Pit Bull / Mix', 'pet_location': 'Foster', 'Dog': 1, 'Cat': 1, 'Child': 2, 'Home  Alone ': 4, 'pet_id': 'APA-A-36615', '_id': ObjectId('5d8253057b3fd12bb5f79cd5')}
# {'pet_name': 'Rio', 'pet_age': 3.75, 'pet_sex': 'Male', 'pet_breed': 'Mixed Breed (Large) / Great Dane', 'pet_location': 'TLAC', 'Dog': 1, 'Cat': 0, 'Child': 1, 'Home  Alone ': 5, 'pet_id': 'APA-A-45785', '_id': ObjectId('5d8253057b3fd12bb5f79cd6')}
# {'pet_name': 'Twister', 'pet_age': 5.67, 'pet_sex': 'Male', 'pet_breed': 'Shepherd, Anatolian / Mix', 'pet_location': 'TLAC', 'Dog': 1, 'Cat': 2, 'Child': 1, 'Home  Alone ': 5, 'pet_id': 'APA-A-47726', '_id': ObjectId('5d8253057b3fd12bb5f79cd7')}
# {'pet_name': 'Beryl', 'pet_age': 6.58, 'pet_sex': 'Male', 'pet_breed': 'Retriever, Yellow Labrador / Mix', 'pet_location': 'TLAC', 'Dog': 2, 'Cat': 2, 'Child': 1, 'Home  Alone ': 4, 'pet_id': 'APA-A-49698', '_id': ObjectId('5d8253057b3fd12bb5f79cd8')}
# {'pet_name': 'Brindle', 'pet_age': 5.5, 'pet_sex': 'Male', 'pet_breed': 'Hound / Hound', 'pet_location': 'TLAC', 'Dog': 1, 'Cat': 2, 'Child': 1, 'Home  Alone ': 5, 'pet_id': 'APA-A-43905', '_id': ObjectId('5d8253057b3fd12bb5f79cd9')}
# {'pet_name': 'Ziggy', 'pet_age': 4.42, 'pet_sex': 'Male', 'pet_breed': 'Hound / Mix', 'pet_location': 'Foster', 'Dog': 1, 'Cat': 3, 'Child': 1, 'Home  Alone ': 4, 'pet_id': 'APA-A-35188', '_id': ObjectId('5d8253057b3fd12bb5f79cda')}
# {'pet_name': 'Grayson', 'pet_age': 4.0, 'pet_sex': 'Male', 'pet_breed': 'Retriever, Labrador / Mix', 'pet_location': 'Foster', 'Dog': 1, 'Cat': 0, 'Child': 3, 'Home  Alone ': 5, 'pet_id': 'APA-A-53121', '_id': ObjectId('5d8253057b3fd12bb5f79cdb')}
# {'pet_name': 'Ludwig', 'pet_age': 6.67, 'pet_sex': 'Male', 'pet_breed': 'Bernese Mountain Dog / Mix', 'pet_location': 'TLAC', 'Dog': 2, 'Cat': 0, 'Child': 1, 'Home  Alone ': 3, 'pet_id': 'APA-A-53740', '_id': ObjectId('5d8253057b3fd12bb5f79cdc')}
# {'pet_name': 'Vegas', 'pet_age': 5.83, 'pet_sex': 'Male', 'pet_breed': 'Terrier, Pit Bull / Mix', 'pet_location': 'Foster', 'Dog': 1, 'Cat': 2, 'Child': 1, 'Home  Alone ': 4, 'pet_id': 'APA-A-54604', '_id': ObjectId('5d8253057b3fd12bb5f79cdd')}
# {'pet_name': 'June Bug', 'pet_age': 5.92, 'pet_sex': 'Female', 'pet_breed': 'Retriever, Labrador / Mix', 'pet_location': 'TLAC', 'Dog': 4, 'Cat': 0, 'Child': 2, 'Home  Alone ': 4, 'pet_id': 'APA-A-54851', '_id': ObjectId('5d8253057b3fd12bb5f79cde')}
# {'pet_name': 'Rocco', 'pet_age': 4.75, 'pet_sex': 'Male', 'pet_breed': 'Catahoula Leopard Dog / Mix', 'pet_location': 'TLAC', 'Dog': 2, 'Cat': 2, 'Child': 1, 'Home  Alone ': 4, 'pet_id': 'APA-A-37564', '_id': ObjectId('5d8253057b3fd12bb5f79cdf')}
# {'pet_name': 'Jake Ryan', 'pet_age': 6.83, 'pet_sex': 'Male', 'pet_breed': 'Retriever, Labrador / Mix', 'pet_location': 'TLAC', 'Dog': 2, 'Cat': 1, 'Child': 1, 'Home  Alone ': 2, 'pet_id': 'APA-A-55056', '_id': ObjectId('5d8253057b3fd12bb5f79ce0')}
# {'pet_name': 'Brooks', 'pet_age': 7.92, 'pet_sex': 'Male', 'pet_breed': 'Mixed Breed (Medium) / Mix', 'pet_location': 'Foster', 'Dog': 1, 'Cat': 1, 'Child': 2, 'Home  Alone ': 4, 'pet_id': 'APA-A-55237', '_id': ObjectId('5d8253057b3fd12bb5f79ce1')}
# {'pet_name': 'Schone', 'pet_age': 10.25, 'pet_sex': 'Female', 'pet_breed': 'Retriever, Black Labrador', 'pet_location': 'Foster', 'Dog': 1, 'Cat': 3, 'Child': 4, 'Home  Alone ': 3, 'pet_id': 'APA-A-55491', '_id': ObjectId('5d8253057b3fd12bb5f79ce2')}
# {'pet_name': 'Monty', 'pet_age': 4.42, 'pet_sex': 'Male', 'pet_breed': 'Terrier, Pit Bull / Mix', 'pet_location': 'Foster', 'Dog': 1, 'Cat': 1, 'Child': 2, 'Home  Alone ': 4, 'pet_id': 'APA-A-40017', '_id': ObjectId('5d8253057b3fd12bb5f79ce3')}
# {'pet_name': 'Nike', 'pet_age': 9.0, 'pet_sex': 'Male', 'pet_breed': 'Retriever, Labrador / Mix', 'pet_location': 'Foster', 'Dog': 3, 'Cat': 0, 'Child': 2, 'Home  Alone ': 5, 'pet_id': 'APA-A-36893', '_id': ObjectId('5d8253057b3fd12bb5f79ce4')}
# {'pet_name': 'Bob Barker', 'pet_age': 6.5, 'pet_sex': 'Male', 'pet_breed': 'Retriever / Mixed Breed (Large)', 'pet_location': 'Foster', 'Dog': 3, 'Cat': 0, 'Child': 2, 'Home  Alone ': 3, 'pet_id': 'APA-A-57113', '_id': ObjectId('5d8253057b3fd12bb5f79ce5')}
# {'pet_name': 'Bethany', 'pet_age': 9.83, 'pet_sex': 'Female', 'pet_breed': 'Retriever, Black Labrador / Mix', 'pet_location': 'Foster', 'Dog': 2, 'Cat': 0, 'Child': 2, 'Home  Alone ': 4, 'pet_id': 'APA-A-57449', '_id': ObjectId('5d8253057b3fd12bb5f79ce6')}
# {'pet_name': 'Jasmine', 'pet_age': 5.08, 'pet_sex': 'Female', 'pet_breed': 'Retriever, Black Labrador / Mix', 'pet_location': 'TLAC', 'Dog': 1, 'Cat': 1, 'Child': 1, 'Home  Alone ': 5, 'pet_id': 'APA-A-53450', '_id': ObjectId('5d8253057b3fd12bb5f79ce7')}
# {'pet_name': 'Manning', 'pet_age': 4.33, 'pet_sex': 'Male', 'pet_breed': 'Retriever, Labrador / Shepherd, German', 'pet_location': 'TLAC', 'Dog': 2, 'Cat': 0, 'Child': 1, 'Home  Alone ': 3, 'pet_id': 'APA-A-58608', '_id': ObjectId('5d8253057b3fd12bb5f79ce8')}
# {'pet_name': 'Benito', 'pet_age': 4.67, 'pet_sex': 'Male', 'pet_breed': 'Terrier, Pit Bull / Mix', 'pet_location': 'Foster', 'Dog': 1, 'Cat': 0, 'Child': 1, 'Home  Alone ': 5, 'pet_id': 'APA-A-59189', '_id': ObjectId('5d8253057b3fd12bb5f79ce9')}
# {'pet_name': 'Princeton', 'pet_age': 7.42, 'pet_sex': 'Male', 'pet_breed': 'Terrier, Pit Bull / Mix', 'pet_location': 'TLAC', 'Dog': 3, 'Cat': 4, 'Child': 1, 'Home  Alone ': 4, 'pet_id': 'APA-A-59431', '_id': ObjectId('5d8253057b3fd12bb5f79cea')}
# {'pet_name': 'Cricket', 'pet_age': 7.92, 'pet_sex': 'Female', 'pet_breed': 'Retriever, Labrador / Mix', 'pet_location': 'Foster', 'Dog': 2, 'Cat': 2, 'Child': 3, 'Home  Alone ': 3, 'pet_id': 'APA-A-55345', '_id': ObjectId('5d8253057b3fd12bb5f79ceb')}
# {'pet_name': 'Toro', 'pet_age': 6.83, 'pet_sex': 'Male', 'pet_breed': 'Mixed Breed (Large) / Mix', 'pet_location': 'Foster', 'Dog': 2, 'Cat': 2, 'Child': 2, 'Home  Alone ': 3, 'pet_id': 'APA-A-60553', '_id': ObjectId('5d8253057b3fd12bb5f79cec')}
# {'pet_name': 'Migos', 'pet_age': 5.83, 'pet_sex': 'Male', 'pet_breed': 'Mixed Breed (Medium)', 'pet_location': 'Foster', 'Dog': 2, 'Cat': 2, 'Child': 3, 'Home  Alone ': 4, 'pet_id': 'APA-A-56868', '_id': ObjectId('5d8253057b3fd12bb5f79ced')}
# {'pet_name': 'Sally', 'pet_age': 3.67, 'pet_sex': 'Female', 'pet_breed': 'Mixed Breed (Medium)', 'pet_location': 'Foster', 'Dog': 2, 'Cat': 2, 'Child': 2, 'Home  Alone ': 4, 'pet_id': 'APA-A-61252', '_id': ObjectId('5d8253057b3fd12bb5f79cee')}
# {'pet_name': 'Josie', 'pet_age': 4.67, 'pet_sex': 'Female', 'pet_breed': 'Retriever / Mix', 'pet_location': 'Foster', 'Dog': 2, 'Cat': 1, 'Child': 1, 'Home  Alone ': 5, 'pet_id': 'APA-A-30844', '_id': ObjectId('5d8253057b3fd12bb5f79cef')}
# {'pet_name': 'Kline', 'pet_age': 2.67, 'pet_sex': 'Male', 'pet_breed': 'Cattle Dog / Mix', 'pet_location': 'TLAC', 'Dog': 1, 'Cat': 2, 'Child': 3, 'Home  Alone ': 3, 'pet_id': 'APA-A-61501', '_id': ObjectId('5d8253057b3fd12bb5f79cf0')}
# {'pet_name': 'Miguelito', 'pet_age': 8.08, 'pet_sex': 'Male', 'pet_breed': 'Chihuahua', 'pet_location': 'Tarrytown', 'Dog': 2, 'Cat': 0, 'Child': 2, 'Home  Alone ': 4, 'pet_id': 'APA-A-62339', '_id': ObjectId('5d8253057b3fd12bb5f79cf1')}
# {'pet_name': 'Tom Hanks', 'pet_age': 6.17, 'pet_sex': 'Male', 'pet_breed': 'Mixed Breed (Medium) / Mix', 'pet_location': 'Foster', 'Dog': 1, 'Cat': 0, 'Child': 2, 'Home  Alone ': 4, 'pet_id': 'APA-A-62575', '_id': ObjectId('5d8253057b3fd12bb5f79cf2')}
# {'pet_name': 'Floppy', 'pet_age': 4.83, 'pet_sex': 'Male', 'pet_breed': 'Mixed Breed (Medium)', 'pet_location': 'Foster', 'Dog': 1, 'Cat': 0, 'Child': 2, 'Home  Alone ': 4, 'pet_id': 'APA-A-55843', '_id': ObjectId('5d8253057b3fd12bb5f79cf3')}
# {'pet_name': 'Brady', 'pet_age': 11.0, 'pet_sex': 'Male', 'pet_breed': 'Mixed Breed (Medium) / Mix', 'pet_location': 'Foster', 'Dog': 4, 'Cat': 1, 'Child': 4, 'Home  Alone ': 3, 'pet_id': 'APA-A-64403', '_id': ObjectId('5d8253057b3fd12bb5f79cf4')}
# {'pet_name': 'Jenga', 'pet_age': 4.08, 'pet_sex': 'Female', 'pet_breed': 'Bulldog, American / Mix', 'pet_location': 'TLAC', 'Dog': 2, 'Cat': 2, 'Child': 2, 'Home  Alone ': 4, 'pet_id': 'APA-A-64409', '_id': ObjectId('5d8253057b3fd12bb5f79cf5')}
# {'pet_name': 'Mr Marbles', 'pet_age': 6.25, 'pet_sex': 'Male', 'pet_breed': 'Mixed Breed (Large)', 'pet_location': 'Foster', 'Dog': 1, 'Cat': 0, 'Child': 2, 'Home  Alone ': 5, 'pet_id': 'APA-A-64524', '_id': ObjectId('5d8253057b3fd12bb5f79cf6')}
# {'pet_name': 'Midnight', 'pet_age': 4.08, 'pet_sex': 'Female', 'pet_breed': 'Retriever, Black Labrador / Mix', 'pet_location': 'TLAC', 'Dog': 1, 'Cat': 1, 'Child': 2, 'Home  Alone ': 4, 'pet_id': 'APA-A-64567', '_id': ObjectId('5d8253057b3fd12bb5f79cf7')}
# {'pet_name': 'Clark', 'pet_age': 8.33, 'pet_sex': 'Male', 'pet_breed': 'Boxer / Mixed Breed (Medium)', 'pet_location': 'Foster', 'Dog': 2, 'Cat': 3, 'Child': 1, 'Home  Alone ': 5, 'pet_id': 'APA-A-41503', '_id': ObjectId('5d8253057b3fd12bb5f79cf8')}
# {'pet_name': 'Calvin', 'pet_age': 3.83, 'pet_sex': 'Male', 'pet_breed': 'Coonhound, Redbone / Mix', 'pet_location': 'Foster', 'Dog': 4, 'Cat': 4, 'Child': 2, 'Home  Alone ': 4, 'pet_id': 'APA-A-38221', '_id': ObjectId('5d8253057b3fd12bb5f79cf9')}
# {'pet_name': 'Brenda', 'pet_age': 7.08, 'pet_sex': 'Female', 'pet_breed': 'Dachshund / Mix', 'pet_location': 'Foster', 'Dog': 3, 'Cat': 4, 'Child': 0, 'Home  Alone ': 3, 'pet_id': 'APA-A-46986', '_id': ObjectId('5d8253057b3fd12bb5f79cfa')}
# {'pet_name': 'El Jefe', 'pet_age': 4.25, 'pet_sex': 'Male', 'pet_breed': 'Boxer / Mix', 'pet_location': 'TLAC', 'Dog': 3, 'Cat': 0, 'Child': 1, 'Home  Alone ': 4, 'pet_id': 'APA-A-49870', '_id': ObjectId('5d8253057b3fd12bb5f79cfb')}
# {'pet_name': 'Button', 'pet_age': 3.17, 'pet_sex': 'Male', 'pet_breed': 'Mixed Breed (Medium) / Mix', 'pet_location': 'TLAC', 'Dog': 1, 'Cat': 0, 'Child': 1, 'Home  Alone ': 4, 'pet_id': 'APA-A-57999', '_id': ObjectId('5d8253057b3fd12bb5f79cfc')}
# {'pet_name': 'Sarah', 'pet_age': 5.83, 'pet_sex': 'Female', 'pet_breed': 'Mixed Breed (Medium) / Mix', 'pet_location': 'Foster', 'Dog': 1, 'Cat': 2, 'Child': 2, 'Home  Alone ': 4, 'pet_id': 'APA-A-65267', '_id': ObjectId('5d8253057b3fd12bb5f79cfd')}
# {'pet_name': 'Sailor', 'pet_age': 3.33, 'pet_sex': 'Female', 'pet_breed': 'Terrier, Pit Bull / Mix', 'pet_location': 'TLAC', 'Dog': 1, 'Cat': 2, 'Child': 3, 'Home  Alone ': 5, 'pet_id': 'APA-A-55076', '_id': ObjectId('5d8253057b3fd12bb5f79cfe')}
# {'pet_name': 'Rhino', 'pet_age': 3.83, 'pet_sex': 'Male', 'pet_breed': 'Terrier, Pit Bull / Mix', 'pet_location': 'Foster', 'Dog': 3, 'Cat': 0, 'Child': 1, 'Home  Alone ': 5, 'pet_id': 'APA-A-59055', '_id': ObjectId('5d8253057b3fd12bb5f79cff')}
# {'pet_name': 'Tutu', 'pet_age': 5.67, 'pet_sex': 'Female', 'pet_breed': 'Mixed Breed (Medium) / Boxer', 'pet_location': 'TLAC', 'Dog': 1, 'Cat': 0, 'Child': 2, 'Home  Alone ': 1, 'pet_id': 'APA-A-38419', '_id': ObjectId('5d8253057b3fd12bb5f79d00')}
# {'pet_name': 'Churchill', 'pet_age': 3.83, 'pet_sex': 'Male', 'pet_breed': 'Terrier, Pit Bull / Mix', 'pet_location': 'Foster', 'Dog': 4, 'Cat': 0, 'Child': 4, 'Home  Alone ': 4, 'pet_id': 'APA-A-66283', '_id': ObjectId('5d8253057b3fd12bb5f79d01')}
# {'pet_name': 'John Rambo', 'pet_age': 4.33, 'pet_sex': 'Male', 'pet_breed': 'Retriever, Labrador / Mix', 'pet_location': 'TLAC', 'Dog': 2, 'Cat': 0, 'Child': 1, 'Home  Alone ': 4, 'pet_id': 'APA-A-55384', '_id': ObjectId('5d8253057b3fd12bb5f79d02')}
# {'pet_name': 'Lennon', 'pet_age': 4.75, 'pet_sex': 'Male', 'pet_breed': 'Shepherd, German / Mix', 'pet_location': 'TLAC', 'Dog': 3, 'Cat': 1, 'Child': 1, 'Home  Alone ': 2, 'pet_id': 'APA-A-62493', '_id': ObjectId('5d8253057b3fd12bb5f79d03')}
# {'pet_name': 'Mercedes', 'pet_age': 3.25, 'pet_sex': 'Female', 'pet_breed': 'Terrier, Pit Bull / Mix', 'pet_location': 'TLAC', 'Dog': 1, 'Cat': 2, 'Child': 2, 'Home  Alone ': 5, 'pet_id': 'APA-A-50261', '_id': ObjectId('5d8253057b3fd12bb5f79d04')}
# {'pet_name': 'Bel-air', 'pet_age': 2.08, 'pet_sex': 'Male', 'pet_breed': 'Mixed Breed (Medium) / Mix', 'pet_location': 'Foster', 'Dog': 3, 'Cat': 2, 'Child': 2, 'Home  Alone ': 5, 'pet_id': 'APA-A-50976', '_id': ObjectId('5d8253057b3fd12bb5f79d05')}
# {'pet_name': 'Albus', 'pet_age': 4.83, 'pet_sex': 'Male', 'pet_breed': 'Mixed Breed (Large) / Mix', 'pet_location': 'TLAC', 'Dog': 3, 'Cat': 0, 'Child': 1, 'Home  Alone ': 4, 'pet_id': 'APA-A-66640', '_id': ObjectId('5d8253057b3fd12bb5f79d06')}
# {'pet_name': 'Goldman', 'pet_age': 3.0, 'pet_sex': 'Male', 'pet_breed': 'Retriever, Yellow Labrador / Mixed Breed (Medium)', 'pet_location': 'TLAC', 'Dog': 1, 'Cat': 0, 'Child': 2, 'Home  Alone ': 4, 'pet_id': 'APA-A-66661', '_id': ObjectId('5d8253057b3fd12bb5f79d07')}
# {'pet_name': 'Nokie', 'pet_age': 8.25, 'pet_sex': 'Female', 'pet_breed': 'Terrier, American Staffordshire / Mix', 'pet_location': 'TLAC', 'Dog': 1, 'Cat': 2, 'Child': 2, 'Home  Alone ': 5, 'pet_id': 'APA-A-45661', '_id': ObjectId('5d8253057b3fd12bb5f79d08')}
# {'pet_name': 'Mack', 'pet_age': 7.75, 'pet_sex': 'Male', 'pet_breed': 'Mixed Breed (Medium)', 'pet_location': 'Foster', 'Dog': 1, 'Cat': 3, 'Child': 2, 'Home  Alone ': 4, 'pet_id': 'APA-A-36999', '_id': ObjectId('5d8253057b3fd12bb5f79d09')}
# {'pet_name': 'Minka', 'pet_age': 7.25, 'pet_sex': 'Female', 'pet_breed': 'Mixed Breed (Medium) / Mix', 'pet_location': 'Foster', 'Dog': 2, 'Cat': 1, 'Child': 1, 'Home  Alone ': 4, 'pet_id': 'APA-A-49408', '_id': ObjectId('5d8253057b3fd12bb5f79d0a')}
# {'pet_name': 'Fun Guy', 'pet_age': 4.83, 'pet_sex': 'Male', 'pet_breed': 'Chihuahua, Short Coat / Mix', 'pet_location': 'TLAC', 'Dog': 2, 'Cat': 2, 'Child': 1, 'Home  Alone ': 4, 'pet_id': 'APA-A-31118', '_id': ObjectId('5d8253057b3fd12bb5f79d0b')}
# {'pet_name': 'Lee', 'pet_age': 2.75, 'pet_sex': 'Male', 'pet_breed': 'Hound, Pharaoh / Mix', 'pet_location': 'TLAC', 'Dog': 3, 'Cat': 0, 'Child': 1, 'Home  Alone ': 3, 'pet_id': 'APA-A-69626', '_id': ObjectId('5d8253057b3fd12bb5f79d0c')}
# {'pet_name': 'Trigger', 'pet_age': 3.75, 'pet_sex': 'Male', 'pet_breed': 'Retriever, Chocolate Labrador / Mix', 'pet_location': 'TLAC', 'Dog': 2, 'Cat': 0, 'Child': 1, 'Home  Alone ': 4, 'pet_id': 'APA-A-69663', '_id': ObjectId('5d8253057b3fd12bb5f79d0d')}
# {'pet_name': 'Osito', 'pet_age': 3.83, 'pet_sex': 'Male', 'pet_breed': 'Chihuahua / Terrier', 'pet_location': 'Tarrytown', 'Dog': 3, 'Cat': 3, 'Child': 2, 'Home  Alone ': 5, 'pet_id': 'APA-A-56036', '_id': ObjectId('5d8253057b3fd12bb5f79d0e')}
# {'pet_name': 'Otis', 'pet_age': 3.67, 'pet_sex': 'Male', 'pet_breed': 'Akita / Mix', 'pet_location': 'TLAC', 'Dog': 1, 'Cat': 0, 'Child': 2, 'Home  Alone ': 4, 'pet_id': 'APA-A-69717', '_id': ObjectId('5d8253057b3fd12bb5f79d0f')}
# {'pet_name': 'Spot', 'pet_age': 6.17, 'pet_sex': 'Male', 'pet_breed': 'Terrier, Pit Bull / Bulldog, American', 'pet_location': 'TLAC', 'Dog': 1, 'Cat': 3, 'Child': 2, 'Home  Alone ': 4, 'pet_id': 'APA-A-55324', '_id': ObjectId('5d8253057b3fd12bb5f79d10')}
# {'pet_name': 'Cashew', 'pet_age': 2.0, 'pet_sex': 'Female', 'pet_breed': 'Basenji', 'pet_location': 'Foster', 'Dog': 2, 'Cat': 4, 'Child': 2, 'Home  Alone ': 4, 'pet_id': 'APA-A-70116', '_id': ObjectId('5d8253057b3fd12bb5f79d11')}
# {'pet_name': 'Mondo', 'pet_age': 6.83, 'pet_sex': 'Male', 'pet_breed': 'Hound / Mix', 'pet_location': 'Foster', 'Dog': 2, 'Cat': 0, 'Child': 1, 'Home  Alone ': 3, 'pet_id': 'APA-A-45387', '_id': ObjectId('5d8253057b3fd12bb5f79d12')}
# {'pet_name': 'Juanita', 'pet_age': 3.17, 'pet_sex': 'Female', 'pet_breed': 'Mixed Breed (Medium)', 'pet_location': 'Foster', 'Dog': 1, 'Cat': 1, 'Child': 2, 'Home  Alone ': 4, 'pet_id': 'APA-A-50809', '_id': ObjectId('5d8253057b3fd12bb5f79d13')}
# {'pet_name': 'Dennis', 'pet_age': 10.67, 'pet_sex': 'Male', 'pet_breed': 'Retriever, Labrador / Mix', 'pet_location': 'Foster', 'Dog': 2, 'Cat': 0, 'Child': 1, 'Home  Alone ': 5, 'pet_id': 'APA-A-25593', '_id': ObjectId('5d8253057b3fd12bb5f79d14')}
# {'pet_name': 'Rustler', 'pet_age': 6.58, 'pet_sex': 'Male', 'pet_breed': 'Mixed Breed (Medium) / Mix', 'pet_location': 'TLAC', 'Dog': 1, 'Cat': 1, 'Child': 2, 'Home  Alone ': 3, 'pet_id': 'APA-A-46692', '_id': ObjectId('5d8253057b3fd12bb5f79d15')}
# {'pet_name': 'Tommy', 'pet_age': 4.42, 'pet_sex': 'Male', 'pet_breed': 'Greyhound / Mix', 'pet_location': 'TLAC', 'Dog': 2, 'Cat': 0, 'Child': 1, 'Home  Alone ': 3, 'pet_id': 'APA-A-33573', '_id': ObjectId('5d8253057b3fd12bb5f79d16')}
# {'pet_name': 'Van Gogh', 'pet_age': 1.83, 'pet_sex': 'Male', 'pet_breed': 'Cattle Dog, Australian (Blue Heeler) / Mix', 'pet_location': 'TLAC', 'Dog': 2, 'Cat': 2, 'Child': 2, 'Home  Alone ': 3, 'pet_id': 'APA-A-66855', '_id': ObjectId('5d8253057b3fd12bb5f79d17')}
# {'pet_name': 'Queen Brenda', 'pet_age': 3.17, 'pet_sex': 'Female', 'pet_breed': 'Malinois, Belgian', 'pet_location': 'TLAC', 'Dog': 2, 'Cat': 0, 'Child': 1, 'Home  Alone ': 4, 'pet_id': 'APA-A-69494', '_id': ObjectId('5d8253057b3fd12bb5f79d18')}
# {'pet_name': 'Pinocchio', 'pet_age': 7.08, 'pet_sex': 'Male', 'pet_breed': 'Great Dane / Mix', 'pet_location': 'TLAC', 'Dog': 3, 'Cat': 0, 'Child': 2, 'Home  Alone ': 3, 'pet_id': 'APA-A-37920', '_id': ObjectId('5d8253057b3fd12bb5f79d19')}
# {'pet_name': 'Gelato', 'pet_age': 3.75, 'pet_sex': 'Male', 'pet_breed': 'Mixed Breed (Medium) / Mix', 'pet_location': 'TLAC', 'Dog': 1, 'Cat': 2, 'Child': 3, 'Home  Alone ': 4, 'pet_id': 'APA-A-56161', '_id': ObjectId('5d8253057b3fd12bb5f79d1a')}
# {'pet_name': 'Sullivan', 'pet_age': 2.5, 'pet_sex': 'Male', 'pet_breed': 'Shepherd, Anatolian / Chow Chow', 'pet_location': 'TLAC', 'Dog': 2, 'Cat': 0, 'Child': 2, 'Home  Alone ': 4, 'pet_id': 'APA-A-70891', '_id': ObjectId('5d8253057b3fd12bb5f79d1b')}
# {'pet_name': 'Alejandro', 'pet_age': 2.83, 'pet_sex': 'Male', 'pet_breed': 'Shepherd, German / Retriever, Labrador', 'pet_location': 'TLAC', 'Dog': 3, 'Cat': 0, 'Child': 1, 'Home  Alone ': 3, 'pet_id': 'APA-A-71075', '_id': ObjectId('5d8253057b3fd12bb5f79d1c')}
# {'pet_name': 'Stella', 'pet_age': 2.58, 'pet_sex': 'Female', 'pet_breed': 'Mixed Breed (Medium) / Mix', 'pet_location': 'TLAC', 'Dog': 2, 'Cat': 0, 'Child': 1, 'Home  Alone ': 4, 'pet_id': 'APA-A-50901', '_id': ObjectId('5d8253057b3fd12bb5f79d1d')}
# {'pet_name': 'Dino', 'pet_age': 6.67, 'pet_sex': 'Male', 'pet_breed': 'Retriever / Mix', 'pet_location': 'TLAC', 'Dog': 2, 'Cat': 0, 'Child': 1, 'Home  Alone ': 4, 'pet_id': 'APA-A-20065', '_id': ObjectId('5d8253057b3fd12bb5f79d1e')}
# {'pet_name': 'Rousseau', 'pet_age': 3.67, 'pet_sex': 'Female', 'pet_breed': 'Coonhound, Bluetick / Mix', 'pet_location': 'TLAC', 'Dog': 1, 'Cat': 0, 'Child': 3, 'Home  Alone ': 4, 'pet_id': 'APA-A-37585', '_id': ObjectId('5d8253057b3fd12bb5f79d1f')}
# {'pet_name': 'Raphael', 'pet_age': 5.17, 'pet_sex': 'Male', 'pet_breed': 'Terrier, American Staffordshire / Mix', 'pet_location': 'TLAC', 'Dog': 1, 'Cat': 0, 'Child': 0, 'Home  Alone ': 4, 'pet_id': 'APA-A-71317', '_id': ObjectId('5d8253057b3fd12bb5f79d20')}
# {'pet_name': 'Pumpkin', 'pet_age': 5.92, 'pet_sex': 'Female', 'pet_breed': 'Hound / Mix', 'pet_location': 'Foster', 'Dog': 2, 'Cat': 3, 'Child': 2, 'Home  Alone ': 3, 'pet_id': 'APA-A-71312', '_id': ObjectId('5d8253057b3fd12bb5f79d21')}
# {'pet_name': 'Mike Jonze', 'pet_age': 1.67, 'pet_sex': 'Male', 'pet_breed': 'Shepherd, German / Mix', 'pet_location': 'Foster', 'Dog': 4, 'Cat': 2, 'Child': 2, 'Home  Alone ': 4, 'pet_id': 'APA-A-55862', '_id': ObjectId('5d8253057b3fd12bb5f79d22')}
# {'pet_name': 'Dreamboat', 'pet_age': 1.42, 'pet_sex': 'Male', 'pet_breed': 'Chihuahua / Mix', 'pet_location': 'Tarrytown', 'Dog': 4, 'Cat': 0, 'Child': 2, 'Home  Alone ': 3, 'pet_id': 'APA-A-71409', '_id': ObjectId('5d8253057b3fd12bb5f79d23')}
# {'pet_name': 'Poof', 'pet_age': 3.42, 'pet_sex': 'Female', 'pet_breed': 'Chihuahua / Mix', 'pet_location': 'Tarrytown', 'Dog': 4, 'Cat': 0, 'Child': 2, 'Home  Alone ': 4, 'pet_id': 'APA-A-71406', '_id': ObjectId('5d8253057b3fd12bb5f79d24')}
# {'pet_name': 'Mariska', 'pet_age': 1.75, 'pet_sex': 'Female', 'pet_breed': 'Terrier, Pit Bull / Mix', 'pet_location': 'TLAC', 'Dog': 1, 'Cat': 0, 'Child': 0, 'Home  Alone ': 2, 'pet_id': 'APA-A-71315', '_id': ObjectId('5d8253057b3fd12bb5f79d25')}
# {'pet_name': 'Mr. Pickles', 'pet_age': 3.42, 'pet_sex': 'Male', 'pet_breed': 'Retriever, Black Labrador / Mix', 'pet_location': 'TLAC', 'Dog': 2, 'Cat': 0, 'Child': 3, 'Home  Alone ': 4, 'pet_id': 'APA-A-71498', '_id': ObjectId('5d8253057b3fd12bb5f79d26')}
# {'pet_name': 'Thanos', 'pet_age': 2.25, 'pet_sex': 'Male', 'pet_breed': 'Retriever, Chocolate Labrador', 'pet_location': 'TLAC', 'Dog': 2, 'Cat': 0, 'Child': 0, 'Home  Alone ': 0, 'pet_id': 'APA-A-71489', '_id': ObjectId('5d8253057b3fd12bb5f79d27')}
# {'pet_name': 'Lillian', 'pet_age': 5.08, 'pet_sex': 'Female', 'pet_breed': 'Terrier, American Staffordshire / Mix', 'pet_location': 'Foster', 'Dog': 2, 'Cat': 0, 'Child': 2, 'Home  Alone ': 5, 'pet_id': 'APA-A-32193', '_id': ObjectId('5d8253057b3fd12bb5f79d28')}
# {'pet_name': 'Prince Charming', 'pet_age': 4.0, 'pet_sex': 'Male', 'pet_breed': 'Terrier, Pit Bull / Retriever, Labrador', 'pet_location': 'TLAC', 'Dog': 2, 'Cat': 1, 'Child': 3, 'Home  Alone ': 3, 'pet_id': 'APA-A-51527', '_id': ObjectId('5d8253057b3fd12bb5f79d29')}
# {'pet_name': 'Amelia Bedelia', 'pet_age': 7.92, 'pet_sex': 'Female', 'pet_breed': 'Cattle Dog, Australian (Blue Heeler) / Collie, Border', 'pet_location': 'TLAC', 'Dog': 2, 'Cat': 0, 'Child': 2, 'Home  Alone ': 4, 'pet_id': 'APA-A-12490', '_id': ObjectId('5d8253057b3fd12bb5f79d2a')}
# {'pet_name': 'Revlon', 'pet_age': 2.75, 'pet_sex': 'Male', 'pet_breed': 'Bulldog, American / Mix', 'pet_location': 'TLAC', 'Dog': 1, 'Cat': 0, 'Child': 0, 'Home  Alone ': 4, 'pet_id': 'APA-A-71685', '_id': ObjectId('5d8253057b3fd12bb5f79d2b')}
# {'pet_name': 'Xena', 'pet_age': 6.58, 'pet_sex': 'Female', 'pet_breed': 'Terrier, Pit Bull / Mix', 'pet_location': 'TLAC', 'Dog': 1, 'Cat': 0, 'Child': 2, 'Home  Alone ': 3, 'pet_id': 'APA-A-19372', '_id': ObjectId('5d8253057b3fd12bb5f79d2c')}
# {'pet_name': 'Silent Bob', 'pet_age': 8.83, 'pet_sex': 'Male', 'pet_breed': 'Terrier, Pit Bull / Mix', 'pet_location': 'Foster', 'Dog': 4, 'Cat': 0, 'Child': 0, 'Home  Alone ': 0, 'pet_id': 'APA-A-6404', '_id': ObjectId('5d8253057b3fd12bb5f79d2d')}
# {'pet_name': 'Possum', 'pet_age': 1.75, 'pet_sex': 'Female', 'pet_breed': 'Terrier, Pit Bull / Mix', 'pet_location': 'Foster', 'Dog': 3, 'Cat': 0, 'Child': 3, 'Home  Alone ': 3, 'pet_id': 'APA-A-71745', '_id': ObjectId('5d8253057b3fd12bb5f79d2e')}
# {'pet_name': 'Howard', 'pet_age': 5.92, 'pet_sex': 'Male', 'pet_breed': 'Cattle Dog, Australian (Blue Heeler) / Mix', 'pet_location': 'Foster', 'Dog': 2, 'Cat': 0, 'Child': 1, 'Home  Alone ': 5, 'pet_id': 'APA-A-38468', '_id': ObjectId('5d8253057b3fd12bb5f79d2f')}
# {'pet_name': 'Gale', 'pet_age': 0.42, 'pet_sex': 'Male', 'pet_breed': 'Terrier, American Pit Bull', 'pet_location': 'TLAC', 'Dog': 4, 'Cat': 4, 'Child': 0, 'Home  Alone ': 2, 'pet_id': 'APA-A-71798', '_id': ObjectId('5d8253057b3fd12bb5f79d30')}
# {'pet_name': 'Reno', 'pet_age': 5.92, 'pet_sex': 'Male', 'pet_breed': 'Shepherd, Australian / Mix', 'pet_location': 'TLAC', 'Dog': 2, 'Cat': 0, 'Child': 2, 'Home  Alone ': 4, 'pet_id': 'APA-A-28011', '_id': ObjectId('5d8253057b3fd12bb5f79d31')}
# {'pet_name': 'Thomas', 'pet_age': 3.42, 'pet_sex': 'Male', 'pet_breed': 'Collie / Mix', 'pet_location': 'Foster', 'Dog': 4, 'Cat': 0, 'Child': 2, 'Home  Alone ': 1, 'pet_id': 'APA-A-71948', '_id': ObjectId('5d8253057b3fd12bb5f79d32')}
# {'pet_name': 'Zora', 'pet_age': 4.25, 'pet_sex': 'Female', 'pet_breed': 'Retriever, Black Labrador / Mix', 'pet_location': 'TLAC', 'Dog': 1, 'Cat': 0, 'Child': 1, 'Home  Alone ': 3, 'pet_id': 'APA-A-50244', '_id': ObjectId('5d8253057b3fd12bb5f79d33')}
# {'pet_name': 'Denny', 'pet_age': 2.33, 'pet_sex': 'Male', 'pet_breed': 'Terrier, American Staffordshire / Mix', 'pet_location': 'TLAC', 'Dog': 2, 'Cat': 0, 'Child': 0, 'Home  Alone ': 4, 'pet_id': 'APA-A-72390', '_id': ObjectId('5d8253057b3fd12bb5f79d34')}
# {'pet_name': 'Cookie', 'pet_age': 4.75, 'pet_sex': 'Male', 'pet_breed': 'Retriever, Labrador / Mix', 'pet_location': 'TLAC', 'Dog': 2, 'Cat': 2, 'Child': 1, 'Home  Alone ': 4, 'pet_id': 'APA-A-38108', '_id': ObjectId('5d8253057b3fd12bb5f79d35')}
# {'pet_name': 'Gomez', 'pet_age': 0.5, 'pet_sex': 'Male', 'pet_breed': 'Mixed Breed (Medium) / Mix', 'pet_location': 'Foster', 'Dog': 4, 'Cat': 3, 'Child': 2, 'Home  Alone ': 0, 'pet_id': 'APA-A-72785', '_id': ObjectId('5d8253057b3fd12bb5f79d36')}
# {'pet_name': 'Willis', 'pet_age': 2.33, 'pet_sex': 'Male', 'pet_breed': 'Retriever / Mix', 'pet_location': 'TLAC', 'Dog': 2, 'Cat': 0, 'Child': 0, 'Home  Alone ': 0, 'pet_id': 'APA-A-72839', '_id': ObjectId('5d8253057b3fd12bb5f79d37')}
# {'pet_name': 'Filbert', 'pet_age': 2.25, 'pet_sex': 'Male', 'pet_breed': 'Retriever, Labrador / Mix', 'pet_location': 'TLAC', 'Dog': 2, 'Cat': 1, 'Child': 0, 'Home  Alone ': 4, 'pet_id': 'APA-A-73063', '_id': ObjectId('5d8253057b3fd12bb5f79d38')}
# {'pet_name': 'Bohdi', 'pet_age': 1.33, 'pet_sex': 'Male', 'pet_breed': 'Shepherd, Anatolian', 'pet_location': 'TLAC', 'Dog': 3, 'Cat': 4, 'Child': 1, 'Home  Alone ': 4, 'pet_id': 'APA-A-72999', '_id': ObjectId('5d8253057b3fd12bb5f79d39')}
# {'pet_name': 'Zelda', 'pet_age': 3.25, 'pet_sex': 'Female', 'pet_breed': 'Terrier, American Pit Bull / Mix', 'pet_location': 'TLAC', 'Dog': 1, 'Cat': 0, 'Child': 0, 'Home  Alone ': 0, 'pet_id': 'APA-A-73067', '_id': ObjectId('5d8253057b3fd12bb5f79d3a')}
# {'pet_name': 'Jack', 'pet_age': 6.42, 'pet_sex': 'Male', 'pet_breed': 'Retriever, Labrador', 'pet_location': 'Foster', 'Dog': 0, 'Cat': 0, 'Child': 0, 'Home  Alone ': 4, 'pet_id': 'APA-A-73129', '_id': ObjectId('5d8253057b3fd12bb5f79d3b')}
# {'pet_name': 'Martin', 'pet_age': 2.75, 'pet_sex': 'Male', 'pet_breed': 'Terrier, Pit Bull / Mix', 'pet_location': 'Foster', 'Dog': 2, 'Cat': 2, 'Child': 2, 'Home  Alone ': 4, 'pet_id': 'APA-A-48650', '_id': ObjectId('5d8253057b3fd12bb5f79d3c')}
# {'pet_name': 'Marshall', 'pet_age': 1.75, 'pet_sex': 'Male', 'pet_breed': 'Catahoula Leopard Dog / Mix', 'pet_location': 'TLAC', 'Dog': 2, 'Cat': 0, 'Child': 0, 'Home  Alone ': 4, 'pet_id': 'APA-A-73283', '_id': ObjectId('5d8253057b3fd12bb5f79d3d')}
# {'pet_name': 'Brandy', 'pet_age': 6.08, 'pet_sex': 'Female', 'pet_breed': 'Terrier / Mix', 'pet_location': 'TLAC', 'Dog': 1, 'Cat': 0, 'Child': 3, 'Home  Alone ': 4, 'pet_id': 'APA-A-73287', '_id': ObjectId('5d8253057b3fd12bb5f79d3e')}
# {'pet_name': 'Triton', 'pet_age': 4.0, 'pet_sex': 'Male', 'pet_breed': 'Terrier, Pit Bull / Mix', 'pet_location': 'TLAC', 'Dog': 2, 'Cat': 2, 'Child': 2, 'Home  Alone ': 4, 'pet_id': 'APA-A-63194', '_id': ObjectId('5d8253057b3fd12bb5f79d3f')}
# {'pet_name': 'Elmo', 'pet_age': 1.25, 'pet_sex': 'Male', 'pet_breed': 'Retriever, Labrador / Mix', 'pet_location': 'TLAC', 'Dog': 4, 'Cat': 3, 'Child': 0, 'Home  Alone ': 3, 'pet_id': 'APA-A-73377', '_id': ObjectId('5d8253057b3fd12bb5f79d40')}
# {'pet_name': 'Maple', 'pet_age': 2.0, 'pet_sex': 'Male', 'pet_breed': 'Terrier, American Pit Bull / Mix', 'pet_location': 'TLAC', 'Dog': 3, 'Cat': 4, 'Child': 2, 'Home  Alone ': 3, 'pet_id': 'APA-A-59125', '_id': ObjectId('5d8253057b3fd12bb5f79d41')}
# {'pet_name': 'Harry Potter', 'pet_age': 6.83, 'pet_sex': 'Male', 'pet_breed': 'Chihuahua / Pomeranian', 'pet_location': 'Foster', 'Dog': 0, 'Cat': 0, 'Child': 0, 'Home  Alone ': 0, 'pet_id': 'APA-A-73448', '_id': ObjectId('5d8253057b3fd12bb5f79d42')}
# {'pet_name': 'Olympia', 'pet_age': 6.08, 'pet_sex': 'Female', 'pet_breed': 'Terrier, Pit Bull', 'pet_location': 'TLAC', 'Dog': 1, 'Cat': 2, 'Child': 2, 'Home  Alone ': 3, 'pet_id': 'APA-A-46924', '_id': ObjectId('5d8253057b3fd12bb5f79d43')}
# {'pet_name': 'Crackers', 'pet_age': 3.17, 'pet_sex': 'Male', 'pet_breed': 'Chihuahua / Mix', 'pet_location': 'Foster', 'Dog': 2, 'Cat': 0, 'Child': 0, 'Home  Alone ': 3, 'pet_id': 'APA-A-71256', '_id': ObjectId('5d8253057b3fd12bb5f79d44')}
# {'pet_name': 'Martha', 'pet_age': 8.0, 'pet_sex': 'Female', 'pet_breed': 'Retriever, Labrador / Mix', 'pet_location': 'TLAC', 'Dog': 1, 'Cat': 0, 'Child': 4, 'Home  Alone ': 5, 'pet_id': 'APA-A-12538', '_id': ObjectId('5d8253057b3fd12bb5f79d45')}
# {'pet_name': 'Charlie', 'pet_age': 1.25, 'pet_sex': 'Male', 'pet_breed': 'Terrier, Pit Bull', 'pet_location': 'Foster', 'Dog': 2, 'Cat': 0, 'Child': 2, 'Home  Alone ': 0, 'pet_id': 'APA-A-73509', '_id': ObjectId('5d8253057b3fd12bb5f79d46')}
# {'pet_name': 'Leonidas', 'pet_age': 7.17, 'pet_sex': 'Male', 'pet_breed': 'Terrier, Pit Bull / Mix', 'pet_location': 'Foster', 'Dog': 2, 'Cat': 1, 'Child': 3, 'Home  Alone ': 4, 'pet_id': 'APA-A-39606', '_id': ObjectId('5d8253057b3fd12bb5f79d47')}
# {'pet_name': 'Soup', 'pet_age': 2.5, 'pet_sex': 'Male', 'pet_breed': 'Bulldog, American / Mix', 'pet_location': 'TLAC', 'Dog': 2, 'Cat': 1, 'Child': 2, 'Home  Alone ': 4, 'pet_id': 'APA-A-71471', '_id': ObjectId('5d8253057b3fd12bb5f79d48')}
# {'pet_name': 'Big Caesar', 'pet_age': 10.42, 'pet_sex': 'Male', 'pet_breed': 'Dogo Argentino / Bulldog', 'pet_location': 'Foster', 'Dog': 1, 'Cat': 1, 'Child': 2, 'Home  Alone ': 5, 'pet_id': 'APA-A-32157', '_id': ObjectId('5d8253057b3fd12bb5f79d49')}
# {'pet_name': 'Shasta', 'pet_age': 2.33, 'pet_sex': 'Female', 'pet_breed': 'Dogo Argentino / Mix', 'pet_location': 'TLAC', 'Dog': 3, 'Cat': 0, 'Child': 0, 'Home  Alone ': 0, 'pet_id': 'APA-A-73778', '_id': ObjectId('5d8253057b3fd12bb5f79d4a')}
# {'pet_name': 'Serengeti', 'pet_age': 5.25, 'pet_sex': 'Female', 'pet_breed': 'Terrier, Pit Bull / Mix', 'pet_location': 'Foster', 'Dog': 4, 'Cat': 0, 'Child': 3, 'Home  Alone ': 4, 'pet_id': 'APA-A-73806', '_id': ObjectId('5d8253057b3fd12bb5f79d4b')}
# {'pet_name': 'Sir Mix-a-Lot', 'pet_age': 2.33, 'pet_sex': 'Male', 'pet_breed': 'Catahoula Leopard Dog', 'pet_location': 'TLAC', 'Dog': 2, 'Cat': 0, 'Child': 0, 'Home  Alone ': 0, 'pet_id': 'APA-A-73794', '_id': ObjectId('5d8253057b3fd12bb5f79d4c')}
# {'pet_name': 'Parker', 'pet_age': 3.25, 'pet_sex': 'Male', 'pet_breed': 'Terrier, Pit Bull / Mix', 'pet_location': 'TLAC', 'Dog': 3, 'Cat': 0, 'Child': 2, 'Home  Alone ': 4, 'pet_id': 'APA-A-73815', '_id': ObjectId('5d8253057b3fd12bb5f79d4d')}
# {'pet_name': 'Harmony', 'pet_age': 2.25, 'pet_sex': 'Female', 'pet_breed': 'Retriever, Labrador / Mix', 'pet_location': 'TLAC', 'Dog': 0, 'Cat': 1, 'Child': 0, 'Home  Alone ': 3, 'pet_id': 'APA-A-73813', '_id': ObjectId('5d8253057b3fd12bb5f79d4e')}
# {'pet_name': 'Todd', 'pet_age': 2.08, 'pet_sex': 'Male', 'pet_breed': 'Retriever / Mix', 'pet_location': 'TLAC', 'Dog': 2, 'Cat': 0, 'Child': 0, 'Home  Alone ': 4, 'pet_id': 'APA-A-62458', '_id': ObjectId('5d8253057b3fd12bb5f79d4f')}
# {'pet_name': 'Molly', 'pet_age': 5.25, 'pet_sex': 'Female', 'pet_breed': 'Terrier, Pit Bull', 'pet_location': 'TLAC', 'Dog': 0, 'Cat': 0, 'Child': 0, 'Home  Alone ': 0, 'pet_id': 'APA-A-73822', '_id': ObjectId('5d8253057b3fd12bb5f79d50')}
# {'pet_name': 'Altaria', 'pet_age': 1.33, 'pet_sex': 'Female', 'pet_breed': 'Hound, Plott', 'pet_location': 'TLAC', 'Dog': 0, 'Cat': 3, 'Child': 4, 'Home  Alone ': 3, 'pet_id': 'APA-A-73914', '_id': ObjectId('5d8253057b3fd12bb5f79d51')}
# {'pet_name': 'Scott', 'pet_age': 2.42, 'pet_sex': 'Male', 'pet_breed': 'Retriever, Black Labrador / Mixed Breed (Medium)', 'pet_location': 'TLAC', 'Dog': 2, 'Cat': 2, 'Child': 2, 'Home  Alone ': 3, 'pet_id': 'APA-A-71768', '_id': ObjectId('5d8253057b3fd12bb5f79d52')}
# {'pet_name': 'Flute', 'pet_age': 1.25, 'pet_sex': 'Female', 'pet_breed': 'Pyrenees, Great / Retriever, Labrador', 'pet_location': 'TLAC', 'Dog': 3, 'Cat': 3, 'Child': 3, 'Home  Alone ': 4, 'pet_id': 'APA-A-73987', '_id': ObjectId('5d8253057b3fd12bb5f79d53')}
# {'pet_name': 'Zephyr', 'pet_age': 6.25, 'pet_sex': 'Male', 'pet_breed': 'Terrier, Bull / Chinese Shar-Pei', 'pet_location': 'TLAC', 'Dog': 2, 'Cat': 0, 'Child': 0, 'Home  Alone ': 4, 'pet_id': 'APA-A-73983', '_id': ObjectId('5d8253057b3fd12bb5f79d54')}
# {'pet_name': 'Sage', 'pet_age': 4.25, 'pet_sex': 'Female', 'pet_breed': 'Bulldog, American', 'pet_location': 'TLAC', 'Dog': 2, 'Cat': 0, 'Child': 0, 'Home  Alone ': 0, 'pet_id': 'APA-A-73981', '_id': ObjectId('5d8253057b3fd12bb5f79d55')}
# {'pet_name': 'Tempo', 'pet_age': 0.17, 'pet_sex': 'Male', 'pet_breed': 'Retriever, Labrador / Mix', 'pet_location': 'Foster', 'Dog': 4, 'Cat': 4, 'Child': 0, 'Home  Alone ': 2, 'pet_id': 'APA-A-74046', '_id': ObjectId('5d8253057b3fd12bb5f79d56')}
# {'pet_name': 'Melody', 'pet_age': 0.17, 'pet_sex': 'Male', 'pet_breed': 'Retriever, Labrador / Mix', 'pet_location': 'Foster', 'Dog': 4, 'Cat': 4, 'Child': 0, 'Home  Alone ': 2, 'pet_id': 'APA-A-74049', '_id': ObjectId('5d8253057b3fd12bb5f79d57')}
# {'pet_name': 'Chicklet', 'pet_age': 4.17, 'pet_sex': 'Female', 'pet_breed': 'Terrier, Pit Bull', 'pet_location': 'Foster', 'Dog': 3, 'Cat': 0, 'Child': 2, 'Home  Alone ': 4, 'pet_id': 'APA-A-74051', '_id': ObjectId('5d8253057b3fd12bb5f79d58')}
# {'pet_name': 'Sophia', 'pet_age': 8.17, 'pet_sex': 'Female', 'pet_breed': 'Chihuahua', 'pet_location': 'Foster', 'Dog': 3, 'Cat': 4, 'Child': 0, 'Home  Alone ': 4, 'pet_id': 'APA-A-74053', '_id': ObjectId('5d8253057b3fd12bb5f79d59')}
# {'pet_name': 'James Bond', 'pet_age': 4.25, 'pet_sex': 'Male', 'pet_breed': 'Mixed Breed (Medium)', 'pet_location': 'TLAC', 'Dog': 3, 'Cat': 0, 'Child': 0, 'Home  Alone ': 4, 'pet_id': 'APA-A-74132', '_id': ObjectId('5d8253057b3fd12bb5f79d5a')}
# {'pet_name': 'Elmer', 'pet_age': 2.25, 'pet_sex': 'Male', 'pet_breed': 'Retriever, Labrador / Pointer', 'pet_location': 'TLAC', 'Dog': 3, 'Cat': 0, 'Child': 0, 'Home  Alone ': 4, 'pet_id': 'APA-A-74126', '_id': ObjectId('5d8253057b3fd12bb5f79d5b')}
# {'pet_name': 'Snortlette', 'pet_age': 3.25, 'pet_sex': 'Female', 'pet_breed': 'Terrier, American Pit Bull / Terrier, American Staffordshire', 'pet_location': 'TLAC', 'Dog': 2, 'Cat': 2, 'Child': 3, 'Home  Alone ': 4, 'pet_id': 'APA-A-74140', '_id': ObjectId('5d8253057b3fd12bb5f79d5c')}
# {'pet_name': 'Margrrrita', 'pet_age': 10.17, 'pet_sex': 'Female', 'pet_breed': 'Poodle, Miniature', 'pet_location': 'Foster', 'Dog': 4, 'Cat': 4, 'Child': 4, 'Home  Alone ': 2, 'pet_id': 'APA-A-74099', '_id': ObjectId('5d8253057b3fd12bb5f79d5d')}
# {'pet_name': 'Bette', 'pet_age': 2.17, 'pet_sex': 'Female', 'pet_breed': 'Husky / Mix', 'pet_location': 'TLAC', 'Dog': 1, 'Cat': 0, 'Child': 2, 'Home  Alone ': 4, 'pet_id': 'APA-A-74082', '_id': ObjectId('5d8253057b3fd12bb5f79d5e')}
# {'pet_name': 'Rosebud', 'pet_age': 0.83, 'pet_sex': 'Female', 'pet_breed': 'Great Dane / Retriever, Black Labrador', 'pet_location': 'Foster', 'Dog': 4, 'Cat': 4, 'Child': 0, 'Home  Alone ': 3, 'pet_id': 'APA-A-74064', '_id': ObjectId('5d8253057b3fd12bb5f79d5f')}
# {'pet_name': 'Schroeder', 'pet_age': 1.83, 'pet_sex': 'Male', 'pet_breed': 'Bernese Mountain Dog / Mix', 'pet_location': 'TLAC', 'Dog': 2, 'Cat': 0, 'Child': 1, 'Home  Alone ': 0, 'pet_id': 'APA-A-65855', '_id': ObjectId('5d8253057b3fd12bb5f79d60')}
# {'pet_name': 'Joshua', 'pet_age': 2.83, 'pet_sex': 'Male', 'pet_breed': 'Collie, Border / Mix', 'pet_location': 'TLAC', 'Dog': 2, 'Cat': 0, 'Child': 1, 'Home  Alone ': 3, 'pet_id': 'APA-A-66365', '_id': ObjectId('5d8253057b3fd12bb5f79d61')}
# {'pet_name': 'Pippen', 'pet_age': 3.5, 'pet_sex': 'Male', 'pet_breed': 'Retriever, Labrador / Mix', 'pet_location': 'TLAC', 'Dog': 4, 'Cat': 3, 'Child': 2, 'Home  Alone ': 4, 'pet_id': 'APA-A-39544', '_id': ObjectId('5d8253057b3fd12bb5f79d62')}
# {'pet_name': 'Mr. Squiggles', 'pet_age': 0.92, 'pet_sex': 'Male', 'pet_breed': 'Shepherd, German / Mix', 'pet_location': 'TLAC', 'Dog': 3, 'Cat': 0, 'Child': 0, 'Home  Alone ': 3, 'pet_id': 'APA-A-74279', '_id': ObjectId('5d8253057b3fd12bb5f79d63')}
# {'pet_name': 'Elton', 'pet_age': 0.83, 'pet_sex': 'Male', 'pet_breed': 'Retriever, Labrador / Mix', 'pet_location': 'Foster', 'Dog': 4, 'Cat': 0, 'Child': 4, 'Home  Alone ': 2, 'pet_id': 'APA-A-74250', '_id': ObjectId('5d8253057b3fd12bb5f79d64')}
# {'pet_name': 'Prince Harry', 'pet_age': 2.17, 'pet_sex': 'Male', 'pet_breed': 'Mixed Breed (Medium)', 'pet_location': 'Foster', 'Dog': 0, 'Cat': 0, 'Child': 0, 'Home  Alone ': 0, 'pet_id': 'APA-A-74276', '_id': ObjectId('5d8253057b3fd12bb5f79d65')}
# {'pet_name': 'Sugar', 'pet_age': 1.33, 'pet_sex': 'Female', 'pet_breed': 'Pyrenees, Great / Mix', 'pet_location': 'Foster', 'Dog': 0, 'Cat': 0, 'Child': 0, 'Home  Alone ': 0, 'pet_id': 'APA-A-74277', '_id': ObjectId('5d8253057b3fd12bb5f79d66')}
# {'pet_name': 'Spice', 'pet_age': 1.33, 'pet_sex': 'Female', 'pet_breed': 'Pyrenees, Great / Mix', 'pet_location': 'Foster', 'Dog': 3, 'Cat': 0, 'Child': 2, 'Home  Alone ': 3, 'pet_id': 'APA-A-74278', '_id': ObjectId('5d8253057b3fd12bb5f79d67')}
# {'pet_name': 'Juno', 'pet_age': 1.17, 'pet_sex': 'Female', 'pet_breed': 'Chihuahua', 'pet_location': 'Foster', 'Dog': 0, 'Cat': 0, 'Child': 0, 'Home  Alone ': 0, 'pet_id': 'APA-A-74282', '_id': ObjectId('5d8253057b3fd12bb5f79d68')}
# {'pet_name': 'Paco', 'pet_age': 5.5, 'pet_sex': 'Male', 'pet_breed': 'Terrier / Mix', 'pet_location': 'TLAC', 'Dog': 3, 'Cat': 2, 'Child': 2, 'Home  Alone ': 4, 'pet_id': 'APA-A-26694', '_id': ObjectId('5d8253057b3fd12bb5f79d69')}
# {'pet_name': 'Felipe', 'pet_age': 3.58, 'pet_sex': 'Male', 'pet_breed': 'Cattle Dog, Australian (Red Heeler) / Mix', 'pet_location': 'TLAC', 'Dog': 2, 'Cat': 0, 'Child': 2, 'Home  Alone ': 3, 'pet_id': 'APA-A-40577', '_id': ObjectId('5d8253057b3fd12bb5f79d6a')}
# {'pet_name': 'Tip', 'pet_age': 12.17, 'pet_sex': 'Male', 'pet_breed': 'Chihuahua, Short Coat / Mix', 'pet_location': 'Foster', 'Dog': 3, 'Cat': 3, 'Child': 2, 'Home  Alone ': 3, 'pet_id': 'APA-A-74352', '_id': ObjectId('5d8253057b3fd12bb5f79d6b')}
# {'pet_name': 'Master', 'pet_age': 0.33, 'pet_sex': 'Male', 'pet_breed': 'Cattle Dog, Australian (Red Heeler)', 'pet_location': 'Foster Home', 'Dog': 4, 'Cat': 4, 'Child': 0, 'Home  Alone ': 2, 'pet_id': 'APA-A-74380', '_id': ObjectId('5d8253057b3fd12bb5f79d6c')}
# {'pet_name': 'Amara', 'pet_age': 0.33, 'pet_sex': 'Female', 'pet_breed': 'Mixed Breed (Large)', 'pet_location': 'Foster', 'Dog': 4, 'Cat': 4, 'Child': 0, 'Home  Alone ': 2, 'pet_id': 'APA-A-74418', '_id': ObjectId('5d8253057b3fd12bb5f79d6d')}
# {'pet_name': 'Beckett', 'pet_age': 0.33, 'pet_sex': 'Male', 'pet_breed': 'Mixed Breed (Large)', 'pet_location': 'Foster', 'Dog': 4, 'Cat': 4, 'Child': 0, 'Home  Alone ': 2, 'pet_id': 'APA-A-74420', '_id': ObjectId('5d8253057b3fd12bb5f79d6e')}
# {'pet_name': 'Cersei', 'pet_age': 0.17, 'pet_sex': 'Female', 'pet_breed': 'Chihuahua', 'pet_location': 'Foster', 'Dog': 4, 'Cat': 4, 'Child': 0, 'Home  Alone ': 2, 'pet_id': 'APA-A-74459', '_id': ObjectId('5d8253057b3fd12bb5f79d6f')}
# {'pet_name': 'Jessie', 'pet_age': 2.17, 'pet_sex': 'Female', 'pet_breed': 'Retriever / Mix', 'pet_location': 'TLAC', 'Dog': 0, 'Cat': 0, 'Child': 0, 'Home  Alone ': 0, 'pet_id': 'APA-A-74437', '_id': ObjectId('5d8253057b3fd12bb5f79d70')}
# {'pet_name': 'Sir Wigglesworth', 'pet_age': 2.5, 'pet_sex': 'Male', 'pet_breed': 'Terrier, Pit Bull / Mix', 'pet_location': 'TLAC', 'Dog': 2, 'Cat': 0, 'Child': 0, 'Home  Alone ': 0, 'pet_id': 'APA-A-74435', '_id': ObjectId('5d8253057b3fd12bb5f79d71')}
# {'pet_name': 'Connie', 'pet_age': 2.17, 'pet_sex': 'Female', 'pet_breed': 'Chihuahua / Mix', 'pet_location': 'Foster', 'Dog': 3, 'Cat': 0, 'Child': 0, 'Home  Alone ': 4, 'pet_id': 'APA-A-74534', '_id': ObjectId('5d8253057b3fd12bb5f79d72')}
# {'pet_name': 'Scarlett', 'pet_age': 1.5, 'pet_sex': 'Female', 'pet_breed': 'Retriever, Labrador / American Blue Heeler', 'pet_location': 'Foster', 'Dog': 0, 'Cat': 0, 'Child': 3, 'Home  Alone ': 4, 'pet_id': 'APA-A-74535', '_id': ObjectId('5d8253057b3fd12bb5f79d73')}
# {'pet_name': 'Dude', 'pet_age': 2.67, 'pet_sex': 'Male', 'pet_breed': 'Retriever, Labrador / Boxer', 'pet_location': 'TLAC', 'Dog': 2, 'Cat': 0, 'Child': 0, 'Home  Alone ': 4, 'pet_id': 'APA-A-74562', '_id': ObjectId('5d8253057b3fd12bb5f79d74')}
# {'pet_name': 'Precious', 'pet_age': 2.08, 'pet_sex': 'Female', 'pet_breed': 'Black Mouth Cur', 'pet_location': 'Foster', 'Dog': 0, 'Cat': 4, 'Child': 0, 'Home  Alone ': 4, 'pet_id': 'APA-A-74598', '_id': ObjectId('5d8253057b3fd12bb5f79d75')}
# {'pet_name': 'Flabbergasted', 'pet_age': 0.17, 'pet_sex': 'Female', 'pet_breed': 'Black Mouth Cur', 'pet_location': 'Foster', 'Dog': 4, 'Cat': 4, 'Child': 0, 'Home  Alone ': 2, 'pet_id': 'APA-A-74607', '_id': ObjectId('5d8253057b3fd12bb5f79d76')}
# {'pet_name': 'Ravioli', 'pet_age': 5.5, 'pet_sex': 'Male', 'pet_breed': 'Shepherd / Mix', 'pet_location': 'TLAC', 'Dog': 3, 'Cat': 3, 'Child': 1, 'Home  Alone ': 4, 'pet_id': 'APA-A-24854', '_id': ObjectId('5d8253057b3fd12bb5f79d77')}
# {'pet_name': 'Moxi', 'pet_age': 2.25, 'pet_sex': 'Female', 'pet_breed': 'Chinese Shar-Pei / Mix', 'pet_location': 'TLAC', 'Dog': 2, 'Cat': 0, 'Child': 0, 'Home  Alone ': 0, 'pet_id': 'APA-A-74632', '_id': ObjectId('5d8253057b3fd12bb5f79d78')}
# {'pet_name': 'Joker', 'pet_age': 3.17, 'pet_sex': 'Male', 'pet_breed': 'Mastiff / Mix', 'pet_location': 'TLAC', 'Dog': 2, 'Cat': 0, 'Child': 2, 'Home  Alone ': 4, 'pet_id': 'APA-A-74655', '_id': ObjectId('5d8253057b3fd12bb5f79d79')}
# {'pet_name': 'Vickie', 'pet_age': 8.0, 'pet_sex': 'Female', 'pet_breed': 'Cattle Dog / Mix', 'pet_location': 'TLAC', 'Dog': 2, 'Cat': 4, 'Child': 2, 'Home  Alone ': 4, 'pet_id': 'APA-A-51960', '_id': ObjectId('5d8253057b3fd12bb5f79d7a')}
# {'pet_name': 'Pepper', 'pet_age': 3.17, 'pet_sex': 'Female', 'pet_breed': 'Chihuahua', 'pet_location': 'Foster', 'Dog': 4, 'Cat': 0, 'Child': 3, 'Home  Alone ': 4, 'pet_id': 'APA-A-74658', '_id': ObjectId('5d8253057b3fd12bb5f79d7b')}
# {'pet_name': 'Falcon', 'pet_age': 2.58, 'pet_sex': 'Male', 'pet_breed': 'Terrier, Pit Bull / Mix', 'pet_location': 'TLAC', 'Dog': 3, 'Cat': 0, 'Child': 3, 'Home  Alone ': 3, 'pet_id': 'APA-A-74684', '_id': ObjectId('5d8253057b3fd12bb5f79d7c')}
# {'pet_name': 'Sequoia', 'pet_age': 3.17, 'pet_sex': 'Female', 'pet_breed': 'Terrier, Pit Bull', 'pet_location': 'Foster', 'Dog': 0, 'Cat': 0, 'Child': 0, 'Home  Alone ': 4, 'pet_id': 'APA-A-74659', '_id': ObjectId('5d8253057b3fd12bb5f79d7d')}
# {'pet_name': 'Falcon', 'pet_age': 2.58, 'pet_sex': 'Male', 'pet_breed': 'Terrier, Pit Bull / Mix', 'pet_location': 'TLAC', 'Dog': 3, 'Cat': 0, 'Child': 3, 'Home  Alone ': 3, 'pet_id': 'APA-A-74684', '_id': ObjectId('5d8253057b3fd12bb5f79d7e')}
# {'pet_name': 'Layla', 'pet_age': 8.67, 'pet_sex': 'Female', 'pet_breed': 'Chow Chow / Retriever, Labrador', 'pet_location': 'Foster', 'Dog': 4, 'Cat': 0, 'Child': 3, 'Home  Alone ': 4, 'pet_id': 'APA-A-74719', '_id': ObjectId('5d8253057b3fd12bb5f79d7f')}
# {'pet_name': 'Shorty', 'pet_age': 3.0, 'pet_sex': 'Male', 'pet_breed': 'Terrier, American Staffordshire', 'pet_location': 'Foster', 'Dog': 3, 'Cat': 0, 'Child': 2, 'Home  Alone ': 4, 'pet_id': 'APA-A-71316', '_id': ObjectId('5d8253057b3fd12bb5f79d80')}
# {'pet_name': 'Black Diamond', 'pet_age': 0.08, 'pet_sex': 'Male', 'pet_breed': 'Chihuahua', 'pet_location': 'Foster', 'Dog': 4, 'Cat': 4, 'Child': 0, 'Home  Alone ': 2, 'pet_id': 'APA-A-74800', '_id': ObjectId('5d8253057b3fd12bb5f79d81')}
# {'pet_name': 'Mr. Fantastic', 'pet_age': 3.67, 'pet_sex': 'Male', 'pet_breed': 'Terrier, American Staffordshire / Mix', 'pet_location': 'TLAC', 'Dog': 2, 'Cat': 0, 'Child': 1, 'Home  Alone ': 5, 'pet_id': 'APA-A-55509', '_id': ObjectId('5d8253057b3fd12bb5f79d82')}
# {'pet_name': 'Paco Taco', 'pet_age': 0.08, 'pet_sex': 'Male', 'pet_breed': 'Chihuahua / Mix', 'pet_location': 'Foster', 'Dog': 4, 'Cat': 4, 'Child': 0, 'Home  Alone ': 2, 'pet_id': 'APA-A-74805', '_id': ObjectId('5d8253057b3fd12bb5f79d83')}
# {'pet_name': 'Pablo Pablano', 'pet_age': 0.08, 'pet_sex': 'Male', 'pet_breed': 'Chihuahua / Mix', 'pet_location': 'Foster', 'Dog': 4, 'Cat': 4, 'Child': 0, 'Home  Alone ': 2, 'pet_id': 'APA-A-74807', '_id': ObjectId('5d8253057b3fd12bb5f79d84')}
# {'pet_name': 'Elvis Parsley', 'pet_age': 0.08, 'pet_sex': 'Male', 'pet_breed': 'Chihuahua / Mix', 'pet_location': 'Foster', 'Dog': 4, 'Cat': 4, 'Child': 0, 'Home  Alone ': 2, 'pet_id': 'APA-A-74808', '_id': ObjectId('5d8253057b3fd12bb5f79d85')}
# {'pet_name': 'Hamlett', 'pet_age': 0.08, 'pet_sex': 'Male', 'pet_breed': 'Chihuahua / Mix', 'pet_location': 'Foster', 'Dog': 4, 'Cat': 4, 'Child': 0, 'Home  Alone ': 2, 'pet_id': 'APA-A-74809', '_id': ObjectId('5d8253057b3fd12bb5f79d86')}
# {'pet_name': 'Bolo Tie', 'pet_age': 0.25, 'pet_sex': 'Male', 'pet_breed': 'Shepherd, German / Mix', 'pet_location': 'Foster', 'Dog': 4, 'Cat': 4, 'Child': 0, 'Home  Alone ': 2, 'pet_id': 'APA-A-74782', '_id': ObjectId('5d8253057b3fd12bb5f79d87')}
# {'pet_name': 'Billy', 'pet_age': 4.25, 'pet_sex': 'Male', 'pet_breed': 'Terrier, Pit Bull / Mix', 'pet_location': 'Foster', 'Dog': 4, 'Cat': 0, 'Child': 2, 'Home  Alone ': 4, 'pet_id': 'APA-A-74843', '_id': ObjectId('5d8253057b3fd12bb5f79d88')}
# {'pet_name': 'Jagger', 'pet_age': 4.08, 'pet_sex': 'Male', 'pet_breed': 'Terrier, American Pit Bull / Boxer', 'pet_location': 'TLAC', 'Dog': 2, 'Cat': 0, 'Child': 0, 'Home  Alone ': 4, 'pet_id': 'APA-A-74844', '_id': ObjectId('5d8253057b3fd12bb5f79d89')}
# {'pet_name': 'Odette', 'pet_age': 10.08, 'pet_sex': 'Female', 'pet_breed': 'Chihuahua', 'pet_location': 'Foster', 'Dog': 0, 'Cat': 0, 'Child': 3, 'Home  Alone ': 4, 'pet_id': 'APA-A-74838', '_id': ObjectId('5d8253057b3fd12bb5f79d8a')}
# {'pet_name': 'Ben', 'pet_age': 6.5, 'pet_sex': 'Male', 'pet_breed': 'Terrier, Pit Bull / Mix', 'pet_location': 'TLAC', 'Dog': 0, 'Cat': 0, 'Child': 2, 'Home  Alone ': 0, 'pet_id': 'APA-A-74865', '_id': ObjectId('5d8253057b3fd12bb5f79d8b')}
# {'pet_name': 'Elizabeth', 'pet_age': 0.08, 'pet_sex': 'Female', 'pet_breed': 'Shepherd, Anatolian', 'pet_location': 'Foster', 'Dog': 4, 'Cat': 4, 'Child': 0, 'Home  Alone ': 2, 'pet_id': 'APA-A-75009', '_id': ObjectId('5d8253057b3fd12bb5f79d8c')}
# {'pet_name': 'Chesney', 'pet_age': 6.08, 'pet_sex': 'Female', 'pet_breed': 'Retriever, Labrador', 'pet_location': 'Foster', 'Dog': 3, 'Cat': 0, 'Child': 0, 'Home  Alone ': 0, 'pet_id': 'APA-A-74899', '_id': ObjectId('5d8253057b3fd12bb5f79d8d')}
# {'pet_name': 'Tinka', 'pet_age': 3.58, 'pet_sex': 'Female', 'pet_breed': 'Mastiff / Mix', 'pet_location': 'TLAC', 'Dog': 2, 'Cat': 4, 'Child': 0, 'Home  Alone ': 0, 'pet_id': 'APA-A-74894', '_id': ObjectId('5d8253057b3fd12bb5f79d8e')}
# {'pet_name': 'Kent', 'pet_age': 7.83, 'pet_sex': 'Male', 'pet_breed': 'Cattle Dog, Australian (Blue Heeler) / Mix', 'pet_location': 'TLAC', 'Dog': 2, 'Cat': 2, 'Child': 3, 'Home  Alone ': 3, 'pet_id': 'APA-A-45985', '_id': ObjectId('5d8253057b3fd12bb5f79d8f')}
# {'pet_name': 'Sabelia', 'pet_age': 0.08, 'pet_sex': 'Female', 'pet_breed': 'Terrier, Pit Bull', 'pet_location': 'Foster', 'Dog': 4, 'Cat': 4, 'Child': 0, 'Home  Alone ': 2, 'pet_id': 'APA-A-74926', '_id': ObjectId('5d8253057b3fd12bb5f79d90')}
# {'pet_name': 'Sagara', 'pet_age': 0.08, 'pet_sex': 'Female', 'pet_breed': 'Terrier, Pit Bull', 'pet_location': 'Foster', 'Dog': 4, 'Cat': 4, 'Child': 0, 'Home  Alone ': 2, 'pet_id': 'APA-A-74927', '_id': ObjectId('5d8253057b3fd12bb5f79d91')}
# {'pet_name': 'Calab', 'pet_age': 3.08, 'pet_sex': 'Male', 'pet_breed': 'Chihuahua, Short Coat / Mix', 'pet_location': 'Tarrytown', 'Dog': 3, 'Cat': 0, 'Child': 3, 'Home  Alone ': 2, 'pet_id': 'APA-A-43151', '_id': ObjectId('5d8253057b3fd12bb5f79d92')}
# {'pet_name': 'Sapphire', 'pet_age': 0.08, 'pet_sex': 'Female', 'pet_breed': 'Terrier, Pit Bull', 'pet_location': 'Foster', 'Dog': 4, 'Cat': 4, 'Child': 0, 'Home  Alone ': 2, 'pet_id': 'APA-A-74928', '_id': ObjectId('5d8253057b3fd12bb5f79d93')}
# {'pet_name': 'Seki', 'pet_age': 0.08, 'pet_sex': 'Female', 'pet_breed': 'Terrier, Pit Bull', 'pet_location': 'Foster', 'Dog': 4, 'Cat': 4, 'Child': 0, 'Home  Alone ': 2, 'pet_id': 'APA-A-74929', '_id': ObjectId('5d8253057b3fd12bb5f79d94')}
# {'pet_name': 'Seki', 'pet_age': 0.08, 'pet_sex': 'Female', 'pet_breed': 'Terrier, Pit Bull', 'pet_location': 'Foster', 'Dog': 4, 'Cat': 4, 'Child': 0, 'Home  Alone ': 2, 'pet_id': 'APA-A-74929', '_id': ObjectId('5d8253057b3fd12bb5f79d95')}
# {'pet_name': 'Shyanna', 'pet_age': 0.08, 'pet_sex': 'Female', 'pet_breed': 'Terrier, Pit Bull', 'pet_location': 'Foster', 'Dog': 4, 'Cat': 4, 'Child': 0, 'Home  Alone ': 2, 'pet_id': 'APA-A-74930', '_id': ObjectId('5d8253057b3fd12bb5f79d96')}
# ...
# {'pet_name': 'Freddie Mercury', 'pet_age': 1.0, 'pet_sex': 'Male', 'pet_breed': 'Terrier, Pit Bull / Mix', 'pet_location': 'TLAC', 'Dog': 0, 'Cat': 0, 'Child': 0, 'Home  Alone ': 0, 'pet_id': 'APA-A-76056', '_id': ObjectId('5d8253057b3fd12bb5f79e0f')}
# {'pet_name': 'India Opal', 'pet_age': 1.08, 'pet_sex': 'Female', 'pet_breed': 'Blue Lacy / Mix', 'pet_location': 'TLAC', 'Dog': 3, 'Cat': 0, 'Child': 0, 'Home  Alone ': 0, 'pet_id': 'APA-A-75482', '_id': ObjectId('5d8253057b3fd12bb5f79e10')}
# {'pet_name': 'Aubrey', 'pet_age': 6.0, 'pet_sex': 'Female', 'pet_breed': 'Pointer / Mix', 'pet_location': 'Foster', 'Dog': 0, 'Cat': 0, 'Child': 0, 'Home  Alone ': 0, 'pet_id': 'APA-A-76062', '_id': ObjectId('5d8253057b3fd12bb5f79e11')}
# {'pet_name': 'Ringo', 'pet_age': 1.5, 'pet_sex': 'Male', 'pet_breed': 'Rottweiler', 'pet_location': 'Foster', 'Dog': 0, 'Cat': 0, 'Child': 0, 'Home  Alone ': 3, 'pet_id': 'APA-A-76063', '_id': ObjectId('5d8253057b3fd12bb5f79e12')}
# {'pet_name': 'Paz', 'pet_age': 1.58, 'pet_sex': 'Female', 'pet_breed': 'Terrier, Pit Bull / Mix', 'pet_location': 'TLAC', 'Dog': 2, 'Cat': 0, 'Child': 0, 'Home  Alone ': 4, 'pet_id': 'APA-A-56883', '_id': ObjectId('5d8253057b3fd12bb5f79e13')}
# {'pet_name': 'Reese', 'pet_age': 0.17, 'pet_sex': 'Female', 'pet_breed': 'Dachshund / Terrier', 'pet_location': 'Foster', 'Dog': 4, 'Cat': 4, 'Child': 0, 'Home  Alone ': 2, 'pet_id': 'APA-A-76106', '_id': ObjectId('5d8253057b3fd12bb5f79e14')}
# {'pet_name': 'Lavigne', 'pet_age': 0.17, 'pet_sex': 'Female', 'pet_breed': 'Dachshund / Terrier', 'pet_location': 'Foster', 'Dog': 4, 'Cat': 4, 'Child': 0, 'Home  Alone ': 2, 'pet_id': 'APA-A-76108', '_id': ObjectId('5d8253057b3fd12bb5f79e15')}
# {'pet_name': 'Rufus', 'pet_age': 5.75, 'pet_sex': 'Male', 'pet_breed': 'Mixed Breed (Medium) / Mix', 'pet_location': 'TLAC', 'Dog': 1, 'Cat': 2, 'Child': 1, 'Home  Alone ': 5, 'pet_id': 'APA-A-40179', '_id': ObjectId('5d8253057b3fd12bb5f79e16')}
# {'pet_name': 'Jett', 'pet_age': 0.17, 'pet_sex': 'Female', 'pet_breed': 'Dachshund / Terrier', 'pet_location': 'Foster', 'Dog': 4, 'Cat': 4, 'Child': 0, 'Home  Alone ': 2, 'pet_id': 'APA-A-76109', '_id': ObjectId('5d8253057b3fd12bb5f79e17')}
# {'pet_name': 'Jiggy', 'pet_age': 7.0, 'pet_sex': 'Male', 'pet_breed': 'Chihuahua / Mix', 'pet_location': 'Tarrytown', 'Dog': 4, 'Cat': 0, 'Child': 3, 'Home  Alone ': 3, 'pet_id': 'APA-A-76039', '_id': ObjectId('5d8253057b3fd12bb5f79e18')}
# {'pet_name': 'Foxy', 'pet_age': 0.17, 'pet_sex': 'Female', 'pet_breed': 'Dachshund / Terrier', 'pet_location': 'Foster', 'Dog': 4, 'Cat': 4, 'Child': 0, 'Home  Alone ': 2, 'pet_id': 'APA-A-76110', '_id': ObjectId('5d8253057b3fd12bb5f79e19')}
# {'pet_name': 'Mary Pitt', 'pet_age': 2.33, 'pet_sex': 'Female', 'pet_breed': 'Terrier, Pit Bull / Mix', 'pet_location': 'TLAC', 'Dog': 2, 'Cat': 3, 'Child': 2, 'Home  Alone ': 5, 'pet_id': 'APA-A-53573', '_id': ObjectId('5d8253057b3fd12bb5f79e1a')}
# {'pet_name': 'Callie', 'pet_age': 0.42, 'pet_sex': 'Female', 'pet_breed': 'Shepherd, German / Mix', 'pet_location': 'TLAC', 'Dog': 4, 'Cat': 4, 'Child': 0, 'Home  Alone ': 2, 'pet_id': 'APA-A-76111', '_id': ObjectId('5d8253057b3fd12bb5f79e1b')}
# {'pet_name': 'Tango', 'pet_age': 0.17, 'pet_sex': 'Male', 'pet_breed': 'Dachshund / Terrier', 'pet_location': 'Foster', 'Dog': 4, 'Cat': 4, 'Child': 0, 'Home  Alone ': 2, 'pet_id': 'APA-A-76103', '_id': ObjectId('5d8253057b3fd12bb5f79e1c')}
# {'pet_name': 'Barker', 'pet_age': 0.17, 'pet_sex': 'Male', 'pet_breed': 'Dachshund / Terrier', 'pet_location': 'Foster', 'Dog': 4, 'Cat': 4, 'Child': 0, 'Home  Alone ': 2, 'pet_id': 'APA-A-76104', '_id': ObjectId('5d8253057b3fd12bb5f79e1d')}
# {'pet_name': 'Stump', 'pet_age': 0.17, 'pet_sex': 'Male', 'pet_breed': 'Dachshund / Terrier', 'pet_location': 'Foster', 'Dog': 4, 'Cat': 4, 'Child': 0, 'Home  Alone ': 2, 'pet_id': 'APA-A-76105', '_id': ObjectId('5d8253057b3fd12bb5f79e1e')}
# {'pet_name': 'Smile', 'pet_age': 3.58, 'pet_sex': 'Female', 'pet_breed': 'Black Mouth Cur / Mix', 'pet_location': 'Foster', 'Dog': 0, 'Cat': 0, 'Child': 0, 'Home  Alone ': 0, 'pet_id': 'APA-A-76127', '_id': ObjectId('5d8253057b3fd12bb5f79e1f')}
# {'pet_name': 'Shaamus', 'pet_age': 5.5, 'pet_sex': 'Male', 'pet_breed': 'Cattle Dog / Mix', 'pet_location': 'Foster', 'Dog': 4, 'Cat': 4, 'Child': 3, 'Home  Alone ': 4, 'pet_id': 'APA-A-76126', '_id': ObjectId('5d8253057b3fd12bb5f79e20')}
# {'pet_name': 'Security', 'pet_age': 7.25, 'pet_sex': 'Male', 'pet_breed': 'Chihuahua / Mix', 'pet_location': 'Tarrytown', 'Dog': 0, 'Cat': 0, 'Child': 2, 'Home  Alone ': 0, 'pet_id': 'APA-A-76131', '_id': ObjectId('5d8253057b3fd12bb5f79e21')}
# {'pet_name': 'Casper', 'pet_age': 0.42, 'pet_sex': 'Male', 'pet_breed': 'Retriever, Labrador / Mix', 'pet_location': 'Foster', 'Dog': 4, 'Cat': 4, 'Child': 0, 'Home  Alone ': 2, 'pet_id': 'APA-A-76128', '_id': ObjectId('5d8253057b3fd12bb5f79e22')}
# {'pet_name': 'Missy', 'pet_age': 0.33, 'pet_sex': 'Female', 'pet_breed': 'Cattle Dog, Australian (Red Heeler)', 'pet_location': 'Foster', 'Dog': 4, 'Cat': 4, 'Child': 0, 'Home  Alone ': 2, 'pet_id': 'APA-A-74381', '_id': ObjectId('5d8253057b3fd12bb5f79e23')}
# {'pet_name': 'JFK', 'pet_age': 7.83, 'pet_sex': 'Male', 'pet_breed': 'Mixed Breed (Small)', 'pet_location': 'Tarrytown', 'Dog': 3, 'Cat': 0, 'Child': 3, 'Home  Alone ': 3, 'pet_id': 'APA-A-76129', '_id': ObjectId('5d8253057b3fd12bb5f79e24')}
# {'pet_name': 'Phyllis', 'pet_age': 7.0, 'pet_sex': 'Female', 'pet_breed': 'Chihuahua / Mix', 'pet_location': 'Tarrytown', 'Dog': 0, 'Cat': 0, 'Child': 0, 'Home  Alone ': 0, 'pet_id': 'APA-A-76146', '_id': ObjectId('5d8253057b3fd12bb5f79e25')}
# {'pet_name': 'Cota', 'pet_age': 2.0, 'pet_sex': 'Male', 'pet_breed': 'Retriever, Labrador / Pyrenees, Great', 'pet_location': 'TLAC', 'Dog': 3, 'Cat': 0, 'Child': 0, 'Home  Alone ': 0, 'pet_id': 'APA-A-76151', '_id': ObjectId('5d8253057b3fd12bb5f79e26')}
# {'pet_name': 'Azra', 'pet_age': 5.5, 'pet_sex': 'Female', 'pet_breed': 'Hound, Plott / Mix', 'pet_location': 'TLAC', 'Dog': 1, 'Cat': 0, 'Child': 4, 'Home  Alone ': 5, 'pet_id': 'APA-A-27139', '_id': ObjectId('5d8253057b3fd12bb5f79e27')}
# {'pet_name': 'Casablanca', 'pet_age': 0.17, 'pet_sex': 'Female', 'pet_breed': 'Mixed Breed (Medium)', 'pet_location': 'Foster', 'Dog': 4, 'Cat': 4, 'Child': 0, 'Home  Alone ': 2, 'pet_id': 'APA-A-76157', '_id': ObjectId('5d8253057b3fd12bb5f79e28')}
# {'pet_name': 'Vertigo', 'pet_age': 0.17, 'pet_sex': 'Female', 'pet_breed': 'Mixed Breed (Medium)', 'pet_location': 'Foster', 'Dog': 4, 'Cat': 4, 'Child': 0, 'Home  Alone ': 2, 'pet_id': 'APA-A-76159', '_id': ObjectId('5d8253057b3fd12bb5f79e29')}
# {'pet_name': 'The Wiz', 'pet_age': 0.17, 'pet_sex': 'Female', 'pet_breed': 'Mixed Breed (Medium)', 'pet_location': 'Foster', 'Dog': 4, 'Cat': 4, 'Child': 0, 'Home  Alone ': 2, 'pet_id': 'APA-A-76160', '_id': ObjectId('5d8253057b3fd12bb5f79e2a')}
# {'pet_name': 'Lemon', 'pet_age': 0.17, 'pet_sex': 'Female', 'pet_breed': 'Mixed Breed (Medium)', 'pet_location': 'Foster', 'Dog': 4, 'Cat': 4, 'Child': 0, 'Home  Alone ': 2, 'pet_id': 'APA-A-76161', '_id': ObjectId('5d8253057b3fd12bb5f79e2b')}
# {'pet_name': 'Maggie Shepherd', 'pet_age': 6.0, 'pet_sex': 'Female', 'pet_breed': 'Shepherd / Mixed Breed (Medium)', 'pet_location': 'Foster', 'Dog': 0, 'Cat': 0, 'Child': 0, 'Home  Alone ': 0, 'pet_id': 'APA-A-76178', '_id': ObjectId('5d8253057b3fd12bb5f79e2c')}
# {'pet_name': 'Mockingbird', 'pet_age': 0.17, 'pet_sex': 'Female', 'pet_breed': 'Mixed Breed (Medium)', 'pet_location': 'Foster', 'Dog': 4, 'Cat': 4, 'Child': 0, 'Home  Alone ': 2, 'pet_id': 'APA-A-76156', '_id': ObjectId('5d8253057b3fd12bb5f79e2d')}
# {'pet_name': 'Jaws', 'pet_age': 0.17, 'pet_sex': 'Female', 'pet_breed': 'Mixed Breed (Medium)', 'pet_location': 'Foster', 'Dog': 4, 'Cat': 4, 'Child': 0, 'Home  Alone ': 2, 'pet_id': 'APA-A-76158', '_id': ObjectId('5d8253057b3fd12bb5f79e2e')}
# {'pet_name': 'Ted', 'pet_age': 10.0, 'pet_sex': 'Male', 'pet_breed': 'Terrier, Rat / Chihuahua', 'pet_location': 'Tarrytown', 'Dog': 0, 'Cat': 0, 'Child': 0, 'Home  Alone ': 0, 'pet_id': 'APA-A-76184', '_id': ObjectId('5d8253057b3fd12bb5f79e2f')}
# {'pet_name': 'Allie', 'pet_age': 6.67, 'pet_sex': 'Female', 'pet_breed': 'Terrier, Pit Bull / Mix', 'pet_location': 'TLAC', 'Dog': 0, 'Cat': 0, 'Child': 0, 'Home  Alone ': 0, 'pet_id': 'APA-A-76183', '_id': ObjectId('5d8253057b3fd12bb5f79e30')}
# {'pet_name': 'Eloise', 'pet_age': 0.17, 'pet_sex': 'Female', 'pet_breed': 'Pointer / Retriever, Black Labrador', 'pet_location': 'TLAC', 'Dog': 4, 'Cat': 4, 'Child': 0, 'Home  Alone ': 2, 'pet_id': 'APA-A-76187', '_id': ObjectId('5d8253057b3fd12bb5f79e31')}
# {'pet_name': 'Chanel', 'pet_age': 1.5, 'pet_sex': 'Female', 'pet_breed': 'Terrier, Pit Bull / Mix', 'pet_location': 'Foster', 'Dog': 0, 'Cat': 0, 'Child': 0, 'Home  Alone ': 0, 'pet_id': 'APA-A-76224', '_id': ObjectId('5d8253057b3fd12bb5f79e32')}
# {'pet_name': 'Highland', 'pet_age': 0.33, 'pet_sex': 'Male', 'pet_breed': 'Retriever, Labrador', 'pet_location': 'TLAC', 'Dog': 4, 'Cat': 4, 'Child': 0, 'Home  Alone ': 2, 'pet_id': 'APA-A-76226', '_id': ObjectId('5d8253057b3fd12bb5f79e33')}
# {'pet_name': 'Little Sarah', 'pet_age': 0.42, 'pet_sex': 'Female', 'pet_breed': 'Hound / Mix', 'pet_location': 'Foster', 'Dog': 4, 'Cat': 4, 'Child': 0, 'Home  Alone ': 2, 'pet_id': 'APA-A-76227', '_id': ObjectId('5d8253057b3fd12bb5f79e34')}
# {'pet_name': 'Rex', 'pet_age': 1.67, 'pet_sex': 'Male', 'pet_breed': 'Shepherd, Belgian Malinois / Mix', 'pet_location': 'TLAC', 'Dog': 3, 'Cat': 1, 'Child': 3, 'Home  Alone ': 4, 'pet_id': 'APA-A-61107', '_id': ObjectId('5d8253057b3fd12bb5f79e35')}
# {'pet_name': 'Mikey', 'pet_age': 1.5, 'pet_sex': 'Male', 'pet_breed': 'Retriever, Curly-Coated / Mix', 'pet_location': 'TLAC', 'Dog': 3, 'Cat': 4, 'Child': 0, 'Home  Alone ': 3, 'pet_id': 'APA-A-65819', '_id': ObjectId('5d8253057b3fd12bb5f79e36')}
# {'pet_name': 'Marley', 'pet_age': 0.33, 'pet_sex': 'Female', 'pet_breed': 'Retriever, Labrador / Mix', 'pet_location': 'TLAC', 'Dog': 4, 'Cat': 4, 'Child': 0, 'Home  Alone ': 2, 'pet_id': 'APA-A-76249', '_id': ObjectId('5d8253057b3fd12bb5f79e37')}
# {'pet_name': 'Joe', 'pet_age': 6.0, 'pet_sex': 'Male', 'pet_breed': 'Mastiff', 'pet_location': 'Foster', 'Dog': 0, 'Cat': 0, 'Child': 0, 'Home  Alone ': 0, 'pet_id': 'APA-A-76250', '_id': ObjectId('5d8253057b3fd12bb5f79e38')}
# {'pet_name': 'Dan', 'pet_age': 1.08, 'pet_sex': 'Male', 'pet_breed': 'Boxer / Terrier, Pit Bull', 'pet_location': 'TLAC', 'Dog': 0, 'Cat': 0, 'Child': 0, 'Home  Alone ': 3, 'pet_id': 'APA-A-75668', '_id': ObjectId('5d8253057b3fd12bb5f79e39')}
# {'pet_name': 'Big Brody', 'pet_age': 3.0, 'pet_sex': 'Male', 'pet_breed': 'Black Mouth Cur', 'pet_location': 'Foster', 'Dog': 0, 'Cat': 0, 'Child': 0, 'Home  Alone ': 0, 'pet_id': 'APA-A-76285', '_id': ObjectId('5d8253057b3fd12bb5f79e3a')}
# {'pet_name': 'Niko', 'pet_age': 1.0, 'pet_sex': 'Male', 'pet_breed': 'Beagle / Retriever, Labrador', 'pet_location': 'TLAC', 'Dog': 0, 'Cat': 0, 'Child': 0, 'Home  Alone ': 0, 'pet_id': 'APA-A-76303', '_id': ObjectId('5d8253057b3fd12bb5f79e3b')}
# {'pet_name': 'Eva', 'pet_age': 3.08, 'pet_sex': 'Female', 'pet_breed': 'Mixed Breed (Medium)', 'pet_location': 'TLAC', 'Dog': 3, 'Cat': 0, 'Child': 0, 'Home  Alone ': 0, 'pet_id': 'APA-A-75389', '_id': ObjectId('5d8253057b3fd12bb5f79e3c')}
# {'pet_name': 'Khloe', 'pet_age': 0.83, 'pet_sex': 'Female', 'pet_breed': 'Retriever, Labrador / Mix', 'pet_location': 'Foster', 'Dog': 0, 'Cat': 0, 'Child': 0, 'Home  Alone ': 0, 'pet_id': 'APA-A-76284', '_id': ObjectId('5d8253057b3fd12bb5f79e3d')}
# {'pet_name': 'Napoleon', 'pet_age': 4.25, 'pet_sex': 'Male', 'pet_breed': 'Hound / Mix', 'pet_location': 'TLAC', 'Dog': 3, 'Cat': 5, 'Child': 2, 'Home  Alone ': 5, 'pet_id': 'APA-A-32756', '_id': ObjectId('5d8253057b3fd12bb5f79e3e')}
# {'pet_name': 'Sr Butter', 'pet_age': 10.0, 'pet_sex': 'Female', 'pet_breed': 'Retriever, Yellow Labrador', 'pet_location': 'Foster', 'Dog': 0, 'Cat': 0, 'Child': 0, 'Home  Alone ': 0, 'pet_id': 'APA-A-76286', '_id': ObjectId('5d8253057b3fd12bb5f79e3f')}
# {'pet_name': 'Chocolate', 'pet_age': 2.0, 'pet_sex': 'Male', 'pet_breed': 'Retriever, Labrador / Mix', 'pet_location': 'TLAC', 'Dog': 0, 'Cat': 0, 'Child': 0, 'Home  Alone ': 0, 'pet_id': 'APA-A-76305', '_id': ObjectId('5d8253057b3fd12bb5f79e40')}
# {'pet_name': 'Herb', 'pet_age': 2.0, 'pet_sex': 'Male', 'pet_breed': 'Cattle Dog / Husky', 'pet_location': 'TLAC', 'Dog': 0, 'Cat': 0, 'Child': 0, 'Home  Alone ': 0, 'pet_id': 'APA-A-76306', '_id': ObjectId('5d8253057b3fd12bb5f79e41')}
# {'pet_name': 'Big Brody', 'pet_age': 3.0, 'pet_sex': 'Male', 'pet_breed': 'Black Mouth Cur', 'pet_location': 'Foster', 'Dog': 0, 'Cat': 0, 'Child': 0, 'Home  Alone ': 0, 'pet_id': 'APA-A-76285', '_id': ObjectId('5d8253057b3fd12bb5f79e42')}
# {'pet_name': 'Niko', 'pet_age': 1.0, 'pet_sex': 'Male', 'pet_breed': 'Beagle / Retriever, Labrador', 'pet_location': 'TLAC', 'Dog': 0, 'Cat': 0, 'Child': 0, 'Home  Alone ': 0, 'pet_id': 'APA-A-76303', '_id': ObjectId('5d8253057b3fd12bb5f79e43')}
# {'pet_name': 'Eva', 'pet_age': 3.08, 'pet_sex': 'Female', 'pet_breed': 'Mixed Breed (Medium)', 'pet_location': 'TLAC', 'Dog': 3, 'Cat': 0, 'Child': 0, 'Home  Alone ': 0, 'pet_id': 'APA-A-75389', '_id': ObjectId('5d8253057b3fd12bb5f79e44')}
# {'pet_name': 'Razen', 'pet_age': 3.0, 'pet_sex': 'Female', 'pet_breed': 'Catahoula Leopard Dog', 'pet_location': 'Foster', 'Dog': 0, 'Cat': 0, 'Child': 0, 'Home  Alone ': 0, 'pet_id': 'APA-A-76287', '_id': ObjectId('5d8253057b3fd12bb5f79e45')}
# {'pet_name': 'Luna', 'pet_age': 0.5, 'pet_sex': 'Female', 'pet_breed': 'Retriever, Labrador', 'pet_location': 'TLAC', 'Dog': 0, 'Cat': 0, 'Child': 0, 'Home  Alone ': 0, 'pet_id': 'APA-A-76335', '_id': ObjectId('5d8253057b3fd12bb5f79e46')}
# {'pet_name': 'Ginger', 'pet_age': 0.67, 'pet_sex': 'Female', 'pet_breed': 'Hound, Plott', 'pet_location': 'TLAC', 'Dog': 0, 'Cat': 0, 'Child': 0, 'Home  Alone ': 0, 'pet_id': 'APA-A-76336', '_id': ObjectId('5d8253057b3fd12bb5f79e47')}
# {'pet_name': 'Nadine', 'pet_age': 0.33, 'pet_sex': 'Female', 'pet_breed': 'Hound, Plott / Mix', 'pet_location': 'TLAC', 'Dog': 4, 'Cat': 4, 'Child': 0, 'Home  Alone ': 2, 'pet_id': 'APA-A-76339', '_id': ObjectId('5d8253057b3fd12bb5f79e48')}
# {'pet_name': 'Marcella', 'pet_age': 4.0, 'pet_sex': 'Female', 'pet_breed': 'Terrier / Chihuahua', 'pet_location': 'Tarrytown', 'Dog': 0, 'Cat': 0, 'Child': 0, 'Home  Alone ': 0, 'pet_id': 'APA-A-76323', '_id': ObjectId('5d8253057b3fd12bb5f79e49')}
# {'pet_name': 'Raggedy Andy', 'pet_age': 2.5, 'pet_sex': 'Male', 'pet_breed': 'Terrier / Mix', 'pet_location': 'Tarrytown', 'Dog': 0, 'Cat': 0, 'Child': 3, 'Home  Alone ': 0, 'pet_id': 'APA-A-76325', '_id': ObjectId('5d8253057b3fd12bb5f79e4a')}
# {'pet_name': 'Denzel', 'pet_age': 2.0, 'pet_sex': 'Male', 'pet_breed': 'Hound, Basset / Mix', 'pet_location': 'TLAC', 'Dog': 0, 'Cat': 0, 'Child': 0, 'Home  Alone ': 0, 'pet_id': 'APA-A-76340', '_id': ObjectId('5d8253057b3fd12bb5f79e4b')}
# {'pet_name': 'Apple Pie', 'pet_age': 2.0, 'pet_sex': 'Female', 'pet_breed': 'Sheepdog, Old English / Mix', 'pet_location': 'TLAC', 'Dog': 0, 'Cat': 0, 'Child': 0, 'Home  Alone ': 0, 'pet_id': 'APA-A-76328', '_id': ObjectId('5d8253057b3fd12bb5f79e4c')}
# {'pet_name': 'Skippy', 'pet_age': 1.5, 'pet_sex': 'Male', 'pet_breed': 'Terrier, Pit Bull / Mix', 'pet_location': 'TLAC', 'Dog': 0, 'Cat': 0, 'Child': 0, 'Home  Alone ': 0, 'pet_id': 'APA-A-76330', '_id': ObjectId('5d8253057b3fd12bb5f79e4d')}
# {'pet_name': 'Malik', 'pet_age': 0.83, 'pet_sex': 'Male', 'pet_breed': 'Pointer / Mix', 'pet_location': 'TLAC', 'Dog': 0, 'Cat': 0, 'Child': 0, 'Home  Alone ': 0, 'pet_id': 'APA-A-76331', '_id': ObjectId('5d8253057b3fd12bb5f79e4e')}
# {'pet_name': 'Nickolas', 'pet_age': 0.42, 'pet_sex': 'Male', 'pet_breed': 'Retriever, Labrador / Mix', 'pet_location': 'TLAC', 'Dog': 4, 'Cat': 4, 'Child': 0, 'Home  Alone ': 2, 'pet_id': 'APA-A-76332', '_id': ObjectId('5d8253057b3fd12bb5f79e4f')}

# %%
#Get the number of entries
len(apa_data)
# Out:
# 379
